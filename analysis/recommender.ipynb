# %%
import pandas as pd
import numpy as np

# %%
students = pd.read_csv('dataset/students.csv')
internships = pd.read_csv('dataset/internships.csv')

# %%
students.head()
# Out:
#    student_id student_name                                             skills  \
# 0           1    Student_1         machine learning, data science, agentic ai
# 1           2    Student_2                     dart, firebase, swift, flutter
# 2           3    Student_3  digital marketing, content writing, mailchimp,...
# 3           4    Student_4  financial modeling, ms excel, tally, business ...
# 4           5    Student_5                              ios, firebase, kotlin
#
#           primary_domain
# 0  Machine Learning / AI
# 1     Mobile Development
# 2   Business / Marketing
# 3   Finance / Management
# 4     Mobile Development

# %%
internships.head()
# Out:
#    internship_id               internship_title             company  stipend  \
# 0              1  Infrastructure As Code Intern        Skyline Corp        0
# 1              2                   Canva Intern        Guerrero LLC     5000
# 2              3              Tensorflow Intern     Harris and Sons    15000
# 3              4                Ms Excel Intern  Singh Technologies    25000
# 4              5         Market Research Intern        Skyline Corp        0
#
#                                      required_skills                 domain
# 0  terraform, azure, docker, gcp, infrastructure ...         DevOps / Cloud
# 1  interaction design, graphic design, photoshop,...                 Design
# 2  agentic ai, pytorch, tensorflow, computer visi...  Machine Learning / AI
# 3  quickbooks, tally, accounting, ms excel, busin...   Finance / Management
# 4    social media strategy, market research, hubspot   Business / Marketing

# %%
students["skills"] = students["skills"].str.lower()
internships["required_skills"] = internships["required_skills"].str.lower()

# %%
stu_skills = students.set_index('student_id')['skills'].to_dict()
int_reqs = internships.set_index('internship_id')['required_skills'].to_dict()

# %%
stu_skills
# Out:
# {1: 'machine learning, data science, agentic ai',
#  2: 'dart, firebase, swift, flutter',
#  3: 'digital marketing, content writing, mailchimp, hubspot',
#  4: 'financial modeling, ms excel, tally, business analysis, quickbooks, accounting',
#  5: 'ios, firebase, kotlin',
#  6: 'canva, adobe xd, figma, interaction design, ui/ux design, illustrator',
#  7: 'gen ai, agentic ai, deep learning, data science, machine learning',
#  8: 'figma, ui/ux design, photoshop, adobe xd',
#  9: 'sql, postgresql, flask',
#  10: 'tally, business analysis, accounting, financial modeling',
#  11: 'digital marketing, hubspot, seo, content writing, market research, social media strategy',
#  12: 'kafka, hadoop, snowflake, spark, tableau, sql',
#  13: 'airflow, tableau, powerbi, hadoop',
#  14: 'adobe xd, illustrator, ui/ux design, canva, figma, photoshop',
#  15: 'css, angular, html, react',
#  16: 'canva, graphic design, figma, photoshop',
#  17: 'swift, react native, firebase, android',
#  18: 'financial modeling, accounting, risk analysis, ms excel',
#  19: 'react native, flutter, android, ios',
#  20: 'quickbooks, business analysis, accounting',
#  21: 'google analytics, seo, mailchimp, digital marketing',
#  22: 'pytorch, tensorflow, agentic ai',
#  23: 'jenkins, ci/cd, infrastructure as code, aws, terraform',
#  24: 'excel, spark, hadoop, tableau, sql',
#  25: 'kubernetes, aws, azure, ci/cd, ansible',
#  26: 'seo, google analytics, digital marketing, hubspot, content writing, mailchimp',
#  27: 'gen ai, mlops, pytorch, machine learning',
#  28: 'gen ai, mlops, agentic ai, data science',
#  29: 'photoshop, graphic design, adobe xd, ui/ux design',
#  30: 'deep learning, nlp, gen ai, machine learning, agentic ai',
#  31: 'mailchimp, hubspot, seo, content writing, market research, social media strategy',
#  32: 'graphic design, photoshop, adobe xd, illustrator, interaction design, ui/ux design',
#  33: 'business analysis, tally, financial modeling',
#  34: 'firebase, dart, android',
#  35: 'adobe xd, ui/ux design, graphic design, figma, canva, interaction design',
#  36: 'mailchimp, content writing, google analytics',
#  37: 'azure, terraform, ci/cd',
#  38: 'ios, react native, dart, kotlin',
#  39: 'flask, spring, mongodb, sql, django, react',
#  40: 'illustrator, graphic design, photoshop, canva, figma, ui/ux design',
#  41: 'agentic ai, computer vision, scikit-learn, pytorch, tensorflow, nlp',
#  42: 'angular, javascript, express',
#  43: 'kubernetes, gcp, terraform, aws',
#  44: 'accounting, risk analysis, ms excel, quickbooks, tally, business analysis',
#  45: 'financial modeling, ms excel, risk analysis, quickbooks',
#  46: 'dart, android, ios, firebase',
#  47: 'figma, ui/ux design, interaction design, photoshop, adobe xd',
#  48: 'flutter, android, kotlin, dart',
#  49: 'market research, digital marketing, social media strategy',
#  50: 'sql, airflow, snowflake, kafka',
#  51: 'social media strategy, content writing, mailchimp, hubspot, market research',
#  52: 'gen ai, deep learning, data science, machine learning',
#  53: 'computer vision, tensorflow, pytorch, nlp',
#  54: 'html, sql, postgresql, css, flask',
#  55: 'spring, vue, sql, next.js, express, postgresql',
#  56: 'content writing, market research, google analytics, mailchimp, social media strategy',
#  57: 'hubspot, seo, social media strategy, google analytics',
#  58: 'ansible, ci/cd, jenkins',
#  59: 'nodejs, css, postgresql, flask, angular, vue',
#  60: 'hubspot, seo, content writing',
#  61: 'quickbooks, accounting, tally, risk analysis, business analysis',
#  62: 'aws, ansible, jenkins, azure',
#  63: 'scikit-learn, data science, deep learning, computer vision, agentic ai, machine learning',
#  64: 'gcp, kubernetes, aws, terraform, jenkins',
#  65: 'snowflake, kafka, excel, etl',
#  66: 'kubernetes, infrastructure as code, docker',
#  67: 'graphic design, illustrator, photoshop, ui/ux design, canva, adobe xd',
#  68: 'sql, kafka, tableau, snowflake, excel, airflow',
#  69: 'nlp, data science, mlops',
#  70: 'hadoop, spark, snowflake',
#  71: 'react native, android, swift, ios, flutter',
#  72: 'accounting, risk analysis, business analysis',
#  73: 'financial modeling, accounting, tally, risk analysis',
#  74: 'pytorch, computer vision, machine learning',
#  75: 'angular, css, html',
#  76: 'market research, digital marketing, social media strategy',
#  77: 'swift, kotlin, react native, firebase, android, dart',
#  78: 'gen ai, deep learning, tensorflow, machine learning',
#  79: 'computer vision, nlp, pytorch, scikit-learn, agentic ai',
#  80: 'computer vision, deep learning, data science, machine learning, scikit-learn, gen ai',
#  81: 'docker, jenkins, terraform, gcp, aws, ansible',
#  82: 'snowflake, airflow, sql, tableau, excel, kafka',
#  83: 'figma, illustrator, ui/ux design, photoshop',
#  84: 'sql, excel, hadoop',
#  85: 'firebase, kotlin, swift, flutter',
#  86: 'ui/ux design, photoshop, illustrator, interaction design, canva, adobe xd',
#  87: 'figma, canva, adobe xd',
#  88: 'aws, jenkins, terraform, gcp, docker, ansible',
#  89: 'azure, infrastructure as code, jenkins, terraform',
#  90: 'kubernetes, jenkins, ci/cd, aws',
#  91: 'html, nodejs, angular, flask, sql, mongodb',
#  92: 'social media strategy, content writing, google analytics, digital marketing, hubspot, mailchimp',
#  93: 'interaction design, figma, adobe xd, photoshop, graphic design, canva',
#  94: 'spring, vue, html, mongodb, flask, javascript',
#  95: 'sql, css, django',
#  96: 'tableau, etl, kafka, sql, excel, airflow',
#  97: 'docker, infrastructure as code, aws, jenkins',
#  98: 'risk analysis, business analysis, ms excel',
#  99: 'tableau, hadoop, spark',
#  100: 'accounting, business analysis, financial modeling, quickbooks, risk analysis',
#  101: 'gcp, terraform, ansible, ci/cd',
#  102: 'excel, kafka, tableau',
#  103: 'ios, react native, dart, swift, firebase',
#  104: 'snowflake, kafka, airflow, tableau, powerbi',
#  105: 'kafka, powerbi, etl',
#  106: 'powerbi, hadoop, tableau, snowflake, spark',
#  107: 'terraform, infrastructure as code, ansible, kubernetes, docker, aws',
#  108: 'deep learning, agentic ai, computer vision, nlp',
#  109: 'javascript, express, angular',
#  110: 'social media strategy, market research, seo',
#  111: 'firebase, kotlin, flutter, swift, android, dart',
#  112: 'spark, hadoop, sql, airflow, kafka, powerbi',
#  113: 'firebase, flutter, swift, ios',
#  114: 'excel, tableau, powerbi',
#  115: 'risk analysis, accounting, ms excel',
#  116: 'quickbooks, ms excel, accounting, financial modeling, tally',
#  117: 'flutter, kotlin, ios',
#  118: 'photoshop, illustrator, canva',
#  119: 'agentic ai, mlops, computer vision, tensorflow, data science',
#  120: 'ios, flutter, firebase, android',
#  121: 'airflow, spark, snowflake, etl',
#  122: 'social media strategy, mailchimp, seo, market research, digital marketing',
#  123: 'ms excel, quickbooks, accounting',
#  124: 'react, next.js, postgresql, css, javascript',
#  125: 'swift, dart, ios, react native',
#  126: 'tally, ms excel, financial modeling, risk analysis, business analysis, quickbooks',
#  127: 'agentic ai, nlp, machine learning, tensorflow',
#  128: 'computer vision, mlops, data science, pytorch',
#  129: 'mailchimp, seo, digital marketing, hubspot, content writing, social media strategy',
#  130: 'aws, ansible, infrastructure as code, gcp, docker, ci/cd',
#  131: 'accounting, risk analysis, financial modeling, tally',
#  132: 'dart, kotlin, react native, flutter',
#  133: 'photoshop, interaction design, adobe xd, illustrator, figma, graphic design',
#  134: 'sql, spring, nodejs, css, html, django',
#  135: 'risk analysis, financial modeling, tally, accounting, business analysis',
#  136: 'aws, ansible, terraform, kubernetes',
#  137: 'mongodb, react, sql, next.js, html, nodejs',
#  138: 'dart, swift, ios',
#  139: 'tensorflow, pytorch, gen ai, agentic ai',
#  140: 'django, html, postgresql',
#  141: 'graphic design, figma, adobe xd, canva, illustrator, interaction design',
#  142: 'digital marketing, google analytics, market research, mailchimp',
#  143: 'infrastructure as code, kubernetes, gcp, terraform, jenkins',
#  144: 'google analytics, hubspot, digital marketing, market research',
#  145: 'aws, terraform, docker, ci/cd',
#  146: 'financial modeling, business analysis, quickbooks',
#  147: 'kotlin, react native, dart',
#  148: 'flutter, swift, dart',
#  149: 'figma, interaction design, ui/ux design, photoshop',
#  150: 'react, postgresql, vue',
#  151: 'data science, mlops, pytorch, agentic ai',
#  152: 'digital marketing, hubspot, google analytics, market research, content writing, mailchimp',
#  153: 'adobe xd, photoshop, graphic design, canva',
#  154: 'digital marketing, seo, mailchimp, social media strategy',
#  155: 'docker, jenkins, ansible',
#  156: 'agentic ai, pytorch, tensorflow, gen ai',
#  157: 'risk analysis, ms excel, financial modeling, business analysis',
#  158: 'ios, dart, react native',
#  159: 'ui/ux design, illustrator, figma, interaction design',
#  160: 'hadoop, airflow, tableau, kafka, snowflake',
#  161: 'express, css, nodejs, spring, postgresql, next.js',
#  162: 'javascript, spring, css, mongodb',
#  163: 'mlops, machine learning, pytorch',
#  164: 'google analytics, mailchimp, hubspot',
#  165: 'html, angular, postgresql, vue',
#  166: 'content writing, social media strategy, mailchimp, market research',
#  167: 'kafka, airflow, sql, etl, snowflake, tableau',
#  168: 'deep learning, computer vision, pytorch, scikit-learn',
#  169: 'risk analysis, ms excel, tally, accounting, business analysis',
#  170: 'agentic ai, scikit-learn, pytorch, tensorflow',
#  171: 'hadoop, tableau, sql',
#  172: 'sql, powerbi, excel, kafka',
#  173: 'kafka, excel, tableau',
#  174: 'ci/cd, ansible, azure, kubernetes, gcp',
#  175: 'firebase, swift, kotlin, dart',
#  176: 'tensorflow, gen ai, pytorch, nlp',
#  177: 'mlops, computer vision, pytorch, agentic ai, gen ai',
#  178: 'mailchimp, social media strategy, content writing, digital marketing, market research',
#  179: 'quickbooks, tally, risk analysis, ms excel, financial modeling',
#  180: 'tensorflow, scikit-learn, mlops, deep learning',
#  181: 'digital marketing, seo, content writing, social media strategy',
#  182: 'hubspot, market research, google analytics',
#  183: 'spark, sql, powerbi, snowflake',
#  184: 'agentic ai, scikit-learn, mlops, pytorch, computer vision',
#  185: 'snowflake, excel, kafka, hadoop, powerbi',
#  186: 'sql, snowflake, excel, tableau',
#  187: 'social media strategy, content writing, google analytics, mailchimp, market research, hubspot',
#  188: 'mailchimp, social media strategy, market research, hubspot, seo',
#  189: 'aws, kubernetes, jenkins, terraform, azure',
#  190: 'azure, aws, kubernetes, docker',
#  191: 'adobe xd, photoshop, canva',
#  192: 'quickbooks, ms excel, risk analysis, tally, accounting',
#  193: 'infrastructure as code, kubernetes, azure, gcp, jenkins, terraform',
#  194: 'figma, graphic design, interaction design, canva',
#  195: 'jenkins, infrastructure as code, kubernetes, gcp, aws',
#  196: 'content writing, hubspot, market research, google analytics, mailchimp, seo',
#  197: 'postgresql, next.js, flask',
#  198: 'machine learning, data science, computer vision, pytorch',
#  199: 'canva, adobe xd, figma, interaction design, photoshop',
#  200: 'django, spring, angular',
#  201: 'ios, kotlin, dart',
#  202: 'flutter, swift, kotlin, dart',
#  203: 'azure, gcp, kubernetes, aws, ci/cd, terraform',
#  204: 'aws, jenkins, docker, gcp, ci/cd, kubernetes',
#  205: 'accounting, risk analysis, ms excel, business analysis, tally',
#  206: 'terraform, docker, azure',
#  207: 'accounting, tally, ms excel, quickbooks, risk analysis',
#  208: 'ms excel, risk analysis, quickbooks, accounting, tally',
#  209: 'aws, gcp, ansible',
#  210: 'ci/cd, kubernetes, ansible',
#  211: 'gen ai, data science, pytorch, scikit-learn, computer vision, agentic ai',
#  212: 'interaction design, photoshop, adobe xd, illustrator, canva',
#  213: 'next.js, flask, django, css, angular',
#  214: 'hadoop, spark, powerbi, sql',
#  215: 'quickbooks, financial modeling, risk analysis, tally, business analysis',
#  216: 'canva, interaction design, adobe xd',
#  217: 'scikit-learn, machine learning, data science',
#  218: 'postgresql, vue, spring, react',
#  219: 'hadoop, snowflake, excel, spark, etl',
#  220: 'google analytics, digital marketing, content writing, mailchimp, social media strategy, hubspot',
#  221: 'flask, spring, next.js, javascript',
#  222: 'photoshop, illustrator, adobe xd',
#  223: 'deep learning, agentic ai, pytorch, nlp, scikit-learn, data science',
#  224: 'hadoop, tableau, powerbi, snowflake, etl, sql',
#  225: 'nodejs, vue, css, angular',
#  226: 'computer vision, agentic ai, deep learning, tensorflow, nlp',
#  227: 'hubspot, google analytics, seo, mailchimp, social media strategy, digital marketing',
#  228: 'powerbi, tableau, kafka, airflow',
#  229: 'nlp, pytorch, deep learning, mlops',
#  230: 'tensorflow, pytorch, mlops, scikit-learn',
#  231: 'react, flask, spring',
#  232: 'excel, tableau, snowflake, airflow',
#  233: 'business analysis, tally, financial modeling, quickbooks',
#  234: 'tally, business analysis, ms excel, risk analysis, quickbooks, accounting',
#  235: 'docker, terraform, aws, ci/cd, infrastructure as code, jenkins',
#  236: 'business analysis, tally, risk analysis',
#  237: 'android, react native, swift, flutter, dart',
#  238: 'illustrator, ui/ux design, adobe xd, interaction design, figma, canva',
#  239: 'gen ai, machine learning, pytorch',
#  240: 'ansible, infrastructure as code, ci/cd',
#  241: 'django, css, html, spring, sql, flask',
#  242: 'ui/ux design, photoshop, interaction design, adobe xd, graphic design',
#  243: 'deep learning, tensorflow, mlops, computer vision, gen ai, machine learning',
#  244: 'angular, flask, sql, react, css, spring',
#  245: 'express, react, angular, css',
#  246: 'excel, tableau, snowflake, etl, powerbi, sql',
#  247: 'illustrator, photoshop, graphic design',
#  248: 'firebase, swift, ios, android, dart, flutter',
#  249: 'graphic design, figma, ui/ux design, adobe xd',
#  250: 'snowflake, sql, excel, tableau, airflow, hadoop',
#  251: 'sql, etl, kafka, spark, tableau',
#  252: 'tableau, snowflake, etl, excel, spark',
#  253: 'firebase, kotlin, swift',
#  254: 'photoshop, figma, graphic design',
#  255: 'infrastructure as code, docker, gcp',
#  256: 'aws, jenkins, infrastructure as code',
#  257: 'gen ai, deep learning, computer vision, scikit-learn',
#  258: 'terraform, jenkins, infrastructure as code',
#  259: 'firebase, swift, flutter',
#  260: 'mlops, pytorch, scikit-learn, deep learning',
#  261: 'ios, firebase, swift, dart, android',
#  262: 'infrastructure as code, kubernetes, terraform',
#  263: 'sql, express, css, spring, flask, mongodb',
#  264: 'firebase, ios, dart',
#  265: 'financial modeling, accounting, risk analysis, ms excel, business analysis, quickbooks',
#  266: 'canva, adobe xd, photoshop, interaction design, illustrator',
#  267: 'swift, dart, react native',
#  268: 'kafka, etl, sql',
#  269: 'figma, ui/ux design, interaction design, adobe xd',
#  270: 'canva, photoshop, graphic design, figma, illustrator',
#  271: 'powerbi, hadoop, tableau, kafka',
#  272: 'express, django, postgresql, nodejs, mongodb',
#  273: 'canva, figma, adobe xd, photoshop, graphic design',
#  274: 'tableau, snowflake, sql, kafka',
#  275: 'docker, kubernetes, jenkins, infrastructure as code',
#  276: 'aws, docker, infrastructure as code, jenkins, terraform',
#  277: 'computer vision, agentic ai, pytorch',
#  278: 'digital marketing, market research, google analytics, content writing, seo',
#  279: 'mlops, computer vision, data science, machine learning, gen ai',
#  280: 'excel, tableau, powerbi, hadoop',
#  281: 'nlp, agentic ai, machine learning',
#  282: 'jenkins, ci/cd, kubernetes, gcp, docker',
#  283: 'canva, ui/ux design, illustrator',
#  284: 'ui/ux design, adobe xd, photoshop',
#  285: 'market research, google analytics, seo, content writing',
#  286: 'financial modeling, quickbooks, accounting',
#  287: 'illustrator, figma, ui/ux design',
#  288: 'javascript, flask, mongodb, django, nodejs',
#  289: 'social media strategy, digital marketing, content writing, market research',
#  290: 'excel, airflow, snowflake, sql, spark, kafka',
#  291: 'computer vision, gen ai, mlops',
#  292: 'mailchimp, market research, content writing, seo, digital marketing',
#  293: 'nodejs, javascript, django, sql, express, flask',
#  294: 'aws, kubernetes, gcp',
#  295: 'accounting, risk analysis, tally',
#  296: 'nodejs, vue, sql, javascript, next.js',
#  297: 'ui/ux design, canva, illustrator, adobe xd, graphic design',
#  298: 'ci/cd, azure, terraform, infrastructure as code, kubernetes',
#  299: 'firebase, react native, android, dart, swift',
#  300: 'sql, excel, snowflake',
#  301: 'photoshop, canva, adobe xd',
#  302: 'google analytics, social media strategy, hubspot, seo, digital marketing, mailchimp',
#  303: 'etl, spark, hadoop, sql, snowflake, tableau',
#  304: 'photoshop, illustrator, graphic design, ui/ux design',
#  305: 'jenkins, infrastructure as code, docker, gcp, kubernetes',
#  306: 'kotlin, flutter, react native, dart, swift',
#  307: 'gen ai, agentic ai, nlp, mlops, scikit-learn',
#  308: 'ui/ux design, photoshop, interaction design, graphic design',
#  309: 'tally, accounting, risk analysis, business analysis',
#  310: 'data science, gen ai, agentic ai, tensorflow, pytorch',
#  311: 'html, mongodb, angular, nodejs, sql',
#  312: 'illustrator, figma, photoshop, ui/ux design, canva, interaction design',
#  313: 'kafka, snowflake, excel, tableau',
#  314: 'accounting, risk analysis, business analysis',
#  315: 'photoshop, figma, ui/ux design, adobe xd, interaction design, illustrator',
#  316: 'tableau, snowflake, hadoop, kafka, sql, spark',
#  317: 'flask, spring, sql, vue, html, postgresql',
#  318: 'dart, react native, ios, swift',
#  319: 'dart, react native, firebase, flutter, swift',
#  320: 'photoshop, interaction design, graphic design',
#  321: 'react, html, django',
#  322: 'docker, kubernetes, terraform',
#  323: 'hubspot, content writing, google analytics',
#  324: 'nlp, tensorflow, agentic ai',
#  325: 'google analytics, seo, hubspot, digital marketing',
#  326: 'sql, html, mongodb, spring, vue',
#  327: 'interaction design, canva, illustrator, photoshop',
#  328: 'figma, photoshop, adobe xd, canva, graphic design, ui/ux design',
#  329: 'ms excel, tally, financial modeling, quickbooks, accounting',
#  330: 'tensorflow, scikit-learn, nlp, computer vision',
#  331: 'snowflake, tableau, excel, kafka, airflow',
#  332: 'angular, django, css, nodejs, flask, express',
#  333: 'sql, css, vue, javascript',
#  334: 'angular, next.js, flask, mongodb, express',
#  335: 'nodejs, angular, react, next.js',
#  336: 'jenkins, docker, azure, kubernetes',
#  337: 'tally, financial modeling, business analysis, ms excel',
#  338: 'ms excel, financial modeling, business analysis, tally, accounting, risk analysis',
#  339: 'react native, swift, firebase, dart, kotlin, ios',
#  340: 'nlp, gen ai, computer vision, tensorflow, data science',
#  341: 'market research, seo, content writing, social media strategy, mailchimp, google analytics',
#  342: 'accounting, quickbooks, business analysis, tally, ms excel',
#  343: 'excel, snowflake, tableau, hadoop',
#  344: 'deep learning, pytorch, nlp, mlops, agentic ai',
#  345: 'gcp, terraform, ci/cd, jenkins, aws, infrastructure as code',
#  346: 'google analytics, seo, content writing',
#  347: 'gcp, azure, terraform, kubernetes, aws',
#  348: 'hadoop, tableau, snowflake, kafka',
#  349: 'ansible, jenkins, ci/cd, terraform',
#  350: 'tally, quickbooks, risk analysis',
#  351: 'risk analysis, quickbooks, financial modeling, accounting',
#  352: 'business analysis, quickbooks, risk analysis, financial modeling, tally',
#  353: 'snowflake, sql, kafka, powerbi',
#  354: 'hadoop, etl, spark, sql, airflow',
#  355: 'agentic ai, machine learning, mlops, deep learning',
#  356: 'excel, tableau, kafka',
#  357: 'machine learning, agentic ai, nlp, tensorflow',
#  358: 'gen ai, mlops, computer vision',
#  359: 'ms excel, risk analysis, quickbooks, tally, accounting, financial modeling',
#  360: 'financial modeling, business analysis, ms excel, risk analysis, tally, quickbooks',
#  361: 'swift, dart, android, flutter',
#  362: 'ms excel, tally, accounting, quickbooks',
#  363: 'snowflake, powerbi, excel, sql, tableau',
#  364: 'hadoop, snowflake, airflow',
#  365: 'spark, hadoop, powerbi, sql',
#  366: 'swift, react native, dart, android',
#  367: 'content writing, google analytics, hubspot, seo, market research, social media strategy',
#  368: 'mongodb, javascript, flask, postgresql, spring, sql',
#  369: 'machine learning, pytorch, tensorflow, deep learning, gen ai, mlops',
#  370: 'digital marketing, hubspot, market research, google analytics, content writing',
#  371: 'spark, etl, hadoop, powerbi',
#  372: 'financial modeling, quickbooks, ms excel, risk analysis, accounting',
#  373: 'sql, excel, kafka',
#  374: 'dart, ios, flutter, kotlin',
#  375: 'ios, android, swift, flutter, react native',
#  376: 'react native, flutter, kotlin, firebase, dart, android',
#  377: 'dart, android, swift, firebase, flutter',
#  378: 'html, django, next.js, express',
#  379: 'scikit-learn, tensorflow, computer vision, machine learning',
#  380: 'risk analysis, financial modeling, quickbooks',
#  381: 'airflow, sql, powerbi, spark',
#  382: 'mailchimp, google analytics, market research, digital marketing',
#  383: 'deep learning, nlp, mlops',
#  384: 'terraform, ansible, ci/cd, jenkins, docker, azure',
#  385: 'excel, powerbi, sql',
#  386: 'tableau, snowflake, hadoop',
#  387: 'azure, kubernetes, docker',
#  388: 'postgresql, html, angular',
#  389: 'tensorflow, deep learning, agentic ai, data science, mlops, computer vision',
#  390: 'financial modeling, ms excel, quickbooks, risk analysis, accounting, tally',
#  391: 'ui/ux design, canva, graphic design',
#  392: 'flutter, kotlin, dart',
#  393: 'risk analysis, ms excel, quickbooks, business analysis, accounting',
#  394: 'tally, financial modeling, business analysis',
#  395: 'vue, django, next.js, spring, express, mongodb',
#  396: 'scikit-learn, data science, tensorflow, gen ai, nlp',
#  397: 'express, react, mongodb, sql, spring',
#  398: 'dart, react native, swift',
#  399: 'mailchimp, google analytics, hubspot, digital marketing',
#  400: 'business analysis, risk analysis, quickbooks, tally, accounting, ms excel',
#  401: 'canva, photoshop, adobe xd, interaction design, figma',
#  402: 'ui/ux design, illustrator, adobe xd, graphic design',
#  403: 'photoshop, graphic design, canva, illustrator, figma',
#  404: 'azure, kubernetes, terraform, jenkins, aws, ci/cd',
#  405: 'adobe xd, interaction design, figma, canva',
#  406: 'gcp, ansible, azure, aws, kubernetes',
#  407: 'digital marketing, content writing, google analytics, seo, mailchimp, hubspot',
#  408: 'deep learning, mlops, nlp, machine learning',
#  409: 'quickbooks, tally, risk analysis, ms excel, business analysis, accounting',
#  410: 'express, html, spring, django, css, sql',
#  411: 'kotlin, react native, swift, dart',
#  412: 'ios, dart, swift, flutter, android, firebase',
#  413: 'react native, android, dart',
#  414: 'powerbi, spark, sql, snowflake, hadoop, excel',
#  415: 'android, react native, kotlin, dart, swift, ios',
#  416: 'content writing, social media strategy, google analytics',
#  417: 'excel, etl, snowflake, hadoop, airflow',
#  418: 'ms excel, financial modeling, risk analysis',
#  419: 'gcp, kubernetes, docker, jenkins',
#  420: 'kotlin, dart, android, firebase, swift, flutter',
#  421: 'android, react native, kotlin, dart, ios',
#  422: 'tensorflow, pytorch, scikit-learn',
#  423: 'hadoop, spark, excel',
#  424: 'illustrator, adobe xd, photoshop, graphic design, canva',
#  425: 'dart, android, swift, flutter, react native, kotlin',
#  426: 'digital marketing, content writing, market research, hubspot',
#  427: 'mailchimp, digital marketing, google analytics, content writing',
#  428: 'aws, docker, terraform, ansible, gcp',
#  429: 'kubernetes, infrastructure as code, jenkins, ansible, aws',
#  430: 'tally, risk analysis, business analysis, ms excel, financial modeling, quickbooks',
#  431: 'infrastructure as code, ci/cd, aws, kubernetes, terraform, docker',
#  432: 'content writing, hubspot, seo, digital marketing, market research',
#  433: 'css, angular, flask, express',
#  434: 'ms excel, accounting, quickbooks, tally, financial modeling',
#  435: 'mlops, pytorch, tensorflow, computer vision, nlp, scikit-learn',
#  436: 'kafka, tableau, hadoop, sql',
#  437: 'aws, kubernetes, infrastructure as code, ci/cd, docker',
#  438: 'dart, android, flutter, ios, swift, kotlin',
#  439: 'tally, ms excel, financial modeling',
#  440: 'photoshop, adobe xd, illustrator',
#  441: 'react native, firebase, kotlin, ios',
#  442: 'tableau, hadoop, spark, snowflake',
#  443: 'illustrator, ui/ux design, photoshop, adobe xd, canva, interaction design',
#  444: 'swift, flutter, kotlin, dart',
#  445: 'flask, next.js, angular',
#  446: 'flutter, ios, android, swift, kotlin',
#  447: 'computer vision, scikit-learn, agentic ai, nlp',
#  448: 'powerbi, tableau, kafka, etl',
#  449: 'ansible, gcp, docker',
#  450: 'infrastructure as code, docker, kubernetes, ansible, terraform',
#  451: 'graphic design, interaction design, ui/ux design, photoshop, adobe xd, illustrator',
#  452: 'django, express, mongodb, postgresql, flask',
#  453: 'social media strategy, mailchimp, market research',
#  454: 'hubspot, google analytics, mailchimp, seo, market research, content writing',
#  455: 'swift, firebase, kotlin',
#  456: 'ios, android, flutter, dart',
#  457: 'tally, ms excel, quickbooks, risk analysis, financial modeling, accounting',
#  458: 'risk analysis, accounting, business analysis, quickbooks, ms excel, tally',
#  459: 'figma, ui/ux design, illustrator, canva',
#  460: 'canva, graphic design, ui/ux design, adobe xd, figma, illustrator',
#  461: 'infrastructure as code, jenkins, azure, ansible, docker, gcp',
#  462: 'kotlin, swift, ios',
#  463: 'spring, nodejs, postgresql, next.js',
#  464: 'social media strategy, content writing, seo, google analytics, digital marketing',
#  465: 'deep learning, mlops, tensorflow, pytorch',
#  466: 'seo, mailchimp, social media strategy, google analytics',
#  467: 'google analytics, social media strategy, market research, mailchimp, content writing',
#  468: 'computer vision, data science, gen ai, mlops, nlp',
#  469: 'ui/ux design, adobe xd, interaction design, illustrator',
#  470: 'quickbooks, risk analysis, tally, accounting',
#  471: 'illustrator, canva, figma, graphic design',
#  472: 'photoshop, figma, interaction design, canva, graphic design, illustrator',
#  473: 'photoshop, graphic design, figma, ui/ux design, adobe xd',
#  474: 'javascript, postgresql, django, flask',
#  475: 'infrastructure as code, ci/cd, jenkins, docker, azure, terraform',
#  476: 'flask, react, angular, mongodb, sql',
#  477: 'kafka, snowflake, airflow',
#  478: 'ui/ux design, photoshop, illustrator, graphic design',
#  479: 'risk analysis, ms excel, quickbooks, accounting, business analysis, financial modeling',
#  480: 'firebase, kotlin, android, swift',
#  481: 'tableau, etl, snowflake, spark, excel, airflow',
#  482: 'firebase, kotlin, swift, ios',
#  483: 'graphic design, canva, figma, photoshop, interaction design, adobe xd',
#  484: 'excel, tableau, etl, sql',
#  485: 'kafka, etl, spark, airflow',
#  486: 'postgresql, spring, express, vue, html, nodejs',
#  487: 'dart, swift, react native',
#  488: 'kotlin, firebase, react native',
#  489: 'google analytics, mailchimp, market research',
#  490: 'social media strategy, digital marketing, hubspot',
#  491: 'gcp, jenkins, ci/cd',
#  492: 'interaction design, photoshop, ui/ux design, canva, figma',
#  493: 'digital marketing, content writing, hubspot, google analytics, mailchimp, seo',
#  494: 'agentic ai, deep learning, machine learning, scikit-learn, pytorch, nlp',
#  495: 'docker, terraform, jenkins, kubernetes',
#  496: 'digital marketing, hubspot, seo, google analytics',
#  497: 'angular, react, css, mongodb, flask',
#  498: 'mlops, gen ai, tensorflow, machine learning, deep learning, agentic ai',
#  499: 'canva, graphic design, interaction design, photoshop',
#  500: 'data science, mlops, computer vision',
#  501: 'graphic design, figma, illustrator',
#  502: 'tensorflow, deep learning, machine learning, nlp, pytorch, data science',
#  503: 'airflow, excel, sql, etl, snowflake, powerbi',
#  504: 'django, express, javascript, css',
#  505: 'pytorch, deep learning, scikit-learn, tensorflow, computer vision',
#  506: 'flutter, dart, react native, kotlin, android',
#  507: 'dart, swift, kotlin, android',
#  508: 'digital marketing, social media strategy, market research, content writing',
#  509: 'google analytics, content writing, mailchimp, social media strategy, digital marketing, hubspot',
#  510: 'spring, javascript, next.js',
#  511: 'social media strategy, digital marketing, hubspot, mailchimp',
#  512: 'data science, mlops, computer vision, gen ai',
#  513: 'html, postgresql, vue',
#  514: 'google analytics, hubspot, social media strategy, content writing, seo',
#  515: 'flutter, ios, firebase, android',
#  516: 'infrastructure as code, kubernetes, ci/cd',
#  517: 'data science, computer vision, gen ai, scikit-learn',
#  518: 'ios, firebase, dart, flutter, android, kotlin',
#  519: 'excel, sql, spark, airflow, kafka, etl',
#  520: 'powerbi, spark, snowflake',
#  521: 'canva, adobe xd, illustrator, ui/ux design, photoshop',
#  522: 'adobe xd, graphic design, canva, ui/ux design, figma',
#  523: 'ios, swift, dart',
#  524: 'react native, firebase, dart',
#  525: 'kafka, tableau, etl, airflow, spark',
#  526: 'ios, swift, kotlin, android',
#  527: 'excel, spark, snowflake',
#  528: 'flutter, dart, firebase',
#  529: 'ui/ux design, illustrator, photoshop, canva, adobe xd, graphic design',
#  530: 'quickbooks, business analysis, risk analysis',
#  531: 'machine learning, nlp, agentic ai, pytorch, gen ai',
#  532: 'kotlin, react native, ios, dart, flutter',
#  533: 'etl, powerbi, sql, excel, snowflake, kafka',
#  534: 'docker, ansible, ci/cd',
#  535: 'firebase, dart, flutter, android, react native, swift',
#  536: 'mlops, nlp, agentic ai, computer vision, pytorch',
#  537: 'nlp, mlops, tensorflow',
#  538: 'ui/ux design, adobe xd, canva, graphic design, illustrator, figma',
#  539: 'jenkins, ci/cd, docker, terraform, ansible',
#  540: 'sql, hadoop, powerbi, excel, etl, snowflake',
#  541: 'accounting, business analysis, financial modeling',
#  542: 'flutter, kotlin, ios, android, swift',
#  543: 'kotlin, firebase, dart, android, react native, ios',
#  544: 'ui/ux design, canva, illustrator',
#  545: 'excel, etl, sql',
#  546: 'content writing, digital marketing, hubspot',
#  547: 'photoshop, graphic design, canva, interaction design, illustrator, adobe xd',
#  548: 'social media strategy, content writing, seo, mailchimp, digital marketing',
#  549: 'nlp, computer vision, scikit-learn, gen ai, agentic ai, machine learning',
#  550: 'gcp, jenkins, infrastructure as code',
#  551: 'content writing, market research, seo, digital marketing, social media strategy',
#  552: 'kubernetes, ansible, jenkins, docker, gcp, infrastructure as code',
#  553: 'sql, flask, express, vue, postgresql, angular',
#  554: 'swift, dart, kotlin',
#  555: 'angular, postgresql, nodejs, javascript, express',
#  556: 'powerbi, hadoop, spark, etl, tableau, excel',
#  557: 'hubspot, google analytics, market research, mailchimp, seo, digital marketing',
#  558: 'photoshop, figma, interaction design, adobe xd',
#  559: 'figma, adobe xd, graphic design',
#  560: 'spark, hadoop, snowflake',
#  561: 'azure, ci/cd, infrastructure as code, docker, jenkins',
#  562: 'sql, etl, kafka, spark',
#  563: 'financial modeling, business analysis, tally, risk analysis, accounting, ms excel',
#  564: 'android, kotlin, react native, ios, flutter',
#  565: 'express, vue, css',
#  566: 'django, html, express',
#  567: 'kubernetes, gcp, terraform, jenkins',
#  568: 'ios, swift, android',
#  569: 'spring, javascript, react, css, next.js, express',
#  570: 'sql, etl, excel',
#  571: 'spark, powerbi, etl, airflow, tableau',
#  572: 'angular, react, vue, javascript, next.js',
#  573: 'mailchimp, google analytics, hubspot, seo',
#  574: 'tableau, snowflake, kafka',
#  575: 'mlops, agentic ai, data science, tensorflow',
#  576: 'business analysis, risk analysis, tally, ms excel, quickbooks',
#  577: 'tableau, powerbi, spark, snowflake, excel',
#  578: 'figma, interaction design, graphic design, canva, adobe xd',
#  579: 'django, spring, nodejs, express, next.js, mongodb',
#  580: 'canva, graphic design, adobe xd, photoshop, illustrator, ui/ux design',
#  581: 'photoshop, canva, adobe xd, graphic design',
#  582: 'css, express, javascript, nodejs, sql, next.js',
#  583: 'excel, kafka, snowflake, etl, airflow, sql',
#  584: 'quickbooks, ms excel, accounting',
#  585: 'nodejs, html, vue, flask',
#  586: 'etl, spark, excel, kafka, tableau',
#  587: 'accounting, tally, financial modeling',
#  588: 'canva, illustrator, figma',
#  589: 'quickbooks, risk analysis, tally, accounting, financial modeling',
#  590: 'financial modeling, ms excel, tally',
#  591: 'excel, etl, kafka, tableau, powerbi, spark',
#  592: 'flask, sql, spring, react, css, javascript',
#  593: 'swift, kotlin, firebase',
#  594: 'tensorflow, scikit-learn, agentic ai, data science',
#  595: 'ci/cd, infrastructure as code, ansible, aws',
#  596: 'digital marketing, hubspot, google analytics, mailchimp',
#  597: 'digital marketing, seo, mailchimp',
#  598: 'accounting, financial modeling, ms excel',
#  599: 'figma, graphic design, canva',
#  600: 'javascript, spring, react, sql',
#  601: 'gen ai, pytorch, machine learning, data science',
#  602: 'flask, spring, express, javascript, css, html',
#  603: 'javascript, express, mongodb',
#  604: 'market research, social media strategy, digital marketing, content writing',
#  605: 'digital marketing, google analytics, seo, market research, mailchimp, social media strategy',
#  606: 'airflow, snowflake, powerbi',
#  607: 'sql, hadoop, excel',
#  608: 'postgresql, sql, javascript, vue, react',
#  609: 'quickbooks, accounting, risk analysis',
#  610: 'graphic design, ui/ux design, photoshop, canva',
#  611: 'flask, nodejs, next.js, express, html, django',
#  612: 'accounting, ms excel, business analysis, risk analysis, financial modeling, quickbooks',
#  613: 'figma, canva, interaction design, ui/ux design',
#  614: 'nodejs, spring, postgresql, flask, html',
#  615: 'machine learning, deep learning, scikit-learn, data science',
#  616: 'business analysis, risk analysis, quickbooks',
#  617: 'javascript, angular, vue, mongodb, next.js, flask',
#  618: 'hadoop, excel, powerbi, airflow, kafka',
#  619: 'graphic design, canva, interaction design, figma',
#  620: 'dart, react native, ios, firebase, flutter, swift',
#  621: 'vue, html, css',
#  622: 'sql, react, html, flask',
#  623: 'interaction design, adobe xd, graphic design, ui/ux design, photoshop, illustrator',
#  624: 'business analysis, tally, quickbooks, financial modeling, accounting',
#  625: 'ansible, ci/cd, azure, terraform',
#  626: 'photoshop, canva, illustrator, adobe xd, graphic design',
#  627: 'flutter, swift, ios',
#  628: 'digital marketing, hubspot, google analytics, social media strategy, content writing, seo',
#  629: 'tally, business analysis, quickbooks, financial modeling, ms excel, accounting',
#  630: 'market research, hubspot, google analytics, seo',
#  631: 'django, css, javascript, flask, spring',
#  632: 'accounting, ms excel, business analysis, financial modeling',
#  633: 'html, react, express, mongodb, django',
#  634: 'photoshop, ui/ux design, figma',
#  635: 'risk analysis, quickbooks, accounting, tally',
#  636: 'spark, kafka, airflow',
#  637: 'next.js, nodejs, spring',
#  638: 'airflow, etl, snowflake, hadoop',
#  639: 'jenkins, azure, gcp',
#  640: 'financial modeling, ms excel, tally, business analysis, risk analysis, quickbooks',
#  641: 'mlops, data science, scikit-learn, pytorch, gen ai, nlp',
#  642: 'scikit-learn, gen ai, deep learning, data science',
#  643: 'react native, android, firebase, swift, ios, flutter',
#  644: 'canva, figma, illustrator, adobe xd, photoshop, ui/ux design',
#  645: 'quickbooks, business analysis, financial modeling, tally',
#  646: 'graphic design, adobe xd, photoshop',
#  647: 'html, nodejs, spring, postgresql, javascript, django',
#  648: 'figma, photoshop, adobe xd, illustrator',
#  649: 'risk analysis, tally, ms excel, financial modeling, accounting, quickbooks',
#  650: 'snowflake, excel, spark, etl, tableau',
#  651: 'angular, flask, html, postgresql, nodejs, react',
#  652: 'swift, android, firebase, ios, react native',
#  653: 'android, dart, react native, kotlin, flutter',
#  654: 'django, express, next.js, flask',
#  655: 'spark, kafka, powerbi',
#  656: 'react, vue, sql, angular, mongodb, next.js',
#  657: 'dart, swift, ios, android, firebase, flutter',
#  658: 'express, next.js, css, mongodb, django, html',
#  659: 'etl, spark, hadoop, excel',
#  660: 'mlops, gen ai, data science, scikit-learn, agentic ai',
#  661: 'adobe xd, interaction design, photoshop, graphic design, illustrator, figma',
#  662: 'jenkins, infrastructure as code, terraform, kubernetes',
#  663: 'vue, angular, flask',
#  664: 'etl, airflow, spark, excel, powerbi, tableau',
#  665: 'figma, interaction design, ui/ux design, photoshop',
#  666: 'ios, firebase, dart, flutter, swift',
#  667: 'kafka, sql, airflow, powerbi, snowflake, spark',
#  668: 'kafka, hadoop, airflow, excel, snowflake, spark',
#  669: 'machine learning, deep learning, data science, pytorch, nlp',
#  670: 'kotlin, ios, react native, flutter',
#  671: 'illustrator, canva, ui/ux design, graphic design, photoshop',
#  672: 'express, react, css, angular, nodejs, next.js',
#  673: 'tensorflow, machine learning, computer vision, data science, agentic ai',
#  674: 'airflow, snowflake, sql',
#  675: 'agentic ai, mlops, computer vision, pytorch, gen ai, machine learning',
#  676: 'risk analysis, ms excel, quickbooks, tally, business analysis, financial modeling',
#  677: 'interaction design, ui/ux design, graphic design, illustrator',
#  678: 'content writing, social media strategy, hubspot, market research, digital marketing',
#  679: 'infrastructure as code, kubernetes, gcp, docker, terraform',
#  680: 'html, vue, react, django, sql, nodejs',
#  681: 'gen ai, computer vision, data science',
#  682: 'ansible, jenkins, azure, infrastructure as code, kubernetes',
#  683: 'quickbooks, accounting, financial modeling, ms excel',
#  684: 'digital marketing, seo, hubspot, market research, mailchimp',
#  685: 'swift, kotlin, dart, ios, firebase',
#  686: 'docker, terraform, aws, ci/cd',
#  687: 'adobe xd, canva, graphic design, photoshop, ui/ux design, illustrator',
#  688: 'html, sql, flask',
#  689: 'deep learning, machine learning, gen ai, tensorflow',
#  690: 'express, react, mongodb, django, postgresql',
#  691: 'snowflake, etl, tableau, excel',
#  692: 'angular, javascript, mongodb',
#  693: 'azure, ci/cd, ansible',
#  694: 'powerbi, kafka, excel, airflow, spark, snowflake',
#  695: 'aws, infrastructure as code, ansible, kubernetes, terraform',
#  696: 'graphic design, ui/ux design, illustrator',
#  697: 'kafka, excel, snowflake, tableau, airflow',
#  698: 'figma, illustrator, ui/ux design, interaction design, graphic design',
#  699: 'seo, mailchimp, digital marketing, hubspot',
#  700: 'tableau, airflow, kafka, etl, excel, spark',
#  701: 'mailchimp, content writing, hubspot, seo, social media strategy, google analytics',
#  702: 'kotlin, ios, flutter',
#  703: 'docker, gcp, ci/cd, azure, terraform',
#  704: 'social media strategy, market research, hubspot, seo',
#  705: 'business analysis, risk analysis, quickbooks',
#  706: 'figma, photoshop, ui/ux design',
#  707: 'tensorflow, deep learning, pytorch, nlp, scikit-learn',
#  708: 'graphic design, interaction design, figma, adobe xd, canva, ui/ux design',
#  709: 'snowflake, excel, powerbi, hadoop',
#  710: 'mlops, scikit-learn, pytorch, nlp, agentic ai, data science',
#  711: 'illustrator, canva, figma, graphic design, ui/ux design',
#  712: 'sql, spark, powerbi, tableau, snowflake',
#  713: 'pytorch, mlops, nlp, gen ai, data science, agentic ai',
#  714: 'data science, mlops, scikit-learn, gen ai',
#  715: 'tensorflow, computer vision, agentic ai, deep learning, scikit-learn',
#  716: 'aws, azure, gcp, docker, ansible',
#  717: 'photoshop, graphic design, figma, adobe xd, ui/ux design',
#  718: 'swift, flutter, firebase, react native, kotlin',
#  719: 'deep learning, tensorflow, agentic ai, scikit-learn, data science',
#  720: 'android, swift, react native, flutter',
#  721: 'sql, excel, kafka, airflow',
#  722: 'graphic design, interaction design, adobe xd, canva, ui/ux design',
#  723: 'flask, html, django, postgresql',
#  724: 'graphic design, interaction design, photoshop',
#  725: 'kubernetes, infrastructure as code, docker, ansible',
#  726: 'accounting, financial modeling, ms excel',
#  727: 'quickbooks, risk analysis, tally, business analysis, financial modeling',
#  728: 'agentic ai, pytorch, scikit-learn',
#  729: 'aws, jenkins, gcp, terraform',
#  730: 'quickbooks, tally, risk analysis, financial modeling',
#  731: 'mlops, pytorch, scikit-learn, machine learning, computer vision, tensorflow',
#  732: 'terraform, infrastructure as code, azure',
#  733: 'infrastructure as code, terraform, ansible',
#  734: 'django, sql, react, vue, flask, css',
#  735: 'dart, ios, swift, android',
#  736: 'ansible, kubernetes, aws, infrastructure as code',
#  737: 'agentic ai, deep learning, computer vision, data science, tensorflow, gen ai',
#  738: 'vue, mongodb, postgresql, nodejs, angular',
#  739: 'flutter, react native, kotlin, firebase, ios',
#  740: 'tensorflow, agentic ai, computer vision',
#  741: 'seo, google analytics, social media strategy, market research, mailchimp',
#  742: 'terraform, infrastructure as code, jenkins, gcp',
#  743: 'kafka, spark, snowflake, excel',
#  744: 'sql, snowflake, kafka',
#  745: 'ios, android, swift',
#  746: 'adobe xd, figma, ui/ux design',
#  747: 'canva, interaction design, figma, adobe xd',
#  748: 'seo, market research, content writing',
#  749: 'docker, terraform, ci/cd, infrastructure as code, aws',
#  750: 'financial modeling, quickbooks, tally, risk analysis',
#  751: 'terraform, aws, gcp',
#  752: 'jenkins, docker, azure, infrastructure as code, terraform, ci/cd',
#  753: 'react native, swift, firebase',
#  754: 'ms excel, accounting, tally',
#  755: 'tally, financial modeling, quickbooks, risk analysis, business analysis, ms excel',
#  756: 'figma, illustrator, canva, interaction design, graphic design',
#  757: 'kubernetes, infrastructure as code, docker, ci/cd, ansible, gcp',
#  758: 'mailchimp, market research, digital marketing, social media strategy',
#  759: 'kotlin, swift, android',
#  760: 'photoshop, canva, graphic design, adobe xd',
#  761: 'market research, content writing, seo, google analytics, mailchimp',
#  762: 'tensorflow, nlp, mlops, deep learning, pytorch, machine learning',
#  763: 'firebase, ios, swift, android, react native',
#  764: 'dart, firebase, react native, kotlin, swift',
#  765: 'deep learning, agentic ai, pytorch, data science, scikit-learn, nlp',
#  766: 'airflow, powerbi, etl',
#  767: 'photoshop, figma, interaction design, canva, graphic design, ui/ux design',
#  768: 'agentic ai, data science, gen ai, tensorflow',
#  769: 'ios, android, react native, flutter, firebase, swift',
#  770: 'mlops, pytorch, computer vision, nlp, gen ai, agentic ai',
#  771: 'ci/cd, azure, kubernetes, jenkins',
#  772: 'graphic design, figma, adobe xd',
#  773: 'flutter, swift, dart, android, react native',
#  774: 'dart, swift, react native, kotlin',
#  775: 'ios, android, flutter, kotlin, react native, dart',
#  776: 'spark, sql, etl, airflow, excel',
#  777: 'business analysis, accounting, tally, risk analysis, quickbooks',
#  778: 'computer vision, nlp, data science, machine learning, deep learning',
#  779: 'vue, next.js, flask, django, angular',
#  780: 'firebase, flutter, react native, android, dart, kotlin',
#  781: 'market research, seo, hubspot, digital marketing, google analytics',
#  782: 'risk analysis, quickbooks, tally, business analysis, financial modeling, accounting',
#  783: 'scikit-learn, tensorflow, pytorch',
#  784: 'flutter, react native, kotlin, ios, swift',
#  785: 'django, javascript, html, angular',
#  786: 'photoshop, canva, interaction design',
#  787: 'nlp, scikit-learn, mlops, agentic ai, computer vision',
#  788: 'data science, agentic ai, nlp, mlops, pytorch',
#  789: 'sql, nodejs, angular, css, spring, express',
#  790: 'firebase, swift, ios',
#  791: 'airflow, hadoop, sql, tableau, kafka, powerbi',
#  792: 'next.js, postgresql, nodejs, sql',
#  793: 'illustrator, ui/ux design, figma',
#  794: 'ms excel, financial modeling, tally, business analysis, quickbooks, accounting',
#  795: 'swift, ios, firebase, android, flutter',
#  796: 'next.js, angular, nodejs, sql, css',
#  797: 'react native, kotlin, android, firebase, dart, flutter',
#  798: 'react, css, spring, express',
#  799: 'snowflake, airflow, powerbi, tableau, spark',
#  800: 'excel, tableau, spark, airflow, etl, snowflake',
#  801: 'photoshop, ui/ux design, canva, figma',
#  802: 'scikit-learn, data science, nlp',
#  803: 'flutter, firebase, dart, ios, react native',
#  804: 'ms excel, financial modeling, risk analysis, tally, business analysis, quickbooks',
#  805: 'ui/ux design, canva, figma, photoshop, interaction design',
#  806: 'google analytics, market research, hubspot, mailchimp',
#  807: 'tableau, kafka, powerbi, airflow',
#  808: 'google analytics, mailchimp, seo',
#  809: 'machine learning, gen ai, deep learning, agentic ai, computer vision',
#  810: 'scikit-learn, tensorflow, pytorch, nlp',
#  811: 'google analytics, content writing, social media strategy, mailchimp, seo, hubspot',
#  812: 'jenkins, ci/cd, ansible, docker',
#  813: 'content writing, seo, hubspot, social media strategy',
#  814: 'ios, android, firebase',
#  815: 'snowflake, tableau, excel',
#  816: 'flask, javascript, react, nodejs, spring',
#  817: 'aws, azure, ansible, gcp, terraform',
#  818: 'css, angular, html, sql',
#  819: 'ui/ux design, photoshop, interaction design, figma, canva',
#  820: 'quickbooks, tally, financial modeling, business analysis, ms excel, accounting',
#  821: 'digital marketing, seo, hubspot',
#  822: 'interaction design, canva, photoshop',
#  823: 'firebase, ios, kotlin, android, react native',
#  824: 'kubernetes, terraform, jenkins, aws, ansible',
#  825: 'hubspot, digital marketing, market research, seo, google analytics',
#  826: 'tableau, hadoop, kafka, snowflake, sql',
#  827: 'ms excel, business analysis, risk analysis',
#  828: 'airflow, sql, tableau, kafka',
#  829: 'financial modeling, accounting, risk analysis, ms excel',
#  830: 'azure, gcp, aws, docker, kubernetes',
#  831: 'firebase, android, react native, kotlin, ios, flutter',
#  832: 'mongodb, django, spring, next.js',
#  833: 'accounting, ms excel, business analysis',
#  834: 'aws, ci/cd, azure, gcp, infrastructure as code',
#  835: 'mailchimp, content writing, google analytics, market research, seo',
#  836: 'tally, financial modeling, risk analysis, business analysis',
#  837: 'css, spring, django, sql, javascript, postgresql',
#  838: 'airflow, tableau, kafka, etl',
#  839: 'jenkins, ci/cd, docker, ansible',
#  840: 'ui/ux design, graphic design, adobe xd',
#  841: 'airflow, sql, excel',
#  842: 'photoshop, ui/ux design, interaction design, adobe xd, canva, graphic design',
#  843: 'financial modeling, tally, ms excel',
#  844: 'vue, spring, mongodb',
#  845: 'postgresql, react, django, html, express, spring',
#  846: 'nlp, deep learning, pytorch',
#  847: 'ui/ux design, graphic design, figma, interaction design, photoshop, canva',
#  848: 'dart, android, kotlin, swift, react native, flutter',
#  849: 'market research, hubspot, content writing, digital marketing',
#  850: 'pytorch, scikit-learn, data science, machine learning, gen ai',
#  851: 'nodejs, sql, flask, postgresql, angular, css',
#  852: 'illustrator, ui/ux design, graphic design',
#  853: 'aws, docker, infrastructure as code, azure, terraform, kubernetes',
#  854: 'flutter, swift, dart',
#  855: 'interaction design, photoshop, adobe xd, illustrator',
#  856: 'seo, content writing, mailchimp, digital marketing, hubspot, google analytics',
#  857: 'swift, flutter, android',
#  858: 'ui/ux design, adobe xd, photoshop, graphic design, figma',
#  859: 'javascript, nodejs, postgresql, django',
#  860: 'dart, android, flutter, ios, react native, firebase',
#  861: 'seo, mailchimp, hubspot, market research, digital marketing, social media strategy',
#  862: 'react native, dart, android, ios, flutter, firebase',
#  863: 'infrastructure as code, gcp, azure, ansible, ci/cd',
#  864: 'nodejs, javascript, react',
#  865: 'express, next.js, postgresql',
#  866: 'mongodb, vue, spring, css',
#  867: 'snowflake, sql, airflow, etl, excel, hadoop',
#  868: 'mlops, agentic ai, scikit-learn, computer vision, machine learning, nlp',
#  869: 'nlp, tensorflow, computer vision, deep learning',
#  870: 'financial modeling, accounting, ms excel, quickbooks, risk analysis',
#  871: 'react native, flutter, android, ios, kotlin',
#  872: 'tensorflow, gen ai, nlp, machine learning',
#  873: 'kotlin, dart, swift, firebase, android',
#  874: 'photoshop, interaction design, ui/ux design, graphic design, illustrator, figma',
#  875: 'mailchimp, social media strategy, content writing, hubspot, market research, seo',
#  876: 'etl, snowflake, sql',
#  877: 'google analytics, content writing, seo',
#  878: 'accounting, business analysis, risk analysis, ms excel, quickbooks',
#  879: 'adobe xd, interaction design, figma, illustrator, photoshop',
#  880: 'scikit-learn, deep learning, pytorch, agentic ai',
#  881: 'illustrator, graphic design, ui/ux design, figma, adobe xd, canva',
#  882: 'tensorflow, scikit-learn, data science, machine learning, deep learning, pytorch',
#  883: 'tableau, hadoop, excel, kafka, snowflake, etl',
#  884: 'quickbooks, risk analysis, financial modeling, accounting, business analysis',
#  885: 'data science, mlops, deep learning, tensorflow, scikit-learn',
#  886: 'business analysis, accounting, ms excel, quickbooks, risk analysis',
#  887: 'ms excel, financial modeling, accounting',
#  888: 'hubspot, mailchimp, market research, content writing',
#  889: 'digital marketing, content writing, hubspot, google analytics, market research, seo',
#  890: 'django, postgresql, angular',
#  891: 'spring, django, angular, html, sql',
#  892: 'seo, hubspot, google analytics, digital marketing, mailchimp, content writing',
#  893: 'computer vision, tensorflow, mlops',
#  894: 'hadoop, airflow, powerbi, spark, snowflake, kafka',
#  895: 'pytorch, agentic ai, gen ai, data science',
#  896: 'machine learning, pytorch, agentic ai',
#  897: 'dart, react native, ios, firebase',
#  898: 'css, spring, flask, sql',
#  899: 'quickbooks, financial modeling, ms excel, accounting',
#  900: 'vue, react, flask, express',
#  901: 'html, postgresql, nodejs',
#  902: 'google analytics, seo, digital marketing',
#  903: 'data science, mlops, gen ai, computer vision, machine learning',
#  904: 'react native, dart, swift, ios',
#  905: 'ci/cd, gcp, azure, infrastructure as code, aws, terraform',
#  906: 'terraform, gcp, ansible, kubernetes',
#  907: 'terraform, kubernetes, ci/cd, docker, aws',
#  908: 'data science, computer vision, gen ai, agentic ai, pytorch',
#  909: 'angular, nodejs, css, react',
#  910: 'kotlin, firebase, flutter',
#  911: 'spring, javascript, nodejs, react',
#  912: 'spring, css, postgresql, react',
#  913: 'seo, market research, google analytics, hubspot, mailchimp, content writing',
#  914: 'javascript, nodejs, react, postgresql, django',
#  915: 'swift, dart, react native, kotlin, firebase, ios',
#  916: 'google analytics, social media strategy, mailchimp, digital marketing, hubspot, market research',
#  917: 'gcp, kubernetes, infrastructure as code, docker',
#  918: 'mailchimp, market research, google analytics, content writing, seo',
#  919: 'excel, etl, powerbi, spark',
#  920: 'gcp, infrastructure as code, jenkins, docker',
#  921: 'hadoop, kafka, tableau, powerbi',
#  922: 'ansible, gcp, ci/cd, infrastructure as code, azure',
#  923: 'aws, jenkins, infrastructure as code, ci/cd',
#  924: 'mongodb, flask, vue, nodejs',
#  925: 'terraform, ansible, docker, azure, ci/cd, gcp',
#  926: 'digital marketing, social media strategy, content writing, seo',
#  927: 'android, dart, flutter, kotlin',
#  928: 'terraform, gcp, aws, ansible, ci/cd, infrastructure as code',
#  929: 'tensorflow, pytorch, mlops, agentic ai',
#  930: 'flutter, react native, swift, ios',
#  931: 'swift, kotlin, flutter, react native, ios, dart',
#  932: 'photoshop, canva, illustrator',
#  933: 'tally, ms excel, accounting, financial modeling',
#  934: 'google analytics, content writing, mailchimp',
#  935: 'ui/ux design, interaction design, illustrator, adobe xd',
#  936: 'machine learning, gen ai, agentic ai, mlops, pytorch, nlp',
#  937: 'content writing, market research, google analytics, digital marketing, hubspot',
#  938: 'firebase, kotlin, flutter, react native, dart',
#  939: 'android, kotlin, ios, react native, dart',
#  940: 'graphic design, photoshop, canva, ui/ux design',
#  941: 'django, next.js, javascript, css, angular',
#  942: 'dart, ios, swift, firebase',
#  943: 'social media strategy, hubspot, mailchimp, market research, content writing',
#  944: 'data science, agentic ai, nlp, pytorch, machine learning, deep learning',
#  945: 'scikit-learn, mlops, pytorch, computer vision, deep learning',
#  946: 'seo, mailchimp, social media strategy, google analytics',
#  947: 'tableau, kafka, airflow',
#  948: 'data science, nlp, tensorflow',
#  949: 'next.js, sql, html, react, javascript, nodejs',
#  950: 'scikit-learn, computer vision, data science, mlops',
#  951: 'figma, interaction design, ui/ux design, adobe xd, graphic design, canva',
#  952: 'swift, kotlin, ios',
#  953: 'flutter, swift, dart, kotlin, react native, ios',
#  954: 'illustrator, adobe xd, ui/ux design, figma, interaction design',
#  955: 'ms excel, accounting, financial modeling, quickbooks, risk analysis',
#  956: 'social media strategy, market research, google analytics, hubspot, mailchimp, content writing',
#  957: 'firebase, swift, kotlin, dart',
#  958: 'spark, airflow, excel, etl',
#  959: 'terraform, jenkins, docker, aws, gcp',
#  960: 'ansible, kubernetes, azure, terraform, docker, ci/cd',
#  961: 'content writing, mailchimp, digital marketing, seo',
#  962: 'computer vision, agentic ai, pytorch',
#  963: 'photoshop, interaction design, adobe xd',
#  964: 'agentic ai, computer vision, nlp',
#  965: 'firebase, ios, swift',
#  966: 'hadoop, airflow, snowflake, excel',
#  967: 'business analysis, financial modeling, accounting',
#  968: 'seo, social media strategy, market research, mailchimp',
#  969: 'spark, excel, hadoop, kafka',
#  970: 'adobe xd, illustrator, graphic design',
#  971: 'google analytics, market research, seo, digital marketing',
#  972: 'market research, mailchimp, content writing, google analytics, digital marketing',
#  973: 'django, spring, express, css, nodejs',
#  974: 'adobe xd, photoshop, graphic design, interaction design',
#  975: 'angular, sql, vue',
#  976: 'mlops, gen ai, tensorflow, pytorch',
#  977: 'ansible, azure, ci/cd, aws, infrastructure as code',
#  978: 'ui/ux design, interaction design, illustrator, canva, photoshop, figma',
#  979: 'nlp, data science, agentic ai, gen ai',
#  980: 'illustrator, interaction design, graphic design, figma, adobe xd',
#  981: 'jenkins, ci/cd, azure',
#  982: 'quickbooks, risk analysis, accounting, financial modeling',
#  983: 'mlops, machine learning, computer vision',
#  984: 'computer vision, nlp, tensorflow, deep learning, scikit-learn',
#  985: 'kotlin, dart, flutter, react native',
#  986: 'computer vision, scikit-learn, mlops',
#  987: 'tableau, snowflake, etl',
#  988: 'swift, flutter, android, react native',
#  989: 'vue, postgresql, mongodb, express, angular, sql',
#  990: 'sql, excel, powerbi',
#  991: 'ci/cd, infrastructure as code, docker, terraform, gcp',
#  992: 'django, sql, mongodb, css, nodejs',
#  993: 'hubspot, seo, content writing, google analytics, digital marketing',
#  994: 'infrastructure as code, ci/cd, kubernetes',
#  995: 'kubernetes, infrastructure as code, terraform, ci/cd',
#  996: 'canva, interaction design, graphic design, ui/ux design, figma, photoshop',
#  997: 'google analytics, market research, digital marketing, mailchimp',
#  998: 'canva, ui/ux design, illustrator',
#  999: 'kafka, etl, snowflake, powerbi',
#  1000: 'graphic design, canva, illustrator'}

# %%
import re

def clean_skills(skills):
    skills = re.sub(r'[^a-zA-Z0-9, ]', '', skills)
    skills = re.sub(r'\s+', ' ', skills)
    skills = skills.strip()
    return skills

# %%
for sid, skills in stu_skills.items():
    stu_skills[sid] = clean_skills(skills).split(', ')
for iid, reqs in int_reqs.items():
    int_reqs[iid] = [clean_skills(req) for req in reqs.split(', ')]

# %%
stu_skills
# Out:
# {1: ['machine learning', 'data science', 'agentic ai'],
#  2: ['dart', 'firebase', 'swift', 'flutter'],
#  3: ['digital marketing', 'content writing', 'mailchimp', 'hubspot'],
#  4: ['financial modeling',
#   'ms excel',
#   'tally',
#   'business analysis',
#   'quickbooks',
#   'accounting'],
#  5: ['ios', 'firebase', 'kotlin'],
#  6: ['canva',
#   'adobe xd',
#   'figma',
#   'interaction design',
#   'uiux design',
#   'illustrator'],
#  7: ['gen ai',
#   'agentic ai',
#   'deep learning',
#   'data science',
#   'machine learning'],
#  8: ['figma', 'uiux design', 'photoshop', 'adobe xd'],
#  9: ['sql', 'postgresql', 'flask'],
#  10: ['tally', 'business analysis', 'accounting', 'financial modeling'],
#  11: ['digital marketing',
#   'hubspot',
#   'seo',
#   'content writing',
#   'market research',
#   'social media strategy'],
#  12: ['kafka', 'hadoop', 'snowflake', 'spark', 'tableau', 'sql'],
#  13: ['airflow', 'tableau', 'powerbi', 'hadoop'],
#  14: ['adobe xd', 'illustrator', 'uiux design', 'canva', 'figma', 'photoshop'],
#  15: ['css', 'angular', 'html', 'react'],
#  16: ['canva', 'graphic design', 'figma', 'photoshop'],
#  17: ['swift', 'react native', 'firebase', 'android'],
#  18: ['financial modeling', 'accounting', 'risk analysis', 'ms excel'],
#  19: ['react native', 'flutter', 'android', 'ios'],
#  20: ['quickbooks', 'business analysis', 'accounting'],
#  21: ['google analytics', 'seo', 'mailchimp', 'digital marketing'],
#  22: ['pytorch', 'tensorflow', 'agentic ai'],
#  23: ['jenkins', 'cicd', 'infrastructure as code', 'aws', 'terraform'],
#  24: ['excel', 'spark', 'hadoop', 'tableau', 'sql'],
#  25: ['kubernetes', 'aws', 'azure', 'cicd', 'ansible'],
#  26: ['seo',
#   'google analytics',
#   'digital marketing',
#   'hubspot',
#   'content writing',
#   'mailchimp'],
#  27: ['gen ai', 'mlops', 'pytorch', 'machine learning'],
#  28: ['gen ai', 'mlops', 'agentic ai', 'data science'],
#  29: ['photoshop', 'graphic design', 'adobe xd', 'uiux design'],
#  30: ['deep learning', 'nlp', 'gen ai', 'machine learning', 'agentic ai'],
#  31: ['mailchimp',
#   'hubspot',
#   'seo',
#   'content writing',
#   'market research',
#   'social media strategy'],
#  32: ['graphic design',
#   'photoshop',
#   'adobe xd',
#   'illustrator',
#   'interaction design',
#   'uiux design'],
#  33: ['business analysis', 'tally', 'financial modeling'],
#  34: ['firebase', 'dart', 'android'],
#  35: ['adobe xd',
#   'uiux design',
#   'graphic design',
#   'figma',
#   'canva',
#   'interaction design'],
#  36: ['mailchimp', 'content writing', 'google analytics'],
#  37: ['azure', 'terraform', 'cicd'],
#  38: ['ios', 'react native', 'dart', 'kotlin'],
#  39: ['flask', 'spring', 'mongodb', 'sql', 'django', 'react'],
#  40: ['illustrator',
#   'graphic design',
#   'photoshop',
#   'canva',
#   'figma',
#   'uiux design'],
#  41: ['agentic ai',
#   'computer vision',
#   'scikitlearn',
#   'pytorch',
#   'tensorflow',
#   'nlp'],
#  42: ['angular', 'javascript', 'express'],
#  43: ['kubernetes', 'gcp', 'terraform', 'aws'],
#  44: ['accounting',
#   'risk analysis',
#   'ms excel',
#   'quickbooks',
#   'tally',
#   'business analysis'],
#  45: ['financial modeling', 'ms excel', 'risk analysis', 'quickbooks'],
#  46: ['dart', 'android', 'ios', 'firebase'],
#  47: ['figma', 'uiux design', 'interaction design', 'photoshop', 'adobe xd'],
#  48: ['flutter', 'android', 'kotlin', 'dart'],
#  49: ['market research', 'digital marketing', 'social media strategy'],
#  50: ['sql', 'airflow', 'snowflake', 'kafka'],
#  51: ['social media strategy',
#   'content writing',
#   'mailchimp',
#   'hubspot',
#   'market research'],
#  52: ['gen ai', 'deep learning', 'data science', 'machine learning'],
#  53: ['computer vision', 'tensorflow', 'pytorch', 'nlp'],
#  54: ['html', 'sql', 'postgresql', 'css', 'flask'],
#  55: ['spring', 'vue', 'sql', 'nextjs', 'express', 'postgresql'],
#  56: ['content writing',
#   'market research',
#   'google analytics',
#   'mailchimp',
#   'social media strategy'],
#  57: ['hubspot', 'seo', 'social media strategy', 'google analytics'],
#  58: ['ansible', 'cicd', 'jenkins'],
#  59: ['nodejs', 'css', 'postgresql', 'flask', 'angular', 'vue'],
#  60: ['hubspot', 'seo', 'content writing'],
#  61: ['quickbooks',
#   'accounting',
#   'tally',
#   'risk analysis',
#   'business analysis'],
#  62: ['aws', 'ansible', 'jenkins', 'azure'],
#  63: ['scikitlearn',
#   'data science',
#   'deep learning',
#   'computer vision',
#   'agentic ai',
#   'machine learning'],
#  64: ['gcp', 'kubernetes', 'aws', 'terraform', 'jenkins'],
#  65: ['snowflake', 'kafka', 'excel', 'etl'],
#  66: ['kubernetes', 'infrastructure as code', 'docker'],
#  67: ['graphic design',
#   'illustrator',
#   'photoshop',
#   'uiux design',
#   'canva',
#   'adobe xd'],
#  68: ['sql', 'kafka', 'tableau', 'snowflake', 'excel', 'airflow'],
#  69: ['nlp', 'data science', 'mlops'],
#  70: ['hadoop', 'spark', 'snowflake'],
#  71: ['react native', 'android', 'swift', 'ios', 'flutter'],
#  72: ['accounting', 'risk analysis', 'business analysis'],
#  73: ['financial modeling', 'accounting', 'tally', 'risk analysis'],
#  74: ['pytorch', 'computer vision', 'machine learning'],
#  75: ['angular', 'css', 'html'],
#  76: ['market research', 'digital marketing', 'social media strategy'],
#  77: ['swift', 'kotlin', 'react native', 'firebase', 'android', 'dart'],
#  78: ['gen ai', 'deep learning', 'tensorflow', 'machine learning'],
#  79: ['computer vision', 'nlp', 'pytorch', 'scikitlearn', 'agentic ai'],
#  80: ['computer vision',
#   'deep learning',
#   'data science',
#   'machine learning',
#   'scikitlearn',
#   'gen ai'],
#  81: ['docker', 'jenkins', 'terraform', 'gcp', 'aws', 'ansible'],
#  82: ['snowflake', 'airflow', 'sql', 'tableau', 'excel', 'kafka'],
#  83: ['figma', 'illustrator', 'uiux design', 'photoshop'],
#  84: ['sql', 'excel', 'hadoop'],
#  85: ['firebase', 'kotlin', 'swift', 'flutter'],
#  86: ['uiux design',
#   'photoshop',
#   'illustrator',
#   'interaction design',
#   'canva',
#   'adobe xd'],
#  87: ['figma', 'canva', 'adobe xd'],
#  88: ['aws', 'jenkins', 'terraform', 'gcp', 'docker', 'ansible'],
#  89: ['azure', 'infrastructure as code', 'jenkins', 'terraform'],
#  90: ['kubernetes', 'jenkins', 'cicd', 'aws'],
#  91: ['html', 'nodejs', 'angular', 'flask', 'sql', 'mongodb'],
#  92: ['social media strategy',
#   'content writing',
#   'google analytics',
#   'digital marketing',
#   'hubspot',
#   'mailchimp'],
#  93: ['interaction design',
#   'figma',
#   'adobe xd',
#   'photoshop',
#   'graphic design',
#   'canva'],
#  94: ['spring', 'vue', 'html', 'mongodb', 'flask', 'javascript'],
#  95: ['sql', 'css', 'django'],
#  96: ['tableau', 'etl', 'kafka', 'sql', 'excel', 'airflow'],
#  97: ['docker', 'infrastructure as code', 'aws', 'jenkins'],
#  98: ['risk analysis', 'business analysis', 'ms excel'],
#  99: ['tableau', 'hadoop', 'spark'],
#  100: ['accounting',
#   'business analysis',
#   'financial modeling',
#   'quickbooks',
#   'risk analysis'],
#  101: ['gcp', 'terraform', 'ansible', 'cicd'],
#  102: ['excel', 'kafka', 'tableau'],
#  103: ['ios', 'react native', 'dart', 'swift', 'firebase'],
#  104: ['snowflake', 'kafka', 'airflow', 'tableau', 'powerbi'],
#  105: ['kafka', 'powerbi', 'etl'],
#  106: ['powerbi', 'hadoop', 'tableau', 'snowflake', 'spark'],
#  107: ['terraform',
#   'infrastructure as code',
#   'ansible',
#   'kubernetes',
#   'docker',
#   'aws'],
#  108: ['deep learning', 'agentic ai', 'computer vision', 'nlp'],
#  109: ['javascript', 'express', 'angular'],
#  110: ['social media strategy', 'market research', 'seo'],
#  111: ['firebase', 'kotlin', 'flutter', 'swift', 'android', 'dart'],
#  112: ['spark', 'hadoop', 'sql', 'airflow', 'kafka', 'powerbi'],
#  113: ['firebase', 'flutter', 'swift', 'ios'],
#  114: ['excel', 'tableau', 'powerbi'],
#  115: ['risk analysis', 'accounting', 'ms excel'],
#  116: ['quickbooks', 'ms excel', 'accounting', 'financial modeling', 'tally'],
#  117: ['flutter', 'kotlin', 'ios'],
#  118: ['photoshop', 'illustrator', 'canva'],
#  119: ['agentic ai', 'mlops', 'computer vision', 'tensorflow', 'data science'],
#  120: ['ios', 'flutter', 'firebase', 'android'],
#  121: ['airflow', 'spark', 'snowflake', 'etl'],
#  122: ['social media strategy',
#   'mailchimp',
#   'seo',
#   'market research',
#   'digital marketing'],
#  123: ['ms excel', 'quickbooks', 'accounting'],
#  124: ['react', 'nextjs', 'postgresql', 'css', 'javascript'],
#  125: ['swift', 'dart', 'ios', 'react native'],
#  126: ['tally',
#   'ms excel',
#   'financial modeling',
#   'risk analysis',
#   'business analysis',
#   'quickbooks'],
#  127: ['agentic ai', 'nlp', 'machine learning', 'tensorflow'],
#  128: ['computer vision', 'mlops', 'data science', 'pytorch'],
#  129: ['mailchimp',
#   'seo',
#   'digital marketing',
#   'hubspot',
#   'content writing',
#   'social media strategy'],
#  130: ['aws', 'ansible', 'infrastructure as code', 'gcp', 'docker', 'cicd'],
#  131: ['accounting', 'risk analysis', 'financial modeling', 'tally'],
#  132: ['dart', 'kotlin', 'react native', 'flutter'],
#  133: ['photoshop',
#   'interaction design',
#   'adobe xd',
#   'illustrator',
#   'figma',
#   'graphic design'],
#  134: ['sql', 'spring', 'nodejs', 'css', 'html', 'django'],
#  135: ['risk analysis',
#   'financial modeling',
#   'tally',
#   'accounting',
#   'business analysis'],
#  136: ['aws', 'ansible', 'terraform', 'kubernetes'],
#  137: ['mongodb', 'react', 'sql', 'nextjs', 'html', 'nodejs'],
#  138: ['dart', 'swift', 'ios'],
#  139: ['tensorflow', 'pytorch', 'gen ai', 'agentic ai'],
#  140: ['django', 'html', 'postgresql'],
#  141: ['graphic design',
#   'figma',
#   'adobe xd',
#   'canva',
#   'illustrator',
#   'interaction design'],
#  142: ['digital marketing',
#   'google analytics',
#   'market research',
#   'mailchimp'],
#  143: ['infrastructure as code', 'kubernetes', 'gcp', 'terraform', 'jenkins'],
#  144: ['google analytics', 'hubspot', 'digital marketing', 'market research'],
#  145: ['aws', 'terraform', 'docker', 'cicd'],
#  146: ['financial modeling', 'business analysis', 'quickbooks'],
#  147: ['kotlin', 'react native', 'dart'],
#  148: ['flutter', 'swift', 'dart'],
#  149: ['figma', 'interaction design', 'uiux design', 'photoshop'],
#  150: ['react', 'postgresql', 'vue'],
#  151: ['data science', 'mlops', 'pytorch', 'agentic ai'],
#  152: ['digital marketing',
#   'hubspot',
#   'google analytics',
#   'market research',
#   'content writing',
#   'mailchimp'],
#  153: ['adobe xd', 'photoshop', 'graphic design', 'canva'],
#  154: ['digital marketing', 'seo', 'mailchimp', 'social media strategy'],
#  155: ['docker', 'jenkins', 'ansible'],
#  156: ['agentic ai', 'pytorch', 'tensorflow', 'gen ai'],
#  157: ['risk analysis', 'ms excel', 'financial modeling', 'business analysis'],
#  158: ['ios', 'dart', 'react native'],
#  159: ['uiux design', 'illustrator', 'figma', 'interaction design'],
#  160: ['hadoop', 'airflow', 'tableau', 'kafka', 'snowflake'],
#  161: ['express', 'css', 'nodejs', 'spring', 'postgresql', 'nextjs'],
#  162: ['javascript', 'spring', 'css', 'mongodb'],
#  163: ['mlops', 'machine learning', 'pytorch'],
#  164: ['google analytics', 'mailchimp', 'hubspot'],
#  165: ['html', 'angular', 'postgresql', 'vue'],
#  166: ['content writing',
#   'social media strategy',
#   'mailchimp',
#   'market research'],
#  167: ['kafka', 'airflow', 'sql', 'etl', 'snowflake', 'tableau'],
#  168: ['deep learning', 'computer vision', 'pytorch', 'scikitlearn'],
#  169: ['risk analysis',
#   'ms excel',
#   'tally',
#   'accounting',
#   'business analysis'],
#  170: ['agentic ai', 'scikitlearn', 'pytorch', 'tensorflow'],
#  171: ['hadoop', 'tableau', 'sql'],
#  172: ['sql', 'powerbi', 'excel', 'kafka'],
#  173: ['kafka', 'excel', 'tableau'],
#  174: ['cicd', 'ansible', 'azure', 'kubernetes', 'gcp'],
#  175: ['firebase', 'swift', 'kotlin', 'dart'],
#  176: ['tensorflow', 'gen ai', 'pytorch', 'nlp'],
#  177: ['mlops', 'computer vision', 'pytorch', 'agentic ai', 'gen ai'],
#  178: ['mailchimp',
#   'social media strategy',
#   'content writing',
#   'digital marketing',
#   'market research'],
#  179: ['quickbooks',
#   'tally',
#   'risk analysis',
#   'ms excel',
#   'financial modeling'],
#  180: ['tensorflow', 'scikitlearn', 'mlops', 'deep learning'],
#  181: ['digital marketing', 'seo', 'content writing', 'social media strategy'],
#  182: ['hubspot', 'market research', 'google analytics'],
#  183: ['spark', 'sql', 'powerbi', 'snowflake'],
#  184: ['agentic ai', 'scikitlearn', 'mlops', 'pytorch', 'computer vision'],
#  185: ['snowflake', 'excel', 'kafka', 'hadoop', 'powerbi'],
#  186: ['sql', 'snowflake', 'excel', 'tableau'],
#  187: ['social media strategy',
#   'content writing',
#   'google analytics',
#   'mailchimp',
#   'market research',
#   'hubspot'],
#  188: ['mailchimp',
#   'social media strategy',
#   'market research',
#   'hubspot',
#   'seo'],
#  189: ['aws', 'kubernetes', 'jenkins', 'terraform', 'azure'],
#  190: ['azure', 'aws', 'kubernetes', 'docker'],
#  191: ['adobe xd', 'photoshop', 'canva'],
#  192: ['quickbooks', 'ms excel', 'risk analysis', 'tally', 'accounting'],
#  193: ['infrastructure as code',
#   'kubernetes',
#   'azure',
#   'gcp',
#   'jenkins',
#   'terraform'],
#  194: ['figma', 'graphic design', 'interaction design', 'canva'],
#  195: ['jenkins', 'infrastructure as code', 'kubernetes', 'gcp', 'aws'],
#  196: ['content writing',
#   'hubspot',
#   'market research',
#   'google analytics',
#   'mailchimp',
#   'seo'],
#  197: ['postgresql', 'nextjs', 'flask'],
#  198: ['machine learning', 'data science', 'computer vision', 'pytorch'],
#  199: ['canva', 'adobe xd', 'figma', 'interaction design', 'photoshop'],
#  200: ['django', 'spring', 'angular'],
#  201: ['ios', 'kotlin', 'dart'],
#  202: ['flutter', 'swift', 'kotlin', 'dart'],
#  203: ['azure', 'gcp', 'kubernetes', 'aws', 'cicd', 'terraform'],
#  204: ['aws', 'jenkins', 'docker', 'gcp', 'cicd', 'kubernetes'],
#  205: ['accounting',
#   'risk analysis',
#   'ms excel',
#   'business analysis',
#   'tally'],
#  206: ['terraform', 'docker', 'azure'],
#  207: ['accounting', 'tally', 'ms excel', 'quickbooks', 'risk analysis'],
#  208: ['ms excel', 'risk analysis', 'quickbooks', 'accounting', 'tally'],
#  209: ['aws', 'gcp', 'ansible'],
#  210: ['cicd', 'kubernetes', 'ansible'],
#  211: ['gen ai',
#   'data science',
#   'pytorch',
#   'scikitlearn',
#   'computer vision',
#   'agentic ai'],
#  212: ['interaction design', 'photoshop', 'adobe xd', 'illustrator', 'canva'],
#  213: ['nextjs', 'flask', 'django', 'css', 'angular'],
#  214: ['hadoop', 'spark', 'powerbi', 'sql'],
#  215: ['quickbooks',
#   'financial modeling',
#   'risk analysis',
#   'tally',
#   'business analysis'],
#  216: ['canva', 'interaction design', 'adobe xd'],
#  217: ['scikitlearn', 'machine learning', 'data science'],
#  218: ['postgresql', 'vue', 'spring', 'react'],
#  219: ['hadoop', 'snowflake', 'excel', 'spark', 'etl'],
#  220: ['google analytics',
#   'digital marketing',
#   'content writing',
#   'mailchimp',
#   'social media strategy',
#   'hubspot'],
#  221: ['flask', 'spring', 'nextjs', 'javascript'],
#  222: ['photoshop', 'illustrator', 'adobe xd'],
#  223: ['deep learning',
#   'agentic ai',
#   'pytorch',
#   'nlp',
#   'scikitlearn',
#   'data science'],
#  224: ['hadoop', 'tableau', 'powerbi', 'snowflake', 'etl', 'sql'],
#  225: ['nodejs', 'vue', 'css', 'angular'],
#  226: ['computer vision', 'agentic ai', 'deep learning', 'tensorflow', 'nlp'],
#  227: ['hubspot',
#   'google analytics',
#   'seo',
#   'mailchimp',
#   'social media strategy',
#   'digital marketing'],
#  228: ['powerbi', 'tableau', 'kafka', 'airflow'],
#  229: ['nlp', 'pytorch', 'deep learning', 'mlops'],
#  230: ['tensorflow', 'pytorch', 'mlops', 'scikitlearn'],
#  231: ['react', 'flask', 'spring'],
#  232: ['excel', 'tableau', 'snowflake', 'airflow'],
#  233: ['business analysis', 'tally', 'financial modeling', 'quickbooks'],
#  234: ['tally',
#   'business analysis',
#   'ms excel',
#   'risk analysis',
#   'quickbooks',
#   'accounting'],
#  235: ['docker',
#   'terraform',
#   'aws',
#   'cicd',
#   'infrastructure as code',
#   'jenkins'],
#  236: ['business analysis', 'tally', 'risk analysis'],
#  237: ['android', 'react native', 'swift', 'flutter', 'dart'],
#  238: ['illustrator',
#   'uiux design',
#   'adobe xd',
#   'interaction design',
#   'figma',
#   'canva'],
#  239: ['gen ai', 'machine learning', 'pytorch'],
#  240: ['ansible', 'infrastructure as code', 'cicd'],
#  241: ['django', 'css', 'html', 'spring', 'sql', 'flask'],
#  242: ['uiux design',
#   'photoshop',
#   'interaction design',
#   'adobe xd',
#   'graphic design'],
#  243: ['deep learning',
#   'tensorflow',
#   'mlops',
#   'computer vision',
#   'gen ai',
#   'machine learning'],
#  244: ['angular', 'flask', 'sql', 'react', 'css', 'spring'],
#  245: ['express', 'react', 'angular', 'css'],
#  246: ['excel', 'tableau', 'snowflake', 'etl', 'powerbi', 'sql'],
#  247: ['illustrator', 'photoshop', 'graphic design'],
#  248: ['firebase', 'swift', 'ios', 'android', 'dart', 'flutter'],
#  249: ['graphic design', 'figma', 'uiux design', 'adobe xd'],
#  250: ['snowflake', 'sql', 'excel', 'tableau', 'airflow', 'hadoop'],
#  251: ['sql', 'etl', 'kafka', 'spark', 'tableau'],
#  252: ['tableau', 'snowflake', 'etl', 'excel', 'spark'],
#  253: ['firebase', 'kotlin', 'swift'],
#  254: ['photoshop', 'figma', 'graphic design'],
#  255: ['infrastructure as code', 'docker', 'gcp'],
#  256: ['aws', 'jenkins', 'infrastructure as code'],
#  257: ['gen ai', 'deep learning', 'computer vision', 'scikitlearn'],
#  258: ['terraform', 'jenkins', 'infrastructure as code'],
#  259: ['firebase', 'swift', 'flutter'],
#  260: ['mlops', 'pytorch', 'scikitlearn', 'deep learning'],
#  261: ['ios', 'firebase', 'swift', 'dart', 'android'],
#  262: ['infrastructure as code', 'kubernetes', 'terraform'],
#  263: ['sql', 'express', 'css', 'spring', 'flask', 'mongodb'],
#  264: ['firebase', 'ios', 'dart'],
#  265: ['financial modeling',
#   'accounting',
#   'risk analysis',
#   'ms excel',
#   'business analysis',
#   'quickbooks'],
#  266: ['canva', 'adobe xd', 'photoshop', 'interaction design', 'illustrator'],
#  267: ['swift', 'dart', 'react native'],
#  268: ['kafka', 'etl', 'sql'],
#  269: ['figma', 'uiux design', 'interaction design', 'adobe xd'],
#  270: ['canva', 'photoshop', 'graphic design', 'figma', 'illustrator'],
#  271: ['powerbi', 'hadoop', 'tableau', 'kafka'],
#  272: ['express', 'django', 'postgresql', 'nodejs', 'mongodb'],
#  273: ['canva', 'figma', 'adobe xd', 'photoshop', 'graphic design'],
#  274: ['tableau', 'snowflake', 'sql', 'kafka'],
#  275: ['docker', 'kubernetes', 'jenkins', 'infrastructure as code'],
#  276: ['aws', 'docker', 'infrastructure as code', 'jenkins', 'terraform'],
#  277: ['computer vision', 'agentic ai', 'pytorch'],
#  278: ['digital marketing',
#   'market research',
#   'google analytics',
#   'content writing',
#   'seo'],
#  279: ['mlops',
#   'computer vision',
#   'data science',
#   'machine learning',
#   'gen ai'],
#  280: ['excel', 'tableau', 'powerbi', 'hadoop'],
#  281: ['nlp', 'agentic ai', 'machine learning'],
#  282: ['jenkins', 'cicd', 'kubernetes', 'gcp', 'docker'],
#  283: ['canva', 'uiux design', 'illustrator'],
#  284: ['uiux design', 'adobe xd', 'photoshop'],
#  285: ['market research', 'google analytics', 'seo', 'content writing'],
#  286: ['financial modeling', 'quickbooks', 'accounting'],
#  287: ['illustrator', 'figma', 'uiux design'],
#  288: ['javascript', 'flask', 'mongodb', 'django', 'nodejs'],
#  289: ['social media strategy',
#   'digital marketing',
#   'content writing',
#   'market research'],
#  290: ['excel', 'airflow', 'snowflake', 'sql', 'spark', 'kafka'],
#  291: ['computer vision', 'gen ai', 'mlops'],
#  292: ['mailchimp',
#   'market research',
#   'content writing',
#   'seo',
#   'digital marketing'],
#  293: ['nodejs', 'javascript', 'django', 'sql', 'express', 'flask'],
#  294: ['aws', 'kubernetes', 'gcp'],
#  295: ['accounting', 'risk analysis', 'tally'],
#  296: ['nodejs', 'vue', 'sql', 'javascript', 'nextjs'],
#  297: ['uiux design', 'canva', 'illustrator', 'adobe xd', 'graphic design'],
#  298: ['cicd', 'azure', 'terraform', 'infrastructure as code', 'kubernetes'],
#  299: ['firebase', 'react native', 'android', 'dart', 'swift'],
#  300: ['sql', 'excel', 'snowflake'],
#  301: ['photoshop', 'canva', 'adobe xd'],
#  302: ['google analytics',
#   'social media strategy',
#   'hubspot',
#   'seo',
#   'digital marketing',
#   'mailchimp'],
#  303: ['etl', 'spark', 'hadoop', 'sql', 'snowflake', 'tableau'],
#  304: ['photoshop', 'illustrator', 'graphic design', 'uiux design'],
#  305: ['jenkins', 'infrastructure as code', 'docker', 'gcp', 'kubernetes'],
#  306: ['kotlin', 'flutter', 'react native', 'dart', 'swift'],
#  307: ['gen ai', 'agentic ai', 'nlp', 'mlops', 'scikitlearn'],
#  308: ['uiux design', 'photoshop', 'interaction design', 'graphic design'],
#  309: ['tally', 'accounting', 'risk analysis', 'business analysis'],
#  310: ['data science', 'gen ai', 'agentic ai', 'tensorflow', 'pytorch'],
#  311: ['html', 'mongodb', 'angular', 'nodejs', 'sql'],
#  312: ['illustrator',
#   'figma',
#   'photoshop',
#   'uiux design',
#   'canva',
#   'interaction design'],
#  313: ['kafka', 'snowflake', 'excel', 'tableau'],
#  314: ['accounting', 'risk analysis', 'business analysis'],
#  315: ['photoshop',
#   'figma',
#   'uiux design',
#   'adobe xd',
#   'interaction design',
#   'illustrator'],
#  316: ['tableau', 'snowflake', 'hadoop', 'kafka', 'sql', 'spark'],
#  317: ['flask', 'spring', 'sql', 'vue', 'html', 'postgresql'],
#  318: ['dart', 'react native', 'ios', 'swift'],
#  319: ['dart', 'react native', 'firebase', 'flutter', 'swift'],
#  320: ['photoshop', 'interaction design', 'graphic design'],
#  321: ['react', 'html', 'django'],
#  322: ['docker', 'kubernetes', 'terraform'],
#  323: ['hubspot', 'content writing', 'google analytics'],
#  324: ['nlp', 'tensorflow', 'agentic ai'],
#  325: ['google analytics', 'seo', 'hubspot', 'digital marketing'],
#  326: ['sql', 'html', 'mongodb', 'spring', 'vue'],
#  327: ['interaction design', 'canva', 'illustrator', 'photoshop'],
#  328: ['figma',
#   'photoshop',
#   'adobe xd',
#   'canva',
#   'graphic design',
#   'uiux design'],
#  329: ['ms excel', 'tally', 'financial modeling', 'quickbooks', 'accounting'],
#  330: ['tensorflow', 'scikitlearn', 'nlp', 'computer vision'],
#  331: ['snowflake', 'tableau', 'excel', 'kafka', 'airflow'],
#  332: ['angular', 'django', 'css', 'nodejs', 'flask', 'express'],
#  333: ['sql', 'css', 'vue', 'javascript'],
#  334: ['angular', 'nextjs', 'flask', 'mongodb', 'express'],
#  335: ['nodejs', 'angular', 'react', 'nextjs'],
#  336: ['jenkins', 'docker', 'azure', 'kubernetes'],
#  337: ['tally', 'financial modeling', 'business analysis', 'ms excel'],
#  338: ['ms excel',
#   'financial modeling',
#   'business analysis',
#   'tally',
#   'accounting',
#   'risk analysis'],
#  339: ['react native', 'swift', 'firebase', 'dart', 'kotlin', 'ios'],
#  340: ['nlp', 'gen ai', 'computer vision', 'tensorflow', 'data science'],
#  341: ['market research',
#   'seo',
#   'content writing',
#   'social media strategy',
#   'mailchimp',
#   'google analytics'],
#  342: ['accounting', 'quickbooks', 'business analysis', 'tally', 'ms excel'],
#  343: ['excel', 'snowflake', 'tableau', 'hadoop'],
#  344: ['deep learning', 'pytorch', 'nlp', 'mlops', 'agentic ai'],
#  345: ['gcp', 'terraform', 'cicd', 'jenkins', 'aws', 'infrastructure as code'],
#  346: ['google analytics', 'seo', 'content writing'],
#  347: ['gcp', 'azure', 'terraform', 'kubernetes', 'aws'],
#  348: ['hadoop', 'tableau', 'snowflake', 'kafka'],
#  349: ['ansible', 'jenkins', 'cicd', 'terraform'],
#  350: ['tally', 'quickbooks', 'risk analysis'],
#  351: ['risk analysis', 'quickbooks', 'financial modeling', 'accounting'],
#  352: ['business analysis',
#   'quickbooks',
#   'risk analysis',
#   'financial modeling',
#   'tally'],
#  353: ['snowflake', 'sql', 'kafka', 'powerbi'],
#  354: ['hadoop', 'etl', 'spark', 'sql', 'airflow'],
#  355: ['agentic ai', 'machine learning', 'mlops', 'deep learning'],
#  356: ['excel', 'tableau', 'kafka'],
#  357: ['machine learning', 'agentic ai', 'nlp', 'tensorflow'],
#  358: ['gen ai', 'mlops', 'computer vision'],
#  359: ['ms excel',
#   'risk analysis',
#   'quickbooks',
#   'tally',
#   'accounting',
#   'financial modeling'],
#  360: ['financial modeling',
#   'business analysis',
#   'ms excel',
#   'risk analysis',
#   'tally',
#   'quickbooks'],
#  361: ['swift', 'dart', 'android', 'flutter'],
#  362: ['ms excel', 'tally', 'accounting', 'quickbooks'],
#  363: ['snowflake', 'powerbi', 'excel', 'sql', 'tableau'],
#  364: ['hadoop', 'snowflake', 'airflow'],
#  365: ['spark', 'hadoop', 'powerbi', 'sql'],
#  366: ['swift', 'react native', 'dart', 'android'],
#  367: ['content writing',
#   'google analytics',
#   'hubspot',
#   'seo',
#   'market research',
#   'social media strategy'],
#  368: ['mongodb', 'javascript', 'flask', 'postgresql', 'spring', 'sql'],
#  369: ['machine learning',
#   'pytorch',
#   'tensorflow',
#   'deep learning',
#   'gen ai',
#   'mlops'],
#  370: ['digital marketing',
#   'hubspot',
#   'market research',
#   'google analytics',
#   'content writing'],
#  371: ['spark', 'etl', 'hadoop', 'powerbi'],
#  372: ['financial modeling',
#   'quickbooks',
#   'ms excel',
#   'risk analysis',
#   'accounting'],
#  373: ['sql', 'excel', 'kafka'],
#  374: ['dart', 'ios', 'flutter', 'kotlin'],
#  375: ['ios', 'android', 'swift', 'flutter', 'react native'],
#  376: ['react native', 'flutter', 'kotlin', 'firebase', 'dart', 'android'],
#  377: ['dart', 'android', 'swift', 'firebase', 'flutter'],
#  378: ['html', 'django', 'nextjs', 'express'],
#  379: ['scikitlearn', 'tensorflow', 'computer vision', 'machine learning'],
#  380: ['risk analysis', 'financial modeling', 'quickbooks'],
#  381: ['airflow', 'sql', 'powerbi', 'spark'],
#  382: ['mailchimp',
#   'google analytics',
#   'market research',
#   'digital marketing'],
#  383: ['deep learning', 'nlp', 'mlops'],
#  384: ['terraform', 'ansible', 'cicd', 'jenkins', 'docker', 'azure'],
#  385: ['excel', 'powerbi', 'sql'],
#  386: ['tableau', 'snowflake', 'hadoop'],
#  387: ['azure', 'kubernetes', 'docker'],
#  388: ['postgresql', 'html', 'angular'],
#  389: ['tensorflow',
#   'deep learning',
#   'agentic ai',
#   'data science',
#   'mlops',
#   'computer vision'],
#  390: ['financial modeling',
#   'ms excel',
#   'quickbooks',
#   'risk analysis',
#   'accounting',
#   'tally'],
#  391: ['uiux design', 'canva', 'graphic design'],
#  392: ['flutter', 'kotlin', 'dart'],
#  393: ['risk analysis',
#   'ms excel',
#   'quickbooks',
#   'business analysis',
#   'accounting'],
#  394: ['tally', 'financial modeling', 'business analysis'],
#  395: ['vue', 'django', 'nextjs', 'spring', 'express', 'mongodb'],
#  396: ['scikitlearn', 'data science', 'tensorflow', 'gen ai', 'nlp'],
#  397: ['express', 'react', 'mongodb', 'sql', 'spring'],
#  398: ['dart', 'react native', 'swift'],
#  399: ['mailchimp', 'google analytics', 'hubspot', 'digital marketing'],
#  400: ['business analysis',
#   'risk analysis',
#   'quickbooks',
#   'tally',
#   'accounting',
#   'ms excel'],
#  401: ['canva', 'photoshop', 'adobe xd', 'interaction design', 'figma'],
#  402: ['uiux design', 'illustrator', 'adobe xd', 'graphic design'],
#  403: ['photoshop', 'graphic design', 'canva', 'illustrator', 'figma'],
#  404: ['azure', 'kubernetes', 'terraform', 'jenkins', 'aws', 'cicd'],
#  405: ['adobe xd', 'interaction design', 'figma', 'canva'],
#  406: ['gcp', 'ansible', 'azure', 'aws', 'kubernetes'],
#  407: ['digital marketing',
#   'content writing',
#   'google analytics',
#   'seo',
#   'mailchimp',
#   'hubspot'],
#  408: ['deep learning', 'mlops', 'nlp', 'machine learning'],
#  409: ['quickbooks',
#   'tally',
#   'risk analysis',
#   'ms excel',
#   'business analysis',
#   'accounting'],
#  410: ['express', 'html', 'spring', 'django', 'css', 'sql'],
#  411: ['kotlin', 'react native', 'swift', 'dart'],
#  412: ['ios', 'dart', 'swift', 'flutter', 'android', 'firebase'],
#  413: ['react native', 'android', 'dart'],
#  414: ['powerbi', 'spark', 'sql', 'snowflake', 'hadoop', 'excel'],
#  415: ['android', 'react native', 'kotlin', 'dart', 'swift', 'ios'],
#  416: ['content writing', 'social media strategy', 'google analytics'],
#  417: ['excel', 'etl', 'snowflake', 'hadoop', 'airflow'],
#  418: ['ms excel', 'financial modeling', 'risk analysis'],
#  419: ['gcp', 'kubernetes', 'docker', 'jenkins'],
#  420: ['kotlin', 'dart', 'android', 'firebase', 'swift', 'flutter'],
#  421: ['android', 'react native', 'kotlin', 'dart', 'ios'],
#  422: ['tensorflow', 'pytorch', 'scikitlearn'],
#  423: ['hadoop', 'spark', 'excel'],
#  424: ['illustrator', 'adobe xd', 'photoshop', 'graphic design', 'canva'],
#  425: ['dart', 'android', 'swift', 'flutter', 'react native', 'kotlin'],
#  426: ['digital marketing', 'content writing', 'market research', 'hubspot'],
#  427: ['mailchimp',
#   'digital marketing',
#   'google analytics',
#   'content writing'],
#  428: ['aws', 'docker', 'terraform', 'ansible', 'gcp'],
#  429: ['kubernetes', 'infrastructure as code', 'jenkins', 'ansible', 'aws'],
#  430: ['tally',
#   'risk analysis',
#   'business analysis',
#   'ms excel',
#   'financial modeling',
#   'quickbooks'],
#  431: ['infrastructure as code',
#   'cicd',
#   'aws',
#   'kubernetes',
#   'terraform',
#   'docker'],
#  432: ['content writing',
#   'hubspot',
#   'seo',
#   'digital marketing',
#   'market research'],
#  433: ['css', 'angular', 'flask', 'express'],
#  434: ['ms excel', 'accounting', 'quickbooks', 'tally', 'financial modeling'],
#  435: ['mlops',
#   'pytorch',
#   'tensorflow',
#   'computer vision',
#   'nlp',
#   'scikitlearn'],
#  436: ['kafka', 'tableau', 'hadoop', 'sql'],
#  437: ['aws', 'kubernetes', 'infrastructure as code', 'cicd', 'docker'],
#  438: ['dart', 'android', 'flutter', 'ios', 'swift', 'kotlin'],
#  439: ['tally', 'ms excel', 'financial modeling'],
#  440: ['photoshop', 'adobe xd', 'illustrator'],
#  441: ['react native', 'firebase', 'kotlin', 'ios'],
#  442: ['tableau', 'hadoop', 'spark', 'snowflake'],
#  443: ['illustrator',
#   'uiux design',
#   'photoshop',
#   'adobe xd',
#   'canva',
#   'interaction design'],
#  444: ['swift', 'flutter', 'kotlin', 'dart'],
#  445: ['flask', 'nextjs', 'angular'],
#  446: ['flutter', 'ios', 'android', 'swift', 'kotlin'],
#  447: ['computer vision', 'scikitlearn', 'agentic ai', 'nlp'],
#  448: ['powerbi', 'tableau', 'kafka', 'etl'],
#  449: ['ansible', 'gcp', 'docker'],
#  450: ['infrastructure as code',
#   'docker',
#   'kubernetes',
#   'ansible',
#   'terraform'],
#  451: ['graphic design',
#   'interaction design',
#   'uiux design',
#   'photoshop',
#   'adobe xd',
#   'illustrator'],
#  452: ['django', 'express', 'mongodb', 'postgresql', 'flask'],
#  453: ['social media strategy', 'mailchimp', 'market research'],
#  454: ['hubspot',
#   'google analytics',
#   'mailchimp',
#   'seo',
#   'market research',
#   'content writing'],
#  455: ['swift', 'firebase', 'kotlin'],
#  456: ['ios', 'android', 'flutter', 'dart'],
#  457: ['tally',
#   'ms excel',
#   'quickbooks',
#   'risk analysis',
#   'financial modeling',
#   'accounting'],
#  458: ['risk analysis',
#   'accounting',
#   'business analysis',
#   'quickbooks',
#   'ms excel',
#   'tally'],
#  459: ['figma', 'uiux design', 'illustrator', 'canva'],
#  460: ['canva',
#   'graphic design',
#   'uiux design',
#   'adobe xd',
#   'figma',
#   'illustrator'],
#  461: ['infrastructure as code',
#   'jenkins',
#   'azure',
#   'ansible',
#   'docker',
#   'gcp'],
#  462: ['kotlin', 'swift', 'ios'],
#  463: ['spring', 'nodejs', 'postgresql', 'nextjs'],
#  464: ['social media strategy',
#   'content writing',
#   'seo',
#   'google analytics',
#   'digital marketing'],
#  465: ['deep learning', 'mlops', 'tensorflow', 'pytorch'],
#  466: ['seo', 'mailchimp', 'social media strategy', 'google analytics'],
#  467: ['google analytics',
#   'social media strategy',
#   'market research',
#   'mailchimp',
#   'content writing'],
#  468: ['computer vision', 'data science', 'gen ai', 'mlops', 'nlp'],
#  469: ['uiux design', 'adobe xd', 'interaction design', 'illustrator'],
#  470: ['quickbooks', 'risk analysis', 'tally', 'accounting'],
#  471: ['illustrator', 'canva', 'figma', 'graphic design'],
#  472: ['photoshop',
#   'figma',
#   'interaction design',
#   'canva',
#   'graphic design',
#   'illustrator'],
#  473: ['photoshop', 'graphic design', 'figma', 'uiux design', 'adobe xd'],
#  474: ['javascript', 'postgresql', 'django', 'flask'],
#  475: ['infrastructure as code',
#   'cicd',
#   'jenkins',
#   'docker',
#   'azure',
#   'terraform'],
#  476: ['flask', 'react', 'angular', 'mongodb', 'sql'],
#  477: ['kafka', 'snowflake', 'airflow'],
#  478: ['uiux design', 'photoshop', 'illustrator', 'graphic design'],
#  479: ['risk analysis',
#   'ms excel',
#   'quickbooks',
#   'accounting',
#   'business analysis',
#   'financial modeling'],
#  480: ['firebase', 'kotlin', 'android', 'swift'],
#  481: ['tableau', 'etl', 'snowflake', 'spark', 'excel', 'airflow'],
#  482: ['firebase', 'kotlin', 'swift', 'ios'],
#  483: ['graphic design',
#   'canva',
#   'figma',
#   'photoshop',
#   'interaction design',
#   'adobe xd'],
#  484: ['excel', 'tableau', 'etl', 'sql'],
#  485: ['kafka', 'etl', 'spark', 'airflow'],
#  486: ['postgresql', 'spring', 'express', 'vue', 'html', 'nodejs'],
#  487: ['dart', 'swift', 'react native'],
#  488: ['kotlin', 'firebase', 'react native'],
#  489: ['google analytics', 'mailchimp', 'market research'],
#  490: ['social media strategy', 'digital marketing', 'hubspot'],
#  491: ['gcp', 'jenkins', 'cicd'],
#  492: ['interaction design', 'photoshop', 'uiux design', 'canva', 'figma'],
#  493: ['digital marketing',
#   'content writing',
#   'hubspot',
#   'google analytics',
#   'mailchimp',
#   'seo'],
#  494: ['agentic ai',
#   'deep learning',
#   'machine learning',
#   'scikitlearn',
#   'pytorch',
#   'nlp'],
#  495: ['docker', 'terraform', 'jenkins', 'kubernetes'],
#  496: ['digital marketing', 'hubspot', 'seo', 'google analytics'],
#  497: ['angular', 'react', 'css', 'mongodb', 'flask'],
#  498: ['mlops',
#   'gen ai',
#   'tensorflow',
#   'machine learning',
#   'deep learning',
#   'agentic ai'],
#  499: ['canva', 'graphic design', 'interaction design', 'photoshop'],
#  500: ['data science', 'mlops', 'computer vision'],
#  501: ['graphic design', 'figma', 'illustrator'],
#  502: ['tensorflow',
#   'deep learning',
#   'machine learning',
#   'nlp',
#   'pytorch',
#   'data science'],
#  503: ['airflow', 'excel', 'sql', 'etl', 'snowflake', 'powerbi'],
#  504: ['django', 'express', 'javascript', 'css'],
#  505: ['pytorch',
#   'deep learning',
#   'scikitlearn',
#   'tensorflow',
#   'computer vision'],
#  506: ['flutter', 'dart', 'react native', 'kotlin', 'android'],
#  507: ['dart', 'swift', 'kotlin', 'android'],
#  508: ['digital marketing',
#   'social media strategy',
#   'market research',
#   'content writing'],
#  509: ['google analytics',
#   'content writing',
#   'mailchimp',
#   'social media strategy',
#   'digital marketing',
#   'hubspot'],
#  510: ['spring', 'javascript', 'nextjs'],
#  511: ['social media strategy', 'digital marketing', 'hubspot', 'mailchimp'],
#  512: ['data science', 'mlops', 'computer vision', 'gen ai'],
#  513: ['html', 'postgresql', 'vue'],
#  514: ['google analytics',
#   'hubspot',
#   'social media strategy',
#   'content writing',
#   'seo'],
#  515: ['flutter', 'ios', 'firebase', 'android'],
#  516: ['infrastructure as code', 'kubernetes', 'cicd'],
#  517: ['data science', 'computer vision', 'gen ai', 'scikitlearn'],
#  518: ['ios', 'firebase', 'dart', 'flutter', 'android', 'kotlin'],
#  519: ['excel', 'sql', 'spark', 'airflow', 'kafka', 'etl'],
#  520: ['powerbi', 'spark', 'snowflake'],
#  521: ['canva', 'adobe xd', 'illustrator', 'uiux design', 'photoshop'],
#  522: ['adobe xd', 'graphic design', 'canva', 'uiux design', 'figma'],
#  523: ['ios', 'swift', 'dart'],
#  524: ['react native', 'firebase', 'dart'],
#  525: ['kafka', 'tableau', 'etl', 'airflow', 'spark'],
#  526: ['ios', 'swift', 'kotlin', 'android'],
#  527: ['excel', 'spark', 'snowflake'],
#  528: ['flutter', 'dart', 'firebase'],
#  529: ['uiux design',
#   'illustrator',
#   'photoshop',
#   'canva',
#   'adobe xd',
#   'graphic design'],
#  530: ['quickbooks', 'business analysis', 'risk analysis'],
#  531: ['machine learning', 'nlp', 'agentic ai', 'pytorch', 'gen ai'],
#  532: ['kotlin', 'react native', 'ios', 'dart', 'flutter'],
#  533: ['etl', 'powerbi', 'sql', 'excel', 'snowflake', 'kafka'],
#  534: ['docker', 'ansible', 'cicd'],
#  535: ['firebase', 'dart', 'flutter', 'android', 'react native', 'swift'],
#  536: ['mlops', 'nlp', 'agentic ai', 'computer vision', 'pytorch'],
#  537: ['nlp', 'mlops', 'tensorflow'],
#  538: ['uiux design',
#   'adobe xd',
#   'canva',
#   'graphic design',
#   'illustrator',
#   'figma'],
#  539: ['jenkins', 'cicd', 'docker', 'terraform', 'ansible'],
#  540: ['sql', 'hadoop', 'powerbi', 'excel', 'etl', 'snowflake'],
#  541: ['accounting', 'business analysis', 'financial modeling'],
#  542: ['flutter', 'kotlin', 'ios', 'android', 'swift'],
#  543: ['kotlin', 'firebase', 'dart', 'android', 'react native', 'ios'],
#  544: ['uiux design', 'canva', 'illustrator'],
#  545: ['excel', 'etl', 'sql'],
#  546: ['content writing', 'digital marketing', 'hubspot'],
#  547: ['photoshop',
#   'graphic design',
#   'canva',
#   'interaction design',
#   'illustrator',
#   'adobe xd'],
#  548: ['social media strategy',
#   'content writing',
#   'seo',
#   'mailchimp',
#   'digital marketing'],
#  549: ['nlp',
#   'computer vision',
#   'scikitlearn',
#   'gen ai',
#   'agentic ai',
#   'machine learning'],
#  550: ['gcp', 'jenkins', 'infrastructure as code'],
#  551: ['content writing',
#   'market research',
#   'seo',
#   'digital marketing',
#   'social media strategy'],
#  552: ['kubernetes',
#   'ansible',
#   'jenkins',
#   'docker',
#   'gcp',
#   'infrastructure as code'],
#  553: ['sql', 'flask', 'express', 'vue', 'postgresql', 'angular'],
#  554: ['swift', 'dart', 'kotlin'],
#  555: ['angular', 'postgresql', 'nodejs', 'javascript', 'express'],
#  556: ['powerbi', 'hadoop', 'spark', 'etl', 'tableau', 'excel'],
#  557: ['hubspot',
#   'google analytics',
#   'market research',
#   'mailchimp',
#   'seo',
#   'digital marketing'],
#  558: ['photoshop', 'figma', 'interaction design', 'adobe xd'],
#  559: ['figma', 'adobe xd', 'graphic design'],
#  560: ['spark', 'hadoop', 'snowflake'],
#  561: ['azure', 'cicd', 'infrastructure as code', 'docker', 'jenkins'],
#  562: ['sql', 'etl', 'kafka', 'spark'],
#  563: ['financial modeling',
#   'business analysis',
#   'tally',
#   'risk analysis',
#   'accounting',
#   'ms excel'],
#  564: ['android', 'kotlin', 'react native', 'ios', 'flutter'],
#  565: ['express', 'vue', 'css'],
#  566: ['django', 'html', 'express'],
#  567: ['kubernetes', 'gcp', 'terraform', 'jenkins'],
#  568: ['ios', 'swift', 'android'],
#  569: ['spring', 'javascript', 'react', 'css', 'nextjs', 'express'],
#  570: ['sql', 'etl', 'excel'],
#  571: ['spark', 'powerbi', 'etl', 'airflow', 'tableau'],
#  572: ['angular', 'react', 'vue', 'javascript', 'nextjs'],
#  573: ['mailchimp', 'google analytics', 'hubspot', 'seo'],
#  574: ['tableau', 'snowflake', 'kafka'],
#  575: ['mlops', 'agentic ai', 'data science', 'tensorflow'],
#  576: ['business analysis',
#   'risk analysis',
#   'tally',
#   'ms excel',
#   'quickbooks'],
#  577: ['tableau', 'powerbi', 'spark', 'snowflake', 'excel'],
#  578: ['figma', 'interaction design', 'graphic design', 'canva', 'adobe xd'],
#  579: ['django', 'spring', 'nodejs', 'express', 'nextjs', 'mongodb'],
#  580: ['canva',
#   'graphic design',
#   'adobe xd',
#   'photoshop',
#   'illustrator',
#   'uiux design'],
#  581: ['photoshop', 'canva', 'adobe xd', 'graphic design'],
#  582: ['css', 'express', 'javascript', 'nodejs', 'sql', 'nextjs'],
#  583: ['excel', 'kafka', 'snowflake', 'etl', 'airflow', 'sql'],
#  584: ['quickbooks', 'ms excel', 'accounting'],
#  585: ['nodejs', 'html', 'vue', 'flask'],
#  586: ['etl', 'spark', 'excel', 'kafka', 'tableau'],
#  587: ['accounting', 'tally', 'financial modeling'],
#  588: ['canva', 'illustrator', 'figma'],
#  589: ['quickbooks',
#   'risk analysis',
#   'tally',
#   'accounting',
#   'financial modeling'],
#  590: ['financial modeling', 'ms excel', 'tally'],
#  591: ['excel', 'etl', 'kafka', 'tableau', 'powerbi', 'spark'],
#  592: ['flask', 'sql', 'spring', 'react', 'css', 'javascript'],
#  593: ['swift', 'kotlin', 'firebase'],
#  594: ['tensorflow', 'scikitlearn', 'agentic ai', 'data science'],
#  595: ['cicd', 'infrastructure as code', 'ansible', 'aws'],
#  596: ['digital marketing', 'hubspot', 'google analytics', 'mailchimp'],
#  597: ['digital marketing', 'seo', 'mailchimp'],
#  598: ['accounting', 'financial modeling', 'ms excel'],
#  599: ['figma', 'graphic design', 'canva'],
#  600: ['javascript', 'spring', 'react', 'sql'],
#  601: ['gen ai', 'pytorch', 'machine learning', 'data science'],
#  602: ['flask', 'spring', 'express', 'javascript', 'css', 'html'],
#  603: ['javascript', 'express', 'mongodb'],
#  604: ['market research',
#   'social media strategy',
#   'digital marketing',
#   'content writing'],
#  605: ['digital marketing',
#   'google analytics',
#   'seo',
#   'market research',
#   'mailchimp',
#   'social media strategy'],
#  606: ['airflow', 'snowflake', 'powerbi'],
#  607: ['sql', 'hadoop', 'excel'],
#  608: ['postgresql', 'sql', 'javascript', 'vue', 'react'],
#  609: ['quickbooks', 'accounting', 'risk analysis'],
#  610: ['graphic design', 'uiux design', 'photoshop', 'canva'],
#  611: ['flask', 'nodejs', 'nextjs', 'express', 'html', 'django'],
#  612: ['accounting',
#   'ms excel',
#   'business analysis',
#   'risk analysis',
#   'financial modeling',
#   'quickbooks'],
#  613: ['figma', 'canva', 'interaction design', 'uiux design'],
#  614: ['nodejs', 'spring', 'postgresql', 'flask', 'html'],
#  615: ['machine learning', 'deep learning', 'scikitlearn', 'data science'],
#  616: ['business analysis', 'risk analysis', 'quickbooks'],
#  617: ['javascript', 'angular', 'vue', 'mongodb', 'nextjs', 'flask'],
#  618: ['hadoop', 'excel', 'powerbi', 'airflow', 'kafka'],
#  619: ['graphic design', 'canva', 'interaction design', 'figma'],
#  620: ['dart', 'react native', 'ios', 'firebase', 'flutter', 'swift'],
#  621: ['vue', 'html', 'css'],
#  622: ['sql', 'react', 'html', 'flask'],
#  623: ['interaction design',
#   'adobe xd',
#   'graphic design',
#   'uiux design',
#   'photoshop',
#   'illustrator'],
#  624: ['business analysis',
#   'tally',
#   'quickbooks',
#   'financial modeling',
#   'accounting'],
#  625: ['ansible', 'cicd', 'azure', 'terraform'],
#  626: ['photoshop', 'canva', 'illustrator', 'adobe xd', 'graphic design'],
#  627: ['flutter', 'swift', 'ios'],
#  628: ['digital marketing',
#   'hubspot',
#   'google analytics',
#   'social media strategy',
#   'content writing',
#   'seo'],
#  629: ['tally',
#   'business analysis',
#   'quickbooks',
#   'financial modeling',
#   'ms excel',
#   'accounting'],
#  630: ['market research', 'hubspot', 'google analytics', 'seo'],
#  631: ['django', 'css', 'javascript', 'flask', 'spring'],
#  632: ['accounting', 'ms excel', 'business analysis', 'financial modeling'],
#  633: ['html', 'react', 'express', 'mongodb', 'django'],
#  634: ['photoshop', 'uiux design', 'figma'],
#  635: ['risk analysis', 'quickbooks', 'accounting', 'tally'],
#  636: ['spark', 'kafka', 'airflow'],
#  637: ['nextjs', 'nodejs', 'spring'],
#  638: ['airflow', 'etl', 'snowflake', 'hadoop'],
#  639: ['jenkins', 'azure', 'gcp'],
#  640: ['financial modeling',
#   'ms excel',
#   'tally',
#   'business analysis',
#   'risk analysis',
#   'quickbooks'],
#  641: ['mlops', 'data science', 'scikitlearn', 'pytorch', 'gen ai', 'nlp'],
#  642: ['scikitlearn', 'gen ai', 'deep learning', 'data science'],
#  643: ['react native', 'android', 'firebase', 'swift', 'ios', 'flutter'],
#  644: ['canva',
#   'figma',
#   'illustrator',
#   'adobe xd',
#   'photoshop',
#   'uiux design'],
#  645: ['quickbooks', 'business analysis', 'financial modeling', 'tally'],
#  646: ['graphic design', 'adobe xd', 'photoshop'],
#  647: ['html', 'nodejs', 'spring', 'postgresql', 'javascript', 'django'],
#  648: ['figma', 'photoshop', 'adobe xd', 'illustrator'],
#  649: ['risk analysis',
#   'tally',
#   'ms excel',
#   'financial modeling',
#   'accounting',
#   'quickbooks'],
#  650: ['snowflake', 'excel', 'spark', 'etl', 'tableau'],
#  651: ['angular', 'flask', 'html', 'postgresql', 'nodejs', 'react'],
#  652: ['swift', 'android', 'firebase', 'ios', 'react native'],
#  653: ['android', 'dart', 'react native', 'kotlin', 'flutter'],
#  654: ['django', 'express', 'nextjs', 'flask'],
#  655: ['spark', 'kafka', 'powerbi'],
#  656: ['react', 'vue', 'sql', 'angular', 'mongodb', 'nextjs'],
#  657: ['dart', 'swift', 'ios', 'android', 'firebase', 'flutter'],
#  658: ['express', 'nextjs', 'css', 'mongodb', 'django', 'html'],
#  659: ['etl', 'spark', 'hadoop', 'excel'],
#  660: ['mlops', 'gen ai', 'data science', 'scikitlearn', 'agentic ai'],
#  661: ['adobe xd',
#   'interaction design',
#   'photoshop',
#   'graphic design',
#   'illustrator',
#   'figma'],
#  662: ['jenkins', 'infrastructure as code', 'terraform', 'kubernetes'],
#  663: ['vue', 'angular', 'flask'],
#  664: ['etl', 'airflow', 'spark', 'excel', 'powerbi', 'tableau'],
#  665: ['figma', 'interaction design', 'uiux design', 'photoshop'],
#  666: ['ios', 'firebase', 'dart', 'flutter', 'swift'],
#  667: ['kafka', 'sql', 'airflow', 'powerbi', 'snowflake', 'spark'],
#  668: ['kafka', 'hadoop', 'airflow', 'excel', 'snowflake', 'spark'],
#  669: ['machine learning', 'deep learning', 'data science', 'pytorch', 'nlp'],
#  670: ['kotlin', 'ios', 'react native', 'flutter'],
#  671: ['illustrator', 'canva', 'uiux design', 'graphic design', 'photoshop'],
#  672: ['express', 'react', 'css', 'angular', 'nodejs', 'nextjs'],
#  673: ['tensorflow',
#   'machine learning',
#   'computer vision',
#   'data science',
#   'agentic ai'],
#  674: ['airflow', 'snowflake', 'sql'],
#  675: ['agentic ai',
#   'mlops',
#   'computer vision',
#   'pytorch',
#   'gen ai',
#   'machine learning'],
#  676: ['risk analysis',
#   'ms excel',
#   'quickbooks',
#   'tally',
#   'business analysis',
#   'financial modeling'],
#  677: ['interaction design', 'uiux design', 'graphic design', 'illustrator'],
#  678: ['content writing',
#   'social media strategy',
#   'hubspot',
#   'market research',
#   'digital marketing'],
#  679: ['infrastructure as code', 'kubernetes', 'gcp', 'docker', 'terraform'],
#  680: ['html', 'vue', 'react', 'django', 'sql', 'nodejs'],
#  681: ['gen ai', 'computer vision', 'data science'],
#  682: ['ansible', 'jenkins', 'azure', 'infrastructure as code', 'kubernetes'],
#  683: ['quickbooks', 'accounting', 'financial modeling', 'ms excel'],
#  684: ['digital marketing', 'seo', 'hubspot', 'market research', 'mailchimp'],
#  685: ['swift', 'kotlin', 'dart', 'ios', 'firebase'],
#  686: ['docker', 'terraform', 'aws', 'cicd'],
#  687: ['adobe xd',
#   'canva',
#   'graphic design',
#   'photoshop',
#   'uiux design',
#   'illustrator'],
#  688: ['html', 'sql', 'flask'],
#  689: ['deep learning', 'machine learning', 'gen ai', 'tensorflow'],
#  690: ['express', 'react', 'mongodb', 'django', 'postgresql'],
#  691: ['snowflake', 'etl', 'tableau', 'excel'],
#  692: ['angular', 'javascript', 'mongodb'],
#  693: ['azure', 'cicd', 'ansible'],
#  694: ['powerbi', 'kafka', 'excel', 'airflow', 'spark', 'snowflake'],
#  695: ['aws', 'infrastructure as code', 'ansible', 'kubernetes', 'terraform'],
#  696: ['graphic design', 'uiux design', 'illustrator'],
#  697: ['kafka', 'excel', 'snowflake', 'tableau', 'airflow'],
#  698: ['figma',
#   'illustrator',
#   'uiux design',
#   'interaction design',
#   'graphic design'],
#  699: ['seo', 'mailchimp', 'digital marketing', 'hubspot'],
#  700: ['tableau', 'airflow', 'kafka', 'etl', 'excel', 'spark'],
#  701: ['mailchimp',
#   'content writing',
#   'hubspot',
#   'seo',
#   'social media strategy',
#   'google analytics'],
#  702: ['kotlin', 'ios', 'flutter'],
#  703: ['docker', 'gcp', 'cicd', 'azure', 'terraform'],
#  704: ['social media strategy', 'market research', 'hubspot', 'seo'],
#  705: ['business analysis', 'risk analysis', 'quickbooks'],
#  706: ['figma', 'photoshop', 'uiux design'],
#  707: ['tensorflow', 'deep learning', 'pytorch', 'nlp', 'scikitlearn'],
#  708: ['graphic design',
#   'interaction design',
#   'figma',
#   'adobe xd',
#   'canva',
#   'uiux design'],
#  709: ['snowflake', 'excel', 'powerbi', 'hadoop'],
#  710: ['mlops', 'scikitlearn', 'pytorch', 'nlp', 'agentic ai', 'data science'],
#  711: ['illustrator', 'canva', 'figma', 'graphic design', 'uiux design'],
#  712: ['sql', 'spark', 'powerbi', 'tableau', 'snowflake'],
#  713: ['pytorch', 'mlops', 'nlp', 'gen ai', 'data science', 'agentic ai'],
#  714: ['data science', 'mlops', 'scikitlearn', 'gen ai'],
#  715: ['tensorflow',
#   'computer vision',
#   'agentic ai',
#   'deep learning',
#   'scikitlearn'],
#  716: ['aws', 'azure', 'gcp', 'docker', 'ansible'],
#  717: ['photoshop', 'graphic design', 'figma', 'adobe xd', 'uiux design'],
#  718: ['swift', 'flutter', 'firebase', 'react native', 'kotlin'],
#  719: ['deep learning',
#   'tensorflow',
#   'agentic ai',
#   'scikitlearn',
#   'data science'],
#  720: ['android', 'swift', 'react native', 'flutter'],
#  721: ['sql', 'excel', 'kafka', 'airflow'],
#  722: ['graphic design',
#   'interaction design',
#   'adobe xd',
#   'canva',
#   'uiux design'],
#  723: ['flask', 'html', 'django', 'postgresql'],
#  724: ['graphic design', 'interaction design', 'photoshop'],
#  725: ['kubernetes', 'infrastructure as code', 'docker', 'ansible'],
#  726: ['accounting', 'financial modeling', 'ms excel'],
#  727: ['quickbooks',
#   'risk analysis',
#   'tally',
#   'business analysis',
#   'financial modeling'],
#  728: ['agentic ai', 'pytorch', 'scikitlearn'],
#  729: ['aws', 'jenkins', 'gcp', 'terraform'],
#  730: ['quickbooks', 'tally', 'risk analysis', 'financial modeling'],
#  731: ['mlops',
#   'pytorch',
#   'scikitlearn',
#   'machine learning',
# ...
#   'content writing',
#   'seo',
#   'google analytics',
#   'mailchimp'],
#  762: ['tensorflow',
#   'nlp',
#   'mlops',
#   'deep learning',
#   'pytorch',
#   'machine learning'],
#  763: ['firebase', 'ios', 'swift', 'android', 'react native'],
#  764: ['dart', 'firebase', 'react native', 'kotlin', 'swift'],
#  765: ['deep learning',
#   'agentic ai',
#   'pytorch',
#   'data science',
#   'scikitlearn',
#   'nlp'],
#  766: ['airflow', 'powerbi', 'etl'],
#  767: ['photoshop',
#   'figma',
#   'interaction design',
#   'canva',
#   'graphic design',
#   'uiux design'],
#  768: ['agentic ai', 'data science', 'gen ai', 'tensorflow'],
#  769: ['ios', 'android', 'react native', 'flutter', 'firebase', 'swift'],
#  770: ['mlops', 'pytorch', 'computer vision', 'nlp', 'gen ai', 'agentic ai'],
#  771: ['cicd', 'azure', 'kubernetes', 'jenkins'],
#  772: ['graphic design', 'figma', 'adobe xd'],
#  773: ['flutter', 'swift', 'dart', 'android', 'react native'],
#  774: ['dart', 'swift', 'react native', 'kotlin'],
#  775: ['ios', 'android', 'flutter', 'kotlin', 'react native', 'dart'],
#  776: ['spark', 'sql', 'etl', 'airflow', 'excel'],
#  777: ['business analysis',
#   'accounting',
#   'tally',
#   'risk analysis',
#   'quickbooks'],
#  778: ['computer vision',
#   'nlp',
#   'data science',
#   'machine learning',
#   'deep learning'],
#  779: ['vue', 'nextjs', 'flask', 'django', 'angular'],
#  780: ['firebase', 'flutter', 'react native', 'android', 'dart', 'kotlin'],
#  781: ['market research',
#   'seo',
#   'hubspot',
#   'digital marketing',
#   'google analytics'],
#  782: ['risk analysis',
#   'quickbooks',
#   'tally',
#   'business analysis',
#   'financial modeling',
#   'accounting'],
#  783: ['scikitlearn', 'tensorflow', 'pytorch'],
#  784: ['flutter', 'react native', 'kotlin', 'ios', 'swift'],
#  785: ['django', 'javascript', 'html', 'angular'],
#  786: ['photoshop', 'canva', 'interaction design'],
#  787: ['nlp', 'scikitlearn', 'mlops', 'agentic ai', 'computer vision'],
#  788: ['data science', 'agentic ai', 'nlp', 'mlops', 'pytorch'],
#  789: ['sql', 'nodejs', 'angular', 'css', 'spring', 'express'],
#  790: ['firebase', 'swift', 'ios'],
#  791: ['airflow', 'hadoop', 'sql', 'tableau', 'kafka', 'powerbi'],
#  792: ['nextjs', 'postgresql', 'nodejs', 'sql'],
#  793: ['illustrator', 'uiux design', 'figma'],
#  794: ['ms excel',
#   'financial modeling',
#   'tally',
#   'business analysis',
#   'quickbooks',
#   'accounting'],
#  795: ['swift', 'ios', 'firebase', 'android', 'flutter'],
#  796: ['nextjs', 'angular', 'nodejs', 'sql', 'css'],
#  797: ['react native', 'kotlin', 'android', 'firebase', 'dart', 'flutter'],
#  798: ['react', 'css', 'spring', 'express'],
#  799: ['snowflake', 'airflow', 'powerbi', 'tableau', 'spark'],
#  800: ['excel', 'tableau', 'spark', 'airflow', 'etl', 'snowflake'],
#  801: ['photoshop', 'uiux design', 'canva', 'figma'],
#  802: ['scikitlearn', 'data science', 'nlp'],
#  803: ['flutter', 'firebase', 'dart', 'ios', 'react native'],
#  804: ['ms excel',
#   'financial modeling',
#   'risk analysis',
#   'tally',
#   'business analysis',
#   'quickbooks'],
#  805: ['uiux design', 'canva', 'figma', 'photoshop', 'interaction design'],
#  806: ['google analytics', 'market research', 'hubspot', 'mailchimp'],
#  807: ['tableau', 'kafka', 'powerbi', 'airflow'],
#  808: ['google analytics', 'mailchimp', 'seo'],
#  809: ['machine learning',
#   'gen ai',
#   'deep learning',
#   'agentic ai',
#   'computer vision'],
#  810: ['scikitlearn', 'tensorflow', 'pytorch', 'nlp'],
#  811: ['google analytics',
#   'content writing',
#   'social media strategy',
#   'mailchimp',
#   'seo',
#   'hubspot'],
#  812: ['jenkins', 'cicd', 'ansible', 'docker'],
#  813: ['content writing', 'seo', 'hubspot', 'social media strategy'],
#  814: ['ios', 'android', 'firebase'],
#  815: ['snowflake', 'tableau', 'excel'],
#  816: ['flask', 'javascript', 'react', 'nodejs', 'spring'],
#  817: ['aws', 'azure', 'ansible', 'gcp', 'terraform'],
#  818: ['css', 'angular', 'html', 'sql'],
#  819: ['uiux design', 'photoshop', 'interaction design', 'figma', 'canva'],
#  820: ['quickbooks',
#   'tally',
#   'financial modeling',
#   'business analysis',
#   'ms excel',
#   'accounting'],
#  821: ['digital marketing', 'seo', 'hubspot'],
#  822: ['interaction design', 'canva', 'photoshop'],
#  823: ['firebase', 'ios', 'kotlin', 'android', 'react native'],
#  824: ['kubernetes', 'terraform', 'jenkins', 'aws', 'ansible'],
#  825: ['hubspot',
#   'digital marketing',
#   'market research',
#   'seo',
#   'google analytics'],
#  826: ['tableau', 'hadoop', 'kafka', 'snowflake', 'sql'],
#  827: ['ms excel', 'business analysis', 'risk analysis'],
#  828: ['airflow', 'sql', 'tableau', 'kafka'],
#  829: ['financial modeling', 'accounting', 'risk analysis', 'ms excel'],
#  830: ['azure', 'gcp', 'aws', 'docker', 'kubernetes'],
#  831: ['firebase', 'android', 'react native', 'kotlin', 'ios', 'flutter'],
#  832: ['mongodb', 'django', 'spring', 'nextjs'],
#  833: ['accounting', 'ms excel', 'business analysis'],
#  834: ['aws', 'cicd', 'azure', 'gcp', 'infrastructure as code'],
#  835: ['mailchimp',
#   'content writing',
#   'google analytics',
#   'market research',
#   'seo'],
#  836: ['tally', 'financial modeling', 'risk analysis', 'business analysis'],
#  837: ['css', 'spring', 'django', 'sql', 'javascript', 'postgresql'],
#  838: ['airflow', 'tableau', 'kafka', 'etl'],
#  839: ['jenkins', 'cicd', 'docker', 'ansible'],
#  840: ['uiux design', 'graphic design', 'adobe xd'],
#  841: ['airflow', 'sql', 'excel'],
#  842: ['photoshop',
#   'uiux design',
#   'interaction design',
#   'adobe xd',
#   'canva',
#   'graphic design'],
#  843: ['financial modeling', 'tally', 'ms excel'],
#  844: ['vue', 'spring', 'mongodb'],
#  845: ['postgresql', 'react', 'django', 'html', 'express', 'spring'],
#  846: ['nlp', 'deep learning', 'pytorch'],
#  847: ['uiux design',
#   'graphic design',
#   'figma',
#   'interaction design',
#   'photoshop',
#   'canva'],
#  848: ['dart', 'android', 'kotlin', 'swift', 'react native', 'flutter'],
#  849: ['market research', 'hubspot', 'content writing', 'digital marketing'],
#  850: ['pytorch', 'scikitlearn', 'data science', 'machine learning', 'gen ai'],
#  851: ['nodejs', 'sql', 'flask', 'postgresql', 'angular', 'css'],
#  852: ['illustrator', 'uiux design', 'graphic design'],
#  853: ['aws',
#   'docker',
#   'infrastructure as code',
#   'azure',
#   'terraform',
#   'kubernetes'],
#  854: ['flutter', 'swift', 'dart'],
#  855: ['interaction design', 'photoshop', 'adobe xd', 'illustrator'],
#  856: ['seo',
#   'content writing',
#   'mailchimp',
#   'digital marketing',
#   'hubspot',
#   'google analytics'],
#  857: ['swift', 'flutter', 'android'],
#  858: ['uiux design', 'adobe xd', 'photoshop', 'graphic design', 'figma'],
#  859: ['javascript', 'nodejs', 'postgresql', 'django'],
#  860: ['dart', 'android', 'flutter', 'ios', 'react native', 'firebase'],
#  861: ['seo',
#   'mailchimp',
#   'hubspot',
#   'market research',
#   'digital marketing',
#   'social media strategy'],
#  862: ['react native', 'dart', 'android', 'ios', 'flutter', 'firebase'],
#  863: ['infrastructure as code', 'gcp', 'azure', 'ansible', 'cicd'],
#  864: ['nodejs', 'javascript', 'react'],
#  865: ['express', 'nextjs', 'postgresql'],
#  866: ['mongodb', 'vue', 'spring', 'css'],
#  867: ['snowflake', 'sql', 'airflow', 'etl', 'excel', 'hadoop'],
#  868: ['mlops',
#   'agentic ai',
#   'scikitlearn',
#   'computer vision',
#   'machine learning',
#   'nlp'],
#  869: ['nlp', 'tensorflow', 'computer vision', 'deep learning'],
#  870: ['financial modeling',
#   'accounting',
#   'ms excel',
#   'quickbooks',
#   'risk analysis'],
#  871: ['react native', 'flutter', 'android', 'ios', 'kotlin'],
#  872: ['tensorflow', 'gen ai', 'nlp', 'machine learning'],
#  873: ['kotlin', 'dart', 'swift', 'firebase', 'android'],
#  874: ['photoshop',
#   'interaction design',
#   'uiux design',
#   'graphic design',
#   'illustrator',
#   'figma'],
#  875: ['mailchimp',
#   'social media strategy',
#   'content writing',
#   'hubspot',
#   'market research',
#   'seo'],
#  876: ['etl', 'snowflake', 'sql'],
#  877: ['google analytics', 'content writing', 'seo'],
#  878: ['accounting',
#   'business analysis',
#   'risk analysis',
#   'ms excel',
#   'quickbooks'],
#  879: ['adobe xd', 'interaction design', 'figma', 'illustrator', 'photoshop'],
#  880: ['scikitlearn', 'deep learning', 'pytorch', 'agentic ai'],
#  881: ['illustrator',
#   'graphic design',
#   'uiux design',
#   'figma',
#   'adobe xd',
#   'canva'],
#  882: ['tensorflow',
#   'scikitlearn',
#   'data science',
#   'machine learning',
#   'deep learning',
#   'pytorch'],
#  883: ['tableau', 'hadoop', 'excel', 'kafka', 'snowflake', 'etl'],
#  884: ['quickbooks',
#   'risk analysis',
#   'financial modeling',
#   'accounting',
#   'business analysis'],
#  885: ['data science', 'mlops', 'deep learning', 'tensorflow', 'scikitlearn'],
#  886: ['business analysis',
#   'accounting',
#   'ms excel',
#   'quickbooks',
#   'risk analysis'],
#  887: ['ms excel', 'financial modeling', 'accounting'],
#  888: ['hubspot', 'mailchimp', 'market research', 'content writing'],
#  889: ['digital marketing',
#   'content writing',
#   'hubspot',
#   'google analytics',
#   'market research',
#   'seo'],
#  890: ['django', 'postgresql', 'angular'],
#  891: ['spring', 'django', 'angular', 'html', 'sql'],
#  892: ['seo',
#   'hubspot',
#   'google analytics',
#   'digital marketing',
#   'mailchimp',
#   'content writing'],
#  893: ['computer vision', 'tensorflow', 'mlops'],
#  894: ['hadoop', 'airflow', 'powerbi', 'spark', 'snowflake', 'kafka'],
#  895: ['pytorch', 'agentic ai', 'gen ai', 'data science'],
#  896: ['machine learning', 'pytorch', 'agentic ai'],
#  897: ['dart', 'react native', 'ios', 'firebase'],
#  898: ['css', 'spring', 'flask', 'sql'],
#  899: ['quickbooks', 'financial modeling', 'ms excel', 'accounting'],
#  900: ['vue', 'react', 'flask', 'express'],
#  901: ['html', 'postgresql', 'nodejs'],
#  902: ['google analytics', 'seo', 'digital marketing'],
#  903: ['data science',
#   'mlops',
#   'gen ai',
#   'computer vision',
#   'machine learning'],
#  904: ['react native', 'dart', 'swift', 'ios'],
#  905: ['cicd', 'gcp', 'azure', 'infrastructure as code', 'aws', 'terraform'],
#  906: ['terraform', 'gcp', 'ansible', 'kubernetes'],
#  907: ['terraform', 'kubernetes', 'cicd', 'docker', 'aws'],
#  908: ['data science', 'computer vision', 'gen ai', 'agentic ai', 'pytorch'],
#  909: ['angular', 'nodejs', 'css', 'react'],
#  910: ['kotlin', 'firebase', 'flutter'],
#  911: ['spring', 'javascript', 'nodejs', 'react'],
#  912: ['spring', 'css', 'postgresql', 'react'],
#  913: ['seo',
#   'market research',
#   'google analytics',
#   'hubspot',
#   'mailchimp',
#   'content writing'],
#  914: ['javascript', 'nodejs', 'react', 'postgresql', 'django'],
#  915: ['swift', 'dart', 'react native', 'kotlin', 'firebase', 'ios'],
#  916: ['google analytics',
#   'social media strategy',
#   'mailchimp',
#   'digital marketing',
#   'hubspot',
#   'market research'],
#  917: ['gcp', 'kubernetes', 'infrastructure as code', 'docker'],
#  918: ['mailchimp',
#   'market research',
#   'google analytics',
#   'content writing',
#   'seo'],
#  919: ['excel', 'etl', 'powerbi', 'spark'],
#  920: ['gcp', 'infrastructure as code', 'jenkins', 'docker'],
#  921: ['hadoop', 'kafka', 'tableau', 'powerbi'],
#  922: ['ansible', 'gcp', 'cicd', 'infrastructure as code', 'azure'],
#  923: ['aws', 'jenkins', 'infrastructure as code', 'cicd'],
#  924: ['mongodb', 'flask', 'vue', 'nodejs'],
#  925: ['terraform', 'ansible', 'docker', 'azure', 'cicd', 'gcp'],
#  926: ['digital marketing', 'social media strategy', 'content writing', 'seo'],
#  927: ['android', 'dart', 'flutter', 'kotlin'],
#  928: ['terraform', 'gcp', 'aws', 'ansible', 'cicd', 'infrastructure as code'],
#  929: ['tensorflow', 'pytorch', 'mlops', 'agentic ai'],
#  930: ['flutter', 'react native', 'swift', 'ios'],
#  931: ['swift', 'kotlin', 'flutter', 'react native', 'ios', 'dart'],
#  932: ['photoshop', 'canva', 'illustrator'],
#  933: ['tally', 'ms excel', 'accounting', 'financial modeling'],
#  934: ['google analytics', 'content writing', 'mailchimp'],
#  935: ['uiux design', 'interaction design', 'illustrator', 'adobe xd'],
#  936: ['machine learning', 'gen ai', 'agentic ai', 'mlops', 'pytorch', 'nlp'],
#  937: ['content writing',
#   'market research',
#   'google analytics',
#   'digital marketing',
#   'hubspot'],
#  938: ['firebase', 'kotlin', 'flutter', 'react native', 'dart'],
#  939: ['android', 'kotlin', 'ios', 'react native', 'dart'],
#  940: ['graphic design', 'photoshop', 'canva', 'uiux design'],
#  941: ['django', 'nextjs', 'javascript', 'css', 'angular'],
#  942: ['dart', 'ios', 'swift', 'firebase'],
#  943: ['social media strategy',
#   'hubspot',
#   'mailchimp',
#   'market research',
#   'content writing'],
#  944: ['data science',
#   'agentic ai',
#   'nlp',
#   'pytorch',
#   'machine learning',
#   'deep learning'],
#  945: ['scikitlearn', 'mlops', 'pytorch', 'computer vision', 'deep learning'],
#  946: ['seo', 'mailchimp', 'social media strategy', 'google analytics'],
#  947: ['tableau', 'kafka', 'airflow'],
#  948: ['data science', 'nlp', 'tensorflow'],
#  949: ['nextjs', 'sql', 'html', 'react', 'javascript', 'nodejs'],
#  950: ['scikitlearn', 'computer vision', 'data science', 'mlops'],
#  951: ['figma',
#   'interaction design',
#   'uiux design',
#   'adobe xd',
#   'graphic design',
#   'canva'],
#  952: ['swift', 'kotlin', 'ios'],
#  953: ['flutter', 'swift', 'dart', 'kotlin', 'react native', 'ios'],
#  954: ['illustrator',
#   'adobe xd',
#   'uiux design',
#   'figma',
#   'interaction design'],
#  955: ['ms excel',
#   'accounting',
#   'financial modeling',
#   'quickbooks',
#   'risk analysis'],
#  956: ['social media strategy',
#   'market research',
#   'google analytics',
#   'hubspot',
#   'mailchimp',
#   'content writing'],
#  957: ['firebase', 'swift', 'kotlin', 'dart'],
#  958: ['spark', 'airflow', 'excel', 'etl'],
#  959: ['terraform', 'jenkins', 'docker', 'aws', 'gcp'],
#  960: ['ansible', 'kubernetes', 'azure', 'terraform', 'docker', 'cicd'],
#  961: ['content writing', 'mailchimp', 'digital marketing', 'seo'],
#  962: ['computer vision', 'agentic ai', 'pytorch'],
#  963: ['photoshop', 'interaction design', 'adobe xd'],
#  964: ['agentic ai', 'computer vision', 'nlp'],
#  965: ['firebase', 'ios', 'swift'],
#  966: ['hadoop', 'airflow', 'snowflake', 'excel'],
#  967: ['business analysis', 'financial modeling', 'accounting'],
#  968: ['seo', 'social media strategy', 'market research', 'mailchimp'],
#  969: ['spark', 'excel', 'hadoop', 'kafka'],
#  970: ['adobe xd', 'illustrator', 'graphic design'],
#  971: ['google analytics', 'market research', 'seo', 'digital marketing'],
#  972: ['market research',
#   'mailchimp',
#   'content writing',
#   'google analytics',
#   'digital marketing'],
#  973: ['django', 'spring', 'express', 'css', 'nodejs'],
#  974: ['adobe xd', 'photoshop', 'graphic design', 'interaction design'],
#  975: ['angular', 'sql', 'vue'],
#  976: ['mlops', 'gen ai', 'tensorflow', 'pytorch'],
#  977: ['ansible', 'azure', 'cicd', 'aws', 'infrastructure as code'],
#  978: ['uiux design',
#   'interaction design',
#   'illustrator',
#   'canva',
#   'photoshop',
#   'figma'],
#  979: ['nlp', 'data science', 'agentic ai', 'gen ai'],
#  980: ['illustrator',
#   'interaction design',
#   'graphic design',
#   'figma',
#   'adobe xd'],
#  981: ['jenkins', 'cicd', 'azure'],
#  982: ['quickbooks', 'risk analysis', 'accounting', 'financial modeling'],
#  983: ['mlops', 'machine learning', 'computer vision'],
#  984: ['computer vision', 'nlp', 'tensorflow', 'deep learning', 'scikitlearn'],
#  985: ['kotlin', 'dart', 'flutter', 'react native'],
#  986: ['computer vision', 'scikitlearn', 'mlops'],
#  987: ['tableau', 'snowflake', 'etl'],
#  988: ['swift', 'flutter', 'android', 'react native'],
#  989: ['vue', 'postgresql', 'mongodb', 'express', 'angular', 'sql'],
#  990: ['sql', 'excel', 'powerbi'],
#  991: ['cicd', 'infrastructure as code', 'docker', 'terraform', 'gcp'],
#  992: ['django', 'sql', 'mongodb', 'css', 'nodejs'],
#  993: ['hubspot',
#   'seo',
#   'content writing',
#   'google analytics',
#   'digital marketing'],
#  994: ['infrastructure as code', 'cicd', 'kubernetes'],
#  995: ['kubernetes', 'infrastructure as code', 'terraform', 'cicd'],
#  996: ['canva',
#   'interaction design',
#   'graphic design',
#   'uiux design',
#   'figma',
#   'photoshop'],
#  997: ['google analytics',
#   'market research',
#   'digital marketing',
#   'mailchimp'],
#  998: ['canva', 'uiux design', 'illustrator'],
#  999: ['kafka', 'etl', 'snowflake', 'powerbi'],
#  1000: ['graphic design', 'canva', 'illustrator']}

# %%
int_reqs
# Out:
# {1: ['terraform', 'azure', 'docker', 'gcp', 'infrastructure as code'],
#  2: ['interaction design',
#   'graphic design',
#   'photoshop',
#   'canva',
#   'illustrator',
#   'figma'],
#  3: ['agentic ai',
#   'pytorch',
#   'tensorflow',
#   'computer vision',
#   'data science',
#   'gen ai'],
#  4: ['quickbooks', 'tally', 'accounting', 'ms excel', 'business analysis'],
#  5: ['social media strategy', 'market research', 'hubspot'],
#  6: ['android', 'firebase', 'kotlin'],
#  7: ['excel', 'etl', 'tableau', 'kafka', 'sql'],
#  8: ['ios', 'dart', 'swift', 'flutter', 'android', 'firebase'],
#  9: ['react native', 'dart', 'swift'],
#  10: ['hadoop', 'powerbi', 'tableau', 'kafka', 'etl', 'snowflake'],
#  11: ['nlp', 'data science', 'deep learning', 'agentic ai', 'mlops', 'gen ai'],
#  12: ['market research',
#   'content writing',
#   'mailchimp',
#   'social media strategy',
#   'digital marketing'],
#  13: ['ms excel', 'business analysis', 'risk analysis', 'tally', 'quickbooks'],
#  14: ['postgresql', 'flask', 'express', 'sql', 'django', 'mongodb'],
#  15: ['swift', 'dart', 'android'],
#  16: ['scikitlearn',
#   'deep learning',
#   'computer vision',
#   'agentic ai',
#   'gen ai'],
#  17: ['excel', 'kafka', 'snowflake', 'airflow', 'spark'],
#  18: ['react native', 'ios', 'android'],
#  19: ['market research',
#   'content writing',
#   'digital marketing',
#   'mailchimp',
#   'hubspot',
#   'seo'],
#  20: ['gcp', 'jenkins', 'azure', 'terraform', 'ansible', 'docker'],
#  21: ['uiux design', 'canva', 'illustrator', 'graphic design'],
#  22: ['snowflake', 'etl', 'powerbi'],
#  23: ['business analysis', 'quickbooks', 'accounting'],
#  24: ['ms excel', 'tally', 'business analysis'],
#  25: ['infrastructure as code', 'jenkins', 'aws', 'gcp'],
#  26: ['data science',
#   'gen ai',
#   'pytorch',
#   'nlp',
#   'computer vision',
#   'deep learning'],
#  27: ['figma',
#   'graphic design',
#   'canva',
#   'uiux design',
#   'interaction design',
#   'adobe xd'],
#  28: ['spark', 'excel', 'airflow'],
#  29: ['firebase', 'android', 'kotlin', 'react native', 'swift', 'ios'],
#  30: ['sql', 'airflow', 'tableau', 'hadoop', 'powerbi', 'snowflake'],
#  31: ['financial modeling', 'business analysis', 'quickbooks'],
#  32: ['django', 'flask', 'mongodb'],
#  33: ['ios', 'firebase', 'flutter', 'kotlin', 'swift', 'dart'],
#  34: ['mlops',
#   'data science',
#   'deep learning',
#   'agentic ai',
#   'machine learning',
#   'gen ai'],
#  35: ['figma', 'illustrator', 'adobe xd', 'graphic design', 'uiux design'],
#  36: ['flutter', 'react native', 'dart', 'swift', 'firebase'],
#  37: ['powerbi', 'kafka', 'excel', 'sql', 'spark'],
#  38: ['azure', 'gcp', 'ansible', 'aws', 'cicd', 'terraform'],
#  39: ['html', 'vue', 'nextjs', 'sql', 'css'],
#  40: ['ansible', 'infrastructure as code', 'gcp'],
#  41: ['angular', 'javascript', 'sql', 'html', 'django'],
#  42: ['illustrator', 'uiux design', 'canva', 'graphic design', 'photoshop'],
#  43: ['graphic design',
#   'photoshop',
#   'figma',
#   'canva',
#   'uiux design',
#   'adobe xd'],
#  44: ['mailchimp', 'social media strategy', 'hubspot', 'google analytics'],
#  45: ['excel', 'airflow', 'spark', 'hadoop', 'etl'],
#  46: ['ios', 'swift', 'firebase', 'kotlin'],
#  47: ['docker', 'aws', 'terraform', 'azure', 'gcp'],
#  48: ['figma', 'illustrator', 'interaction design'],
#  49: ['social media strategy', 'mailchimp', 'content writing', 'seo'],
#  50: ['pytorch',
#   'computer vision',
#   'tensorflow',
#   'scikitlearn',
#   'nlp',
#   'machine learning'],
#  51: ['ms excel', 'accounting', 'business analysis', 'tally'],
#  52: ['docker', 'aws', 'kubernetes', 'cicd', 'terraform'],
#  53: ['azure', 'jenkins', 'aws', 'kubernetes', 'docker'],
#  54: ['mailchimp', 'hubspot', 'market research', 'seo', 'content writing'],
#  55: ['illustrator', 'canva', 'figma'],
#  56: ['mailchimp', 'digital marketing', 'content writing'],
#  57: ['javascript', 'sql', 'react', 'nodejs', 'angular', 'django'],
#  58: ['kotlin', 'dart', 'react native', 'swift', 'firebase', 'android'],
#  59: ['business analysis',
#   'quickbooks',
#   'financial modeling',
#   'tally',
#   'ms excel',
#   'risk analysis'],
#  60: ['react native', 'flutter', 'android'],
#  61: ['risk analysis', 'financial modeling', 'tally'],
#  62: ['android', 'swift', 'ios', 'kotlin', 'flutter', 'dart'],
#  63: ['aws', 'cicd', 'docker'],
#  64: ['cicd', 'ansible', 'gcp', 'infrastructure as code', 'docker', 'aws'],
#  65: ['figma', 'interaction design', 'adobe xd', 'canva'],
#  66: ['infrastructure as code', 'cicd', 'terraform', 'docker', 'ansible'],
#  67: ['terraform', 'azure', 'cicd', 'aws'],
#  68: ['computer vision', 'tensorflow', 'gen ai'],
#  69: ['html', 'css', 'spring', 'mongodb', 'nextjs', 'javascript'],
#  70: ['accounting', 'quickbooks', 'tally'],
#  71: ['mailchimp', 'digital marketing', 'seo'],
#  72: ['ansible', 'infrastructure as code', 'terraform'],
#  73: ['canva', 'adobe xd', 'uiux design', 'interaction design'],
#  74: ['gen ai', 'computer vision', 'agentic ai', 'machine learning'],
#  75: ['tensorflow', 'agentic ai', 'nlp', 'pytorch', 'computer vision'],
#  76: ['airflow', 'hadoop', 'excel', 'spark', 'kafka', 'powerbi'],
#  77: ['jenkins', 'aws', 'kubernetes', 'azure', 'docker', 'ansible'],
#  78: ['pytorch', 'machine learning', 'nlp', 'tensorflow'],
#  79: ['mongodb', 'javascript', 'nextjs', 'postgresql', 'django', 'sql'],
#  80: ['etl', 'airflow', 'kafka', 'spark'],
#  81: ['tableau', 'sql', 'hadoop'],
#  82: ['hadoop', 'spark', 'sql', 'powerbi'],
#  83: ['airflow', 'tableau', 'etl', 'sql', 'snowflake', 'spark'],
#  84: ['powerbi', 'tableau', 'sql', 'excel', 'snowflake', 'kafka'],
#  85: ['mongodb', 'flask', 'vue'],
#  86: ['kotlin', 'flutter', 'ios', 'react native'],
#  87: ['illustrator', 'canva', 'adobe xd', 'interaction design'],
#  88: ['financial modeling',
#   'quickbooks',
#   'business analysis',
#   'risk analysis',
#   'accounting'],
#  89: ['excel', 'airflow', 'powerbi', 'snowflake', 'spark', 'kafka'],
#  90: ['nodejs', 'javascript', 'angular', 'vue', 'sql', 'nextjs'],
#  91: ['powerbi', 'spark', 'tableau', 'sql', 'snowflake'],
#  92: ['interaction design', 'figma', 'uiux design', 'canva', 'adobe xd'],
#  93: ['excel', 'tableau', 'kafka', 'spark', 'hadoop', 'powerbi'],
#  94: ['ms excel',
#   'quickbooks',
#   'risk analysis',
#   'accounting',
#   'tally',
#   'business analysis'],
#  95: ['adobe xd', 'graphic design', 'figma', 'illustrator', 'photoshop'],
#  96: ['mlops', 'scikitlearn', 'data science'],
#  97: ['accounting', 'ms excel', 'financial modeling'],
#  98: ['kotlin', 'react native', 'firebase', 'ios', 'android', 'dart'],
#  99: ['flutter', 'android', 'dart'],
#  100: ['airflow', 'etl', 'spark'],
#  101: ['illustrator',
#   'canva',
#   'photoshop',
#   'uiux design',
#   'interaction design'],
#  102: ['hubspot', 'social media strategy', 'google analytics'],
#  103: ['azure', 'ansible', 'gcp', 'kubernetes', 'terraform', 'cicd'],
#  104: ['mlops',
#   'tensorflow',
#   'machine learning',
#   'deep learning',
#   'data science'],
#  105: ['content writing',
#   'mailchimp',
#   'social media strategy',
#   'market research',
#   'seo'],
#  106: ['spark', 'airflow', 'sql', 'powerbi', 'etl', 'tableau'],
#  107: ['market research',
#   'google analytics',
#   'hubspot',
#   'mailchimp',
#   'digital marketing'],
#  108: ['google analytics',
#   'digital marketing',
#   'market research',
#   'social media strategy',
#   'hubspot',
#   'seo'],
#  109: ['risk analysis',
#   'business analysis',
#   'accounting',
#   'financial modeling'],
#  110: ['ms excel', 'tally', 'financial modeling', 'accounting'],
#  111: ['powerbi', 'airflow', 'kafka', 'etl'],
#  112: ['html', 'nextjs', 'css', 'javascript', 'postgresql'],
#  113: ['react native', 'flutter', 'ios'],
#  114: ['angular', 'mongodb', 'nextjs', 'css', 'postgresql'],
#  115: ['cicd', 'jenkins', 'terraform', 'gcp', 'kubernetes', 'docker'],
#  116: ['scikitlearn', 'mlops', 'data science'],
#  117: ['illustrator', 'figma', 'adobe xd', 'photoshop'],
#  118: ['figma', 'uiux design', 'graphic design', 'illustrator'],
#  119: ['angular', 'spring', 'react', 'express', 'nodejs'],
#  120: ['terraform', 'docker', 'azure'],
#  121: ['postgresql', 'angular', 'nodejs', 'nextjs'],
#  122: ['hubspot',
#   'google analytics',
#   'market research',
#   'digital marketing',
#   'content writing',
#   'seo'],
#  123: ['quickbooks', 'accounting', 'business analysis', 'financial modeling'],
#  124: ['aws', 'jenkins', 'docker', 'kubernetes', 'azure'],
#  125: ['illustrator', 'interaction design', 'figma', 'uiux design'],
#  126: ['tableau', 'spark', 'sql', 'snowflake', 'airflow'],
#  127: ['content writing', 'mailchimp', 'market research', 'hubspot', 'seo'],
#  128: ['computer vision',
#   'mlops',
#   'pytorch',
#   'deep learning',
#   'tensorflow',
#   'agentic ai'],
#  129: ['css', 'html', 'postgresql', 'mongodb', 'nodejs', 'express'],
#  130: ['tally',
#   'risk analysis',
#   'ms excel',
#   'quickbooks',
#   'financial modeling',
#   'business analysis'],
#  131: ['figma', 'graphic design', 'canva', 'illustrator', 'uiux design'],
#  132: ['tensorflow',
#   'agentic ai',
#   'nlp',
#   'scikitlearn',
#   'data science',
#   'pytorch'],
#  133: ['vue', 'html', 'css'],
#  134: ['risk analysis',
#   'quickbooks',
#   'ms excel',
#   'tally',
#   'financial modeling'],
#  135: ['data science', 'scikitlearn', 'nlp', 'computer vision'],
#  136: ['ios', 'react native', 'dart'],
#  137: ['quickbooks', 'accounting', 'ms excel'],
#  138: ['illustrator', 'adobe xd', 'uiux design', 'figma', 'canva'],
#  139: ['gcp', 'aws', 'terraform', 'azure'],
#  140: ['jenkins', 'aws', 'infrastructure as code', 'kubernetes', 'gcp'],
#  141: ['snowflake', 'spark', 'airflow', 'hadoop'],
#  142: ['hubspot',
#   'social media strategy',
#   'seo',
#   'digital marketing',
#   'content writing'],
#  143: ['ios', 'firebase', 'dart', 'android', 'kotlin'],
#  144: ['interaction design', 'adobe xd', 'uiux design'],
#  145: ['docker',
#   'infrastructure as code',
#   'azure',
#   'kubernetes',
#   'aws',
#   'cicd'],
#  146: ['hubspot', 'digital marketing', 'seo', 'google analytics'],
#  147: ['angular', 'nodejs', 'javascript', 'css', 'react', 'spring'],
#  148: ['mailchimp', 'hubspot', 'social media strategy'],
#  149: ['computer vision',
#   'data science',
#   'scikitlearn',
#   'pytorch',
#   'machine learning',
#   'agentic ai'],
#  150: ['uiux design', 'adobe xd', 'illustrator'],
#  151: ['nlp', 'tensorflow', 'scikitlearn', 'pytorch', 'machine learning'],
#  152: ['react native', 'dart', 'android', 'firebase'],
#  153: ['snowflake', 'kafka', 'spark', 'powerbi'],
#  154: ['accounting', 'financial modeling', 'ms excel', 'risk analysis'],
#  155: ['nextjs', 'flask', 'spring'],
#  156: ['nlp', 'mlops', 'machine learning', 'data science', 'agentic ai'],
#  157: ['illustrator', 'canva', 'photoshop', 'adobe xd', 'figma'],
#  158: ['hadoop', 'kafka', 'tableau', 'spark', 'sql', 'etl'],
#  159: ['seo',
#   'hubspot',
#   'mailchimp',
#   'social media strategy',
#   'content writing',
#   'market research'],
#  160: ['ms excel',
#   'business analysis',
#   'financial modeling',
#   'accounting',
#   'quickbooks',
#   'tally'],
#  161: ['android', 'flutter', 'swift', 'firebase'],
#  162: ['data science', 'scikitlearn', 'tensorflow', 'deep learning'],
#  163: ['deep learning', 'mlops', 'gen ai', 'pytorch', 'tensorflow'],
#  164: ['swift', 'firebase', 'flutter'],
#  165: ['pytorch',
#   'scikitlearn',
#   'deep learning',
#   'tensorflow',
#   'mlops',
#   'nlp'],
#  166: ['photoshop',
#   'graphic design',
#   'figma',
#   'adobe xd',
#   'interaction design',
#   'illustrator'],
#  167: ['seo',
#   'social media strategy',
#   'mailchimp',
#   'digital marketing',
#   'market research'],
#  168: ['django', 'angular', 'mongodb', 'react', 'sql'],
#  169: ['ios', 'kotlin', 'android'],
#  170: ['ios', 'react native', 'dart', 'flutter'],
#  171: ['cicd',
#   'ansible',
#   'infrastructure as code',
#   'jenkins',
#   'terraform',
#   'gcp'],
#  172: ['graphic design',
#   'uiux design',
#   'adobe xd',
#   'interaction design',
#   'canva',
#   'figma'],
#  173: ['illustrator', 'uiux design', 'canva'],
#  174: ['powerbi', 'hadoop', 'tableau', 'snowflake', 'airflow'],
#  175: ['firebase', 'swift', 'dart', 'ios', 'react native', 'android'],
#  176: ['business analysis', 'financial modeling', 'quickbooks', 'accounting'],
#  177: ['google analytics', 'social media strategy', 'content writing'],
#  178: ['mongodb', 'css', 'angular'],
#  179: ['react', 'mongodb', 'express', 'sql', 'flask'],
#  180: ['uiux design',
#   'photoshop',
#   'interaction design',
#   'canva',
#   'graphic design',
#   'figma'],
#  181: ['seo', 'mailchimp', 'content writing', 'google analytics'],
#  182: ['kafka', 'sql', 'spark', 'tableau'],
#  183: ['illustrator',
#   'graphic design',
#   'adobe xd',
#   'interaction design',
#   'uiux design'],
#  184: ['html', 'css', 'nextjs'],
#  185: ['react', 'css', 'postgresql', 'nodejs', 'vue', 'nextjs'],
#  186: ['machine learning', 'tensorflow', 'computer vision', 'deep learning'],
#  187: ['ms excel',
#   'quickbooks',
#   'accounting',
#   'financial modeling',
#   'business analysis',
#   'tally'],
#  188: ['computer vision',
#   'deep learning',
#   'data science',
#   'scikitlearn',
#   'pytorch'],
#  189: ['pytorch', 'agentic ai', 'scikitlearn', 'machine learning', 'gen ai'],
#  190: ['flutter', 'dart', 'firebase', 'react native', 'android'],
#  191: ['seo',
#   'hubspot',
#   'social media strategy',
#   'content writing',
#   'mailchimp'],
#  192: ['kotlin', 'swift', 'flutter', 'ios', 'firebase', 'dart'],
#  193: ['ansible', 'azure', 'docker'],
#  194: ['tensorflow', 'machine learning', 'gen ai'],
#  195: ['nlp', 'deep learning', 'mlops'],
#  196: ['aws', 'kubernetes', 'infrastructure as code'],
#  197: ['interaction design', 'canva', 'graphic design', 'illustrator'],
#  198: ['excel', 'powerbi', 'snowflake', 'sql'],
#  199: ['figma',
#   'uiux design',
#   'canva',
#   'graphic design',
#   'adobe xd',
#   'illustrator'],
#  200: ['react native', 'kotlin', 'firebase', 'swift', 'android'],
#  201: ['quickbooks', 'tally', 'business analysis', 'accounting', 'ms excel'],
#  202: ['kafka', 'hadoop', 'snowflake', 'airflow', 'spark', 'sql'],
#  203: ['kafka', 'airflow', 'excel', 'etl', 'hadoop', 'snowflake'],
#  204: ['nodejs', 'html', 'postgresql'],
#  205: ['jenkins', 'gcp', 'aws', 'docker', 'kubernetes', 'ansible'],
#  206: ['flutter', 'kotlin', 'react native'],
#  207: ['azure',
#   'kubernetes',
#   'infrastructure as code',
#   'gcp',
#   'jenkins',
#   'cicd'],
#  208: ['flutter', 'ios', 'dart'],
#  209: ['react native', 'flutter', 'ios', 'swift'],
#  210: ['seo',
#   'digital marketing',
#   'social media strategy',
#   'mailchimp',
#   'google analytics',
#   'market research'],
#  211: ['etl', 'excel', 'airflow'],
#  212: ['javascript', 'nodejs', 'django', 'vue', 'css'],
#  213: ['ansible', 'terraform', 'docker'],
#  214: ['react', 'sql', 'angular'],
#  215: ['gcp', 'docker', 'cicd', 'infrastructure as code', 'azure'],
#  216: ['mongodb', 'postgresql', 'express', 'sql', 'flask'],
#  217: ['illustrator', 'adobe xd', 'interaction design', 'uiux design'],
#  218: ['vue', 'javascript', 'react', 'django'],
#  219: ['content writing', 'google analytics', 'hubspot'],
#  220: ['tally', 'ms excel', 'business analysis', 'quickbooks'],
#  221: ['tally',
#   'accounting',
#   'quickbooks',
#   'financial modeling',
#   'business analysis'],
#  222: ['computer vision', 'mlops', 'data science', 'machine learning'],
#  223: ['computer vision',
#   'scikitlearn',
#   'mlops',
#   'pytorch',
#   'gen ai',
#   'tensorflow'],
#  224: ['adobe xd', 'uiux design', 'canva', 'interaction design'],
#  225: ['seo',
#   'mailchimp',
#   'hubspot',
#   'social media strategy',
#   'google analytics',
#   'digital marketing'],
#  226: ['jenkins', 'cicd', 'terraform', 'infrastructure as code'],
#  227: ['kubernetes', 'terraform', 'gcp', 'azure', 'ansible', 'aws'],
#  228: ['css', 'javascript', 'angular', 'express', 'html', 'react'],
#  229: ['ms excel', 'business analysis', 'quickbooks', 'financial modeling'],
#  230: ['figma', 'interaction design', 'adobe xd', 'graphic design'],
#  231: ['aws', 'cicd', 'docker', 'azure', 'ansible'],
#  232: ['sql', 'kafka', 'powerbi'],
#  233: ['ansible', 'jenkins', 'aws'],
#  234: ['canva', 'photoshop', 'adobe xd', 'illustrator', 'interaction design'],
#  235: ['django', 'nextjs', 'nodejs', 'vue'],
#  236: ['risk analysis', 'tally', 'quickbooks'],
#  237: ['digital marketing',
#   'content writing',
#   'market research',
#   'social media strategy',
#   'seo'],
#  238: ['google analytics',
#   'seo',
#   'social media strategy',
#   'mailchimp',
#   'hubspot'],
#  239: ['market research', 'mailchimp', 'google analytics', 'hubspot', 'seo'],
#  240: ['powerbi', 'spark', 'tableau', 'airflow'],
#  241: ['gen ai', 'machine learning', 'deep learning', 'mlops'],
#  242: ['ansible', 'jenkins', 'docker', 'terraform', 'azure'],
#  243: ['adobe xd', 'interaction design', 'figma'],
#  244: ['ios', 'dart', 'react native', 'kotlin', 'firebase'],
#  245: ['powerbi', 'excel', 'kafka', 'snowflake', 'etl', 'sql'],
#  246: ['excel', 'snowflake', 'powerbi', 'etl', 'spark'],
#  247: ['illustrator',
#   'adobe xd',
#   'interaction design',
#   'figma',
#   'graphic design',
#   'uiux design'],
#  248: ['sql', 'flask', 'django', 'vue', 'spring', 'express'],
#  249: ['illustrator',
#   'adobe xd',
#   'figma',
#   'uiux design',
#   'interaction design',
#   'graphic design'],
#  250: ['vue', 'django', 'css', 'javascript'],
#  251: ['kafka', 'excel', 'powerbi'],
#  252: ['react', 'spring', 'vue'],
#  253: ['accounting', 'financial modeling', 'business analysis'],
#  254: ['accounting', 'ms excel', 'tally', 'financial modeling'],
#  255: ['android', 'flutter', 'ios', 'react native', 'firebase'],
#  256: ['quickbooks',
#   'risk analysis',
#   'ms excel',
#   'tally',
#   'business analysis',
#   'accounting'],
#  257: ['figma', 'interaction design', 'graphic design'],
#  258: ['html', 'nodejs', 'css', 'sql', 'spring', 'javascript'],
#  259: ['docker', 'ansible', 'azure'],
#  260: ['financial modeling',
#   'tally',
#   'business analysis',
#   'ms excel',
#   'accounting',
#   'risk analysis'],
#  261: ['risk analysis',
#   'accounting',
#   'financial modeling',
#   'quickbooks',
#   'business analysis',
#   'ms excel'],
#  262: ['swift', 'kotlin', 'firebase', 'flutter'],
#  263: ['interaction design',
#   'canva',
#   'graphic design',
#   'uiux design',
#   'illustrator',
#   'adobe xd'],
#  264: ['express', 'sql', 'postgresql', 'nextjs'],
#  265: ['nodejs', 'html', 'django', 'angular', 'mongodb', 'css'],
#  266: ['interaction design', 'canva', 'photoshop', 'figma'],
#  267: ['risk analysis', 'quickbooks', 'tally'],
#  268: ['risk analysis', 'business analysis', 'ms excel', 'accounting'],
#  269: ['data science',
#   'tensorflow',
#   'scikitlearn',
#   'computer vision',
#   'machine learning',
#   'deep learning'],
#  270: ['kotlin', 'android', 'flutter', 'swift', 'react native', 'firebase'],
#  271: ['ms excel',
#   'risk analysis',
#   'business analysis',
#   'financial modeling',
#   'accounting'],
#  272: ['jenkins', 'gcp', 'kubernetes', 'aws', 'docker', 'azure'],
#  273: ['risk analysis', 'business analysis', 'accounting'],
#  274: ['excel', 'sql', 'tableau', 'etl'],
#  275: ['mongodb', 'html', 'spring', 'nodejs', 'angular'],
#  276: ['kubernetes',
#   'azure',
#   'cicd',
#   'aws',
#   'terraform',
#   'infrastructure as code'],
#  277: ['adobe xd', 'uiux design', 'figma', 'illustrator'],
#  278: ['react native', 'flutter', 'firebase'],
#  279: ['excel', 'spark', 'tableau'],
#  280: ['dart', 'firebase', 'kotlin', 'swift', 'android'],
#  281: ['business analysis', 'quickbooks', 'accounting', 'ms excel', 'tally'],
#  282: ['quickbooks', 'ms excel', 'risk analysis'],
#  283: ['gen ai', 'data science', 'tensorflow'],
#  284: ['flask', 'mongodb', 'nextjs', 'sql', 'javascript', 'angular'],
#  285: ['social media strategy', 'market research', 'google analytics'],
#  286: ['kubernetes', 'jenkins', 'infrastructure as code'],
#  287: ['graphic design', 'adobe xd', 'interaction design', 'illustrator'],
#  288: ['accounting',
#   'business analysis',
#   'quickbooks',
#   'tally',
#   'financial modeling',
#   'ms excel'],
#  289: ['cicd', 'ansible', 'terraform', 'azure'],
#  290: ['social media strategy', 'seo', 'mailchimp'],
#  291: ['tableau', 'hadoop', 'spark', 'powerbi'],
#  292: ['interaction design',
#   'adobe xd',
#   'canva',
#   'figma',
#   'graphic design',
#   'illustrator'],
#  293: ['financial modeling', 'business analysis', 'tally'],
#  294: ['react', 'angular', 'spring', 'nextjs', 'sql'],
#  295: ['excel', 'airflow', 'etl', 'tableau', 'hadoop', 'powerbi'],
#  296: ['social media strategy',
#   'seo',
#   'google analytics',
#   'market research',
#   'content writing'],
#  297: ['jenkins', 'infrastructure as code', 'cicd', 'gcp'],
#  298: ['excel', 'etl', 'snowflake', 'spark', 'sql'],
#  299: ['angular', 'nextjs', 'postgresql', 'django'],
#  300: ['firebase', 'react native', 'ios', 'kotlin', 'swift', 'dart'],
#  301: ['airflow', 'tableau', 'hadoop', 'excel', 'spark'],
#  302: ['financial modeling',
#   'quickbooks',
#   'risk analysis',
#   'business analysis',
#   'tally'],
#  303: ['infrastructure as code', 'aws', 'azure', 'jenkins', 'cicd'],
#  304: ['azure', 'terraform', 'jenkins'],
#  305: ['react native', 'ios', 'flutter', 'swift', 'firebase'],
#  306: ['kafka', 'sql', 'excel', 'spark'],
#  307: ['tally', 'ms excel', 'risk analysis'],
#  308: ['accounting',
#   'business analysis',
#   'ms excel',
#   'quickbooks',
#   'financial modeling'],
#  309: ['kotlin', 'dart', 'flutter', 'android', 'ios', 'swift'],
#  310: ['docker', 'terraform', 'infrastructure as code', 'gcp', 'azure'],
#  311: ['deep learning', 'gen ai', 'computer vision', 'machine learning'],
#  312: ['javascript', 'django', 'express', 'mongodb'],
#  313: ['docker', 'gcp', 'kubernetes'],
#  314: ['javascript', 'postgresql', 'nodejs', 'angular', 'vue'],
#  315: ['photoshop', 'figma', 'graphic design', 'illustrator', 'uiux design'],
#  316: ['social media strategy',
#   'digital marketing',
#   'seo',
#   'google analytics',
#   'mailchimp',
#   'hubspot'],
#  317: ['spark', 'hadoop', 'etl'],
#  318: ['interaction design', 'graphic design', 'uiux design', 'figma'],
#  319: ['content writing',
#   'digital marketing',
#   'social media strategy',
#   'google analytics',
#   'seo'],
#  320: ['kotlin', 'dart', 'swift'],
#  321: ['risk analysis',
#   'accounting',
#   'ms excel',
#   'quickbooks',
#   'financial modeling',
#   'tally'],
#  322: ['business analysis',
#   'financial modeling',
#   'tally',
#   'quickbooks',
#   'ms excel'],
#  323: ['tally', 'ms excel', 'business analysis'],
#  324: ['risk analysis', 'accounting', 'tally', 'business analysis'],
#  325: ['django', 'sql', 'mongodb', 'vue', 'nextjs'],
#  326: ['express', 'flask', 'vue'],
#  327: ['mailchimp',
#   'market research',
#   'google analytics',
#   'social media strategy',
#   'hubspot',
#   'seo'],
#  328: ['computer vision', 'pytorch', 'gen ai'],
#  329: ['firebase', 'ios', 'kotlin', 'flutter', 'swift', 'android'],
#  330: ['flask', 'spring', 'react', 'sql', 'mongodb', 'angular'],
#  331: ['photoshop',
#   'canva',
#   'graphic design',
#   'interaction design',
#   'uiux design'],
#  332: ['figma', 'uiux design', 'adobe xd'],
#  333: ['illustrator', 'photoshop', 'adobe xd'],
#  334: ['excel', 'snowflake', 'etl'],
#  335: ['infrastructure as code', 'terraform', 'jenkins'],
#  336: ['quickbooks',
#   'financial modeling',
#   'risk analysis',
#   'business analysis',
#   'ms excel',
#   'accounting'],
#  337: ['spark', 'kafka', 'excel', 'tableau', 'powerbi', 'airflow'],
#  338: ['scikitlearn', 'mlops', 'pytorch', 'computer vision'],
#  339: ['docker', 'ansible', 'terraform'],
#  340: ['data science',
#   'pytorch',
#   'deep learning',
#   'machine learning',
#   'scikitlearn'],
#  341: ['interaction design', 'adobe xd', 'photoshop', 'uiux design'],
#  342: ['firebase', 'kotlin', 'ios', 'react native'],
#  343: ['terraform', 'ansible', 'cicd', 'aws', 'jenkins', 'docker'],
#  344: ['business analysis', 'ms excel', 'financial modeling', 'tally'],
#  345: ['canva', 'uiux design', 'photoshop'],
#  346: ['html', 'nodejs', 'javascript', 'vue'],
#  347: ['sql', 'css', 'vue', 'react', 'spring'],
#  348: ['infrastructure as code', 'cicd', 'kubernetes'],
#  349: ['ms excel',
#   'financial modeling',
#   'quickbooks',
#   'business analysis',
#   'risk analysis'],
#  350: ['seo', 'digital marketing', 'google analytics', 'hubspot'],
#  351: ['social media strategy', 'hubspot', 'mailchimp', 'market research'],
#  352: ['financial modeling', 'business analysis', 'quickbooks', 'ms excel'],
#  353: ['hadoop', 'excel', 'etl'],
#  354: ['dart', 'swift', 'android'],
#  355: ['kubernetes', 'aws', 'terraform', 'cicd'],
#  356: ['express', 'spring', 'react', 'mongodb', 'sql', 'flask'],
#  357: ['airflow', 'tableau', 'excel', 'hadoop', 'powerbi'],
#  358: ['content writing',
#   'digital marketing',
#   'social media strategy',
#   'google analytics'],
#  359: ['docker', 'cicd', 'infrastructure as code', 'azure', 'kubernetes'],
#  360: ['snowflake', 'tableau', 'sql'],
#  361: ['digital marketing', 'social media strategy', 'seo'],
#  362: ['illustrator', 'uiux design', 'adobe xd'],
#  363: ['mailchimp', 'digital marketing', 'hubspot', 'market research', 'seo'],
#  364: ['vue', 'react', 'mongodb', 'sql', 'nextjs', 'nodejs'],
#  365: ['adobe xd', 'canva', 'graphic design'],
#  366: ['firebase', 'ios', 'kotlin', 'react native', 'android', 'swift'],
#  367: ['hubspot', 'google analytics', 'mailchimp'],
#  368: ['figma', 'illustrator', 'uiux design'],
#  369: ['graphic design',
#   'uiux design',
#   'interaction design',
#   'figma',
#   'canva',
#   'photoshop'],
#  370: ['digital marketing', 'mailchimp', 'social media strategy'],
#  371: ['interaction design',
#   'graphic design',
#   'illustrator',
#   'photoshop',
#   'uiux design'],
#  372: ['excel', 'tableau', 'spark'],
#  373: ['flask', 'nodejs', 'sql', 'react'],
#  374: ['jenkins', 'azure', 'aws', 'cicd', 'terraform'],
#  375: ['angular', 'mongodb', 'css', 'express', 'django', 'react'],
#  376: ['seo', 'hubspot', 'digital marketing', 'social media strategy'],
#  377: ['javascript', 'flask', 'django'],
#  378: ['hadoop', 'sql', 'kafka', 'etl'],
#  379: ['dart', 'android', 'react native', 'swift', 'kotlin'],
#  380: ['adobe xd', 'figma', 'uiux design', 'canva'],
#  381: ['vue', 'spring', 'react'],
#  382: ['financial modeling',
#   'ms excel',
#   'accounting',
#   'risk analysis',
#   'tally',
#   'quickbooks'],
#  383: ['computer vision', 'scikitlearn', 'gen ai', 'mlops'],
#  384: ['illustrator', 'adobe xd', 'uiux design'],
#  385: ['graphic design', 'adobe xd', 'uiux design', 'interaction design'],
#  386: ['tally',
#   'accounting',
#   'quickbooks',
#   'financial modeling',
#   'business analysis'],
#  387: ['hubspot', 'content writing', 'digital marketing'],
#  388: ['digital marketing',
#   'market research',
#   'mailchimp',
#   'social media strategy'],
#  389: ['flutter', 'react native', 'dart', 'swift'],
#  390: ['vue', 'html', 'django'],
#  391: ['spark', 'kafka', 'etl', 'hadoop', 'excel', 'sql'],
#  392: ['flutter', 'swift', 'android'],
#  393: ['firebase', 'flutter', 'swift'],
#  394: ['kotlin', 'firebase', 'dart', 'flutter', 'react native'],
#  395: ['illustrator',
#   'photoshop',
#   'adobe xd',
#   'interaction design',
#   'graphic design'],
#  396: ['risk analysis',
#   'quickbooks',
#   'tally',
#   'business analysis',
#   'accounting',
#   'ms excel'],
#  397: ['airflow', 'kafka', 'hadoop', 'snowflake', 'sql'],
#  398: ['agentic ai', 'machine learning', 'scikitlearn', 'gen ai', 'nlp'],
#  399: ['aws', 'infrastructure as code', 'terraform', 'gcp', 'docker', 'azure'],
#  400: ['uiux design', 'interaction design', 'graphic design'],
#  401: ['risk analysis',
#   'accounting',
#   'quickbooks',
#   'financial modeling',
#   'ms excel'],
#  402: ['computer vision', 'pytorch', 'agentic ai'],
#  403: ['accounting', 'ms excel', 'risk analysis'],
#  404: ['vue', 'spring', 'html'],
#  405: ['figma',
#   'photoshop',
#   'canva',
#   'illustrator',
#   'adobe xd',
#   'uiux design'],
#  406: ['tensorflow', 'mlops', 'agentic ai', 'gen ai'],
#  407: ['financial modeling', 'ms excel', 'tally', 'accounting'],
#  408: ['ms excel',
#   'business analysis',
#   'quickbooks',
#   'tally',
#   'financial modeling',
#   'risk analysis'],
#  409: ['data science', 'tensorflow', 'nlp', 'scikitlearn'],
#  410: ['spring', 'html', 'vue'],
#  411: ['android', 'ios', 'react native', 'kotlin'],
#  412: ['gcp', 'aws', 'terraform'],
#  413: ['risk analysis',
#   'business analysis',
#   'ms excel',
#   'quickbooks',
#   'tally'],
#  414: ['sql', 'mongodb', 'css', 'vue', 'javascript'],
#  415: ['uiux design', 'photoshop', 'canva'],
#  416: ['digital marketing', 'market research', 'social media strategy'],
#  417: ['spark', 'powerbi', 'snowflake', 'hadoop', 'etl'],
#  418: ['gen ai', 'data science', 'pytorch'],
#  419: ['firebase', 'ios', 'dart', 'android', 'kotlin'],
#  420: ['angular', 'javascript', 'django', 'express'],
#  421: ['computer vision', 'tensorflow', 'agentic ai'],
#  422: ['dart', 'ios', 'kotlin', 'flutter'],
#  423: ['angular', 'react', 'spring', 'express', 'django'],
#  424: ['seo', 'social media strategy', 'google analytics'],
#  425: ['photoshop', 'interaction design', 'graphic design'],
#  426: ['sql', 'excel', 'hadoop', 'kafka', 'tableau', 'etl'],
#  427: ['aws', 'terraform', 'docker', 'infrastructure as code'],
#  428: ['javascript', 'nextjs', 'postgresql', 'angular'],
#  429: ['sql', 'hadoop', 'etl', 'snowflake'],
#  430: ['sql', 'excel', 'tableau', 'kafka', 'hadoop', 'spark'],
#  431: ['powerbi', 'sql', 'etl', 'spark', 'kafka', 'snowflake'],
#  432: ['interaction design', 'adobe xd', 'figma'],
#  433: ['sql', 'flask', 'nodejs', 'mongodb', 'javascript'],
#  434: ['azure', 'docker', 'cicd', 'infrastructure as code', 'ansible'],
#  435: ['infrastructure as code', 'ansible', 'jenkins', 'cicd', 'terraform'],
#  436: ['digital marketing',
#   'content writing',
#   'hubspot',
#   'social media strategy',
#   'mailchimp'],
#  437: ['interaction design', 'illustrator', 'adobe xd', 'figma'],
#  438: ['illustrator',
#   'uiux design',
#   'interaction design',
#   'photoshop',
#   'graphic design'],
#  439: ['illustrator',
#   'canva',
#   'photoshop',
#   'interaction design',
#   'adobe xd',
#   'uiux design'],
#  440: ['hubspot', 'social media strategy', 'content writing'],
#  441: ['tensorflow',
#   'scikitlearn',
#   'computer vision',
#   'nlp',
#   'machine learning'],
#  442: ['express', 'angular', 'html'],
#  443: ['financial modeling', 'tally', 'accounting'],
#  444: ['android', 'swift', 'firebase', 'flutter', 'ios', 'kotlin'],
#  445: ['illustrator', 'uiux design', 'figma', 'photoshop'],
#  446: ['dart', 'swift', 'android', 'react native', 'firebase'],
#  447: ['powerbi', 'tableau', 'hadoop', 'spark', 'snowflake', 'excel'],
#  448: ['flutter', 'android', 'ios'],
#  449: ['cicd', 'infrastructure as code', 'jenkins'],
#  450: ['mongodb', 'react', 'vue', 'django'],
#  451: ['adobe xd',
#   'illustrator',
#   'figma',
#   'graphic design',
#   'interaction design',
#   'photoshop'],
#  452: ['gen ai',
#   'data science',
#   'nlp',
#   'computer vision',
#   'deep learning',
#   'scikitlearn'],
#  453: ['canva',
#   'interaction design',
#   'adobe xd',
#   'photoshop',
#   'graphic design',
#   'figma'],
#  454: ['react native', 'android', 'swift', 'ios', 'flutter'],
#  455: ['social media strategy',
#   'digital marketing',
#   'google analytics',
#   'mailchimp',
#   'seo',
#   'content writing'],
#  456: ['ms excel',
#   'risk analysis',
#   'business analysis',
#   'tally',
#   'financial modeling'],
#  457: ['social media strategy',
#   'mailchimp',
#   'market research',
#   'hubspot',
#   'google analytics'],
#  458: ['data science', 'machine learning', 'agentic ai', 'computer vision'],
#  459: ['scikitlearn', 'nlp', 'mlops'],
#  460: ['adobe xd', 'interaction design', 'canva', 'illustrator'],
#  461: ['azure', 'jenkins', 'cicd'],
#  462: ['content writing',
#   'mailchimp',
#   'hubspot',
#   'seo',
#   'google analytics',
#   'market research'],
#  463: ['agentic ai',
#   'deep learning',
#   'scikitlearn',
#   'computer vision',
#   'nlp',
#   'tensorflow'],
#  464: ['react native', 'android', 'kotlin', 'flutter', 'firebase', 'dart'],
#  465: ['canva',
#   'graphic design',
#   'figma',
#   'photoshop',
#   'adobe xd',
#   'interaction design'],
#  466: ['business analysis',
#   'financial modeling',
#   'quickbooks',
#   'risk analysis',
#   'tally',
#   'ms excel'],
#  467: ['firebase', 'flutter', 'ios', 'swift'],
#  468: ['ansible', 'gcp', 'docker', 'aws'],
#  469: ['spring', 'nodejs', 'vue', 'sql', 'react', 'html'],
#  470: ['pytorch', 'computer vision', 'gen ai', 'tensorflow', 'mlops'],
#  471: ['interaction design',
#   'illustrator',
#   'uiux design',
#   'figma',
#   'adobe xd'],
#  472: ['terraform', 'cicd', 'gcp'],
#  473: ['spark', 'tableau', 'excel', 'sql'],
#  474: ['docker', 'aws', 'ansible'],
#  475: ['swift', 'firebase', 'dart'],
#  476: ['tableau', 'spark', 'sql', 'excel', 'etl', 'airflow'],
#  477: ['adobe xd', 'photoshop', 'graphic design'],
#  478: ['hadoop', 'spark', 'airflow', 'kafka', 'tableau', 'snowflake'],
#  479: ['quickbooks',
#   'risk analysis',
#   'business analysis',
#   'ms excel',
#   'tally'],
#  480: ['canva',
#   'illustrator',
#   'photoshop',
#   'uiux design',
#   'interaction design'],
#  481: ['hadoop', 'kafka', 'tableau'],
#  482: ['firebase', 'kotlin', 'swift', 'ios'],
#  483: ['risk analysis',
#   'tally',
#   'financial modeling',
#   'business analysis',
#   'accounting'],
#  484: ['adobe xd', 'photoshop', 'illustrator'],
#  485: ['interaction design',
#   'figma',
#   'uiux design',
#   'canva',
#   'photoshop',
#   'illustrator'],
#  486: ['react', 'css', 'express', 'spring'],
#  487: ['android', 'dart', 'swift', 'firebase'],
#  488: ['business analysis', 'financial modeling', 'ms excel'],
#  489: ['cicd', 'azure', 'docker'],
#  490: ['docker', 'jenkins', 'terraform', 'infrastructure as code', 'azure'],
#  491: ['infrastructure as code', 'kubernetes', 'ansible'],
#  492: ['photoshop', 'figma', 'interaction design', 'illustrator'],
#  493: ['tally',
#   'ms excel',
#   'quickbooks',
#   'accounting',
#   'risk analysis',
#   'financial modeling'],
#  494: ['figma',
#   'illustrator',
#   'adobe xd',
#   'photoshop',
#   'uiux design',
#   'graphic design'],
#  495: ['powerbi', 'tableau', 'spark', 'etl', 'airflow'],
#  496: ['market research', 'seo', 'content writing'],
#  497: ['ios', 'dart', 'firebase', 'react native'],
#  498: ['etl', 'excel', 'hadoop', 'snowflake', 'kafka'],
#  499: ['postgresql', 'react', 'express', 'angular'],
#  500: ['computer vision',
#   'machine learning',
#   'data science',
#   'pytorch',
#   'gen ai',
#   'tensorflow'],
#  501: ['powerbi', 'tableau', 'hadoop'],
#  502: ['quickbooks',
#   'financial modeling',
#   'business analysis',
#   'risk analysis'],
#  503: ['tableau', 'etl', 'snowflake'],
#  504: ['canva', 'interaction design', 'uiux design'],
#  505: ['nlp',
#   'pytorch',
#   'computer vision',
#   'deep learning',
#   'gen ai',
#   'machine learning'],
#  506: ['excel', 'snowflake', 'etl', 'kafka', 'sql'],
#  507: ['swift', 'firebase', 'flutter'],
#  508: ['spark', 'hadoop', 'powerbi', 'airflow', 'etl'],
#  509: ['content writing',
#   'social media strategy',
#   'mailchimp',
#   'seo',
#   'google analytics'],
#  510: ['google analytics',
#   'digital marketing',
#   'social media strategy',
#   'market research',
#   'mailchimp'],
#  511: ['machine learning', 'tensorflow', 'deep learning', 'pytorch', 'mlops'],
#  512: ['business analysis', 'risk analysis', 'quickbooks'],
#  513: ['swift', 'dart', 'android', 'kotlin', 'react native'],
#  514: ['infrastructure as code',
#   'azure',
#   'cicd',
#   'gcp',
#   'terraform',
#   'jenkins'],
#  515: ['illustrator', 'adobe xd', 'canva', 'uiux design', 'figma'],
#  516: ['figma',
#   'interaction design',
#   'graphic design',
#   'photoshop',
#   'adobe xd',
#   'uiux design'],
#  517: ['jenkins', 'aws', 'gcp', 'azure', 'infrastructure as code'],
#  518: ['firebase', 'ios', 'dart', 'flutter', 'react native'],
#  519: ['cicd', 'docker', 'ansible', 'jenkins', 'gcp', 'kubernetes'],
#  520: ['mailchimp',
#   'market research',
#   'digital marketing',
#   'seo',
#   'social media strategy',
#   'content writing'],
#  521: ['angular', 'sql', 'html'],
#  522: ['spark', 'airflow', 'powerbi'],
#  523: ['hubspot', 'seo', 'content writing', 'google analytics'],
#  524: ['infrastructure as code', 'gcp', 'kubernetes', 'jenkins'],
#  525: ['sql', 'snowflake', 'etl'],
#  526: ['flutter', 'kotlin', 'react native', 'ios'],
#  527: ['canva', 'uiux design', 'illustrator', 'graphic design'],
#  528: ['seo', 'market research', 'content writing', 'social media strategy'],
#  529: ['social media strategy', 'mailchimp', 'seo', 'content writing'],
#  530: ['kubernetes', 'infrastructure as code', 'aws', 'terraform', 'gcp'],
#  531: ['ms excel', 'business analysis', 'risk analysis'],
#  532: ['photoshop',
#   'uiux design',
#   'figma',
#   'illustrator',
#   'interaction design'],
#  533: ['ios', 'swift', 'firebase', 'react native'],
#  534: ['swift', 'dart', 'android', 'react native', 'flutter'],
#  535: ['sql', 'spark', 'tableau', 'powerbi', 'excel', 'kafka'],
#  536: ['tableau', 'airflow', 'spark', 'kafka', 'etl'],
#  537: ['computer vision', 'data science', 'tensorflow'],
#  538: ['uiux design', 'canva', 'illustrator'],
#  539: ['business analysis',
#   'risk analysis',
#   'financial modeling',
#   'accounting',
#   'quickbooks',
#   'ms excel'],
#  540: ['cicd', 'docker', 'ansible'],
#  541: ['adobe xd',
#   'interaction design',
#   'figma',
#   'uiux design',
#   'photoshop',
#   'graphic design'],
#  542: ['dart', 'react native', 'flutter'],
#  543: ['seo', 'social media strategy', 'digital marketing', 'content writing'],
#  544: ['react', 'javascript', 'mongodb', 'css'],
#  545: ['etl', 'excel', 'sql'],
#  546: ['nlp', 'pytorch', 'scikitlearn'],
#  547: ['angular', 'javascript', 'vue'],
#  548: ['azure', 'terraform', 'infrastructure as code', 'kubernetes', 'aws'],
#  549: ['uiux design', 'canva', 'adobe xd'],
#  550: ['aws', 'gcp', 'docker', 'infrastructure as code'],
#  551: ['flask', 'react', 'django', 'angular', 'mongodb'],
#  552: ['android', 'ios', 'swift', 'dart'],
#  553: ['infrastructure as code', 'azure', 'kubernetes', 'terraform', 'gcp'],
#  554: ['ios', 'android', 'dart', 'flutter'],
#  555: ['css', 'nextjs', 'express', 'spring', 'postgresql', 'django'],
#  556: ['cicd', 'aws', 'gcp'],
#  557: ['html', 'sql', 'django', 'react', 'vue', 'css'],
#  558: ['spring', 'css', 'angular'],
#  559: ['postgresql', 'spring', 'react', 'express', 'html', 'flask'],
#  560: ['deep learning', 'nlp', 'agentic ai'],
#  561: ['vue', 'angular', 'html', 'spring', 'express'],
#  562: ['tally',
#   'accounting',
#   'risk analysis',
#   'quickbooks',
#   'financial modeling'],
#  563: ['etl', 'powerbi', 'snowflake', 'tableau'],
#  564: ['kotlin', 'dart', 'swift'],
#  565: ['graphic design', 'canva', 'interaction design'],
#  566: ['react native', 'kotlin', 'ios'],
#  567: ['quickbooks', 'ms excel', 'risk analysis'],
#  568: ['figma',
#   'photoshop',
#   'graphic design',
#   'canva',
#   'illustrator',
#   'uiux design'],
#  569: ['content writing', 'social media strategy', 'market research'],
#  570: ['android', 'react native', 'firebase', 'dart'],
#  571: ['spark', 'tableau', 'kafka', 'etl', 'hadoop'],
#  572: ['airflow', 'hadoop', 'excel', 'tableau'],
#  573: ['mlops', 'data science', 'scikitlearn'],
#  574: ['computer vision', 'gen ai', 'agentic ai', 'mlops'],
#  575: ['jenkins', 'aws', 'ansible', 'infrastructure as code', 'gcp'],
#  576: ['react native', 'ios', 'kotlin', 'swift'],
#  577: ['ios', 'swift', 'kotlin', 'dart'],
#  578: ['hadoop', 'spark', 'snowflake', 'kafka', 'airflow', 'etl'],
#  579: ['swift', 'react native', 'ios', 'flutter'],
#  580: ['airflow', 'hadoop', 'kafka'],
#  581: ['ios', 'react native', 'dart', 'kotlin', 'flutter', 'swift'],
#  582: ['mailchimp',
#   'google analytics',
#   'market research',
#   'digital marketing',
#   'hubspot'],
#  583: ['deep learning',
#   'scikitlearn',
#   'agentic ai',
#   'nlp',
#   'gen ai',
#   'tensorflow'],
#  584: ['flutter', 'dart', 'android', 'swift'],
#  585: ['seo',
#   'hubspot',
#   'google analytics',
#   'digital marketing',
#   'social media strategy',
#   'mailchimp'],
#  586: ['mongodb', 'angular', 'spring', 'vue', 'postgresql', 'flask'],
#  587: ['sql', 'javascript', 'postgresql', 'spring', 'mongodb'],
#  588: ['uiux design',
#   'illustrator',
#   'figma',
#   'graphic design',
#   'photoshop',
#   'canva'],
#  589: ['photoshop', 'illustrator', 'interaction design', 'canva'],
#  590: ['ms excel',
#   'business analysis',
#   'financial modeling',
#   'quickbooks',
#   'accounting'],
#  591: ['terraform', 'azure', 'kubernetes', 'ansible', 'gcp'],
#  592: ['mongodb', 'react', 'django', 'express', 'angular', 'spring'],
#  593: ['market research',
#   'content writing',
#   'google analytics',
#   'mailchimp',
#   'hubspot',
#   'digital marketing'],
#  594: ['react', 'postgresql', 'vue', 'express', 'css'],
#  595: ['interaction design', 'figma', 'uiux design', 'adobe xd'],
#  596: ['airflow', 'tableau', 'spark', 'sql', 'hadoop'],
#  597: ['market research',
#   'mailchimp',
#   'content writing',
#   'google analytics',
#   'digital marketing',
#   'social media strategy'],
#  598: ['android', 'flutter', 'swift', 'kotlin', 'dart'],
#  599: ['flask', 'express', 'sql', 'javascript', 'postgresql', 'angular'],
#  600: ['figma',
#   'adobe xd',
#   'uiux design',
#   'canva',
#   'graphic design',
#   'illustrator'],
#  601: ['jenkins',
#   'gcp',
#   'azure',
#   'kubernetes',
#   'infrastructure as code',
#   'terraform'],
#  602: ['react', 'angular', 'html'],
#  603: ['cicd', 'docker', 'jenkins'],
#  604: ['express', 'mongodb', 'nextjs', 'postgresql'],
#  605: ['snowflake', 'kafka', 'etl', 'tableau', 'hadoop'],
#  606: ['css', 'nodejs', 'html'],
#  607: ['excel', 'tableau', 'etl', 'spark', 'airflow', 'snowflake'],
#  608: ['financial modeling',
#   'accounting',
#   'risk analysis',
#   'tally',
#   'quickbooks'],
#  609: ['django', 'nextjs', 'react', 'html', 'css', 'mongodb'],
#  610: ['docker', 'aws', 'jenkins', 'azure', 'gcp'],
#  611: ['react native', 'firebase', 'swift', 'flutter', 'ios', 'dart'],
#  612: ['digital marketing',
#   'mailchimp',
#   'market research',
#   'google analytics',
#   'content writing'],
#  613: ['flutter', 'android', 'react native', 'firebase', 'dart', 'ios'],
#  614: ['photoshop', 'uiux design', 'canva', 'graphic design', 'figma'],
#  615: ['financial modeling', 'accounting', 'risk analysis', 'quickbooks'],
#  616: ['jenkins',
#   'terraform',
#   'infrastructure as code',
#   'docker',
#   'cicd',
#   'kubernetes'],
#  617: ['kotlin', 'firebase', 'android', 'ios'],
#  618: ['google analytics', 'seo', 'mailchimp', 'social media strategy'],
#  619: ['hadoop', 'excel', 'airflow', 'powerbi', 'etl'],
#  620: ['ms excel', 'accounting', 'business analysis', 'quickbooks', 'tally'],
#  621: ['spring', 'css', 'django', 'vue', 'nextjs'],
#  622: ['uiux design',
#   'interaction design',
#   'illustrator',
#   'photoshop',
#   'graphic design'],
#  623: ['html', 'sql', 'css'],
#  624: ['figma', 'interaction design', 'canva'],
#  625: ['kubernetes', 'cicd', 'ansible', 'terraform', 'gcp'],
#  626: ['flutter', 'ios', 'dart', 'swift'],
#  627: ['firebase', 'android', 'flutter'],
#  628: ['graphic design', 'interaction design', 'figma'],
#  629: ['express', 'angular', 'flask', 'vue', 'django'],
#  630: ['tableau', 'sql', 'powerbi', 'kafka'],
#  631: ['scikitlearn', 'pytorch', 'agentic ai', 'gen ai'],
#  632: ['scikitlearn', 'gen ai', 'agentic ai', 'computer vision'],
#  633: ['sql', 'spark', 'excel', 'tableau', 'powerbi', 'airflow'],
#  634: ['azure', 'aws', 'infrastructure as code'],
#  635: ['terraform',
#   'infrastructure as code',
#   'aws',
#   'azure',
#   'kubernetes',
#   'docker'],
#  636: ['machine learning',
#   'deep learning',
#   'agentic ai',
#   'data science',
#   'tensorflow'],
#  637: ['kubernetes',
#   'jenkins',
#   'docker',
#   'gcp',
#   'terraform',
#   'infrastructure as code'],
#  638: ['vue', 'postgresql', 'javascript'],
#  639: ['angular', 'vue', 'express', 'flask', 'spring'],
#  640: ['computer vision', 'mlops', 'pytorch'],
#  641: ['gcp',
#   'ansible',
#   'kubernetes',
#   'jenkins',
#   'infrastructure as code',
#   'aws'],
#  642: ['illustrator',
#   'photoshop',
#   'interaction design',
#   'adobe xd',
#   'uiux design',
#   'graphic design'],
#  643: ['ms excel',
#   'business analysis',
#   'risk analysis',
#   'accounting',
#   'financial modeling',
#   'quickbooks'],
#  644: ['airflow', 'powerbi', 'kafka'],
#  645: ['airflow', 'sql', 'hadoop', 'snowflake', 'powerbi', 'kafka'],
#  646: ['express', 'angular', 'react'],
#  647: ['hadoop', 'tableau', 'kafka'],
#  648: ['pytorch',
#   'gen ai',
#   'deep learning',
#   'computer vision',
#   'machine learning'],
#  649: ['photoshop', 'illustrator', 'figma'],
#  650: ['mlops', 'gen ai', 'tensorflow', 'scikitlearn', 'computer vision'],
#  651: ['html', 'javascript', 'flask', 'nodejs', 'django'],
#  652: ['quickbooks',
#   'business analysis',
#   'tally',
#   'risk analysis',
#   'financial modeling'],
#  653: ['social media strategy',
#   'market research',
#   'mailchimp',
#   'digital marketing',
#   'seo',
#   'google analytics'],
#  654: ['figma', 'photoshop', 'uiux design', 'canva'],
#  655: ['agentic ai',
#   'deep learning',
#   'scikitlearn',
#   'mlops',
#   'computer vision',
#   'nlp'],
#  656: ['market research',
#   'social media strategy',
#   'content writing',
#   'hubspot'],
#  657: ['computer vision', 'data science', 'machine learning'],
#  658: ['aws',
#   'docker',
#   'azure',
#   'infrastructure as code',
#   'gcp',
#   'kubernetes'],
#  659: ['tableau', 'snowflake', 'excel'],
#  660: ['firebase', 'kotlin', 'dart', 'swift', 'flutter'],
#  661: ['snowflake', 'tableau', 'excel', 'airflow'],
#  662: ['nextjs', 'css', 'react', 'django', 'flask', 'sql'],
#  663: ['uiux design',
#   'photoshop',
#   'canva',
#   'figma',
#   'adobe xd',
#   'interaction design'],
#  664: ['data science',
#   'machine learning',
#   'agentic ai',
#   'computer vision',
#   'pytorch'],
#  665: ['ms excel',
#   'quickbooks',
#   'business analysis',
#   'risk analysis',
#   'financial modeling',
#   'accounting'],
#  666: ['mailchimp',
#   'social media strategy',
#   'google analytics',
#   'hubspot',
#   'market research'],
#  667: ['data science',
#   'machine learning',
#   'deep learning',
#   'computer vision',
#   'gen ai'],
#  668: ['uiux design',
#   'interaction design',
#   'photoshop',
#   'illustrator',
#   'graphic design'],
#  669: ['snowflake', 'hadoop', 'airflow', 'tableau', 'excel', 'powerbi'],
#  670: ['gcp', 'aws', 'docker', 'terraform'],
#  671: ['graphic design', 'canva', 'illustrator', 'uiux design'],
#  672: ['uiux design', 'graphic design', 'illustrator', 'figma', 'adobe xd'],
#  673: ['firebase', 'dart', 'ios', 'react native', 'android', 'kotlin'],
#  674: ['postgresql', 'html', 'angular', 'react'],
#  675: ['quickbooks',
#   'tally',
#   'accounting',
#   'risk analysis',
#   'financial modeling',
#   'ms excel'],
#  676: ['ios', 'firebase', 'react native', 'android', 'swift', 'flutter'],
#  677: ['cicd', 'infrastructure as code', 'docker', 'jenkins'],
#  678: ['pytorch',
#   'computer vision',
#   'scikitlearn',
#   'deep learning',
#   'agentic ai',
#   'mlops'],
#  679: ['financial modeling',
#   'quickbooks',
#   'tally',
#   'ms excel',
#   'accounting',
#   'risk analysis'],
#  680: ['swift', 'flutter', 'android', 'dart', 'ios', 'react native'],
#  681: ['tensorflow',
#   'agentic ai',
#   'mlops',
#   'computer vision',
#   'machine learning',
#   'scikitlearn'],
#  682: ['financial modeling',
#   'business analysis',
#   'tally',
#   'ms excel',
#   'accounting'],
#  683: ['mailchimp',
#   'digital marketing',
#   'content writing',
#   'social media strategy',
#   'market research',
#   'hubspot'],
#  684: ['uiux design', 'illustrator', 'adobe xd', 'photoshop', 'figma'],
#  685: ['uiux design',
#   'photoshop',
#   'interaction design',
#   'adobe xd',
#   'illustrator',
#   'figma'],
#  686: ['ios', 'android', 'dart'],
#  687: ['excel', 'sql', 'etl', 'tableau'],
#  688: ['content writing', 'mailchimp', 'google analytics'],
#  689: ['powerbi', 'hadoop', 'airflow'],
#  690: ['flask', 'django', 'express', 'css', 'react'],
#  691: ['powerbi', 'spark', 'tableau', 'excel'],
#  692: ['flutter', 'dart', 'kotlin'],
#  693: ['canva', 'photoshop', 'uiux design', 'adobe xd', 'graphic design'],
#  694: ['illustrator',
#   'figma',
#   'graphic design',
#   'uiux design',
#   'interaction design',
#   'adobe xd'],
#  695: ['spring', 'angular', 'css', 'nodejs', 'django'],
#  696: ['jenkins', 'ansible', 'cicd', 'terraform'],
#  697: ['excel', 'airflow', 'hadoop', 'tableau'],
#  698: ['adobe xd', 'illustrator', 'canva'],
#  699: ['tableau', 'etl', 'sql'],
#  700: ['infrastructure as code', 'jenkins', 'cicd', 'azure'],
#  701: ['content writing',
#   'google analytics',
#   'hubspot',
#   'social media strategy'],
#  702: ['vue', 'django', 'react'],
#  703: ['business analysis',
#   'financial modeling',
#   'risk analysis',
#   'quickbooks',
#   'tally',
#   'ms excel'],
#  704: ['market research',
#   'content writing',
#   'hubspot',
#   'google analytics',
#   'digital marketing',
#   'seo'],
#  705: ['accounting', 'business analysis', 'tally'],
#  706: ['uiux design', 'canva', 'adobe xd', 'photoshop'],
#  707: ['adobe xd', 'graphic design', 'photoshop', 'illustrator', 'figma'],
#  708: ['hubspot',
#   'mailchimp',
#   'market research',
#   'social media strategy',
#   'content writing',
#   'digital marketing'],
#  709: ['aws', 'cicd', 'terraform'],
#  710: ['google analytics',
#   'content writing',
#   'seo',
#   'hubspot',
#   'social media strategy'],
#  711: ['interaction design',
#   'graphic design',
#   'uiux design',
#   'figma',
#   'photoshop'],
#  712: ['hubspot', 'digital marketing', 'mailchimp'],
#  713: ['illustrator', 'uiux design', 'adobe xd', 'figma'],
#  714: ['deep learning', 'tensorflow', 'scikitlearn', 'machine learning'],
#  715: ['digital marketing',
#   'content writing',
#   'market research',
#   'google analytics'],
# ...
#  763: ['excel', 'snowflake', 'hadoop', 'kafka', 'airflow', 'tableau'],
#  764: ['flask', 'spring', 'javascript', 'sql', 'css', 'vue'],
#  765: ['canva', 'adobe xd', 'illustrator'],
#  766: ['angular', 'postgresql', 'nextjs', 'react', 'javascript', 'html'],
#  767: ['accounting', 'financial modeling', 'tally'],
#  768: ['aws',
#   'docker',
#   'kubernetes',
#   'gcp',
#   'infrastructure as code',
#   'terraform'],
#  769: ['tally',
#   'quickbooks',
#   'accounting',
#   'risk analysis',
#   'business analysis'],
#  770: ['django', 'postgresql', 'vue', 'css', 'spring', 'angular'],
#  771: ['social media strategy',
#   'hubspot',
#   'seo',
#   'content writing',
#   'google analytics',
#   'digital marketing'],
#  772: ['android', 'ios', 'swift', 'flutter'],
#  773: ['spark', 'excel', 'kafka'],
#  774: ['flutter', 'dart', 'kotlin', 'ios', 'react native', 'android'],
#  775: ['data science', 'computer vision', 'mlops'],
#  776: ['angular', 'mongodb', 'javascript', 'nextjs'],
#  777: ['tensorflow',
#   'machine learning',
#   'data science',
#   'agentic ai',
#   'scikitlearn',
#   'pytorch'],
#  778: ['seo', 'mailchimp', 'social media strategy', 'market research'],
#  779: ['seo', 'content writing', 'market research'],
#  780: ['business analysis', 'accounting', 'ms excel', 'risk analysis'],
#  781: ['airflow', 'hadoop', 'spark', 'tableau', 'kafka', 'powerbi'],
#  782: ['snowflake', 'sql', 'tableau', 'etl', 'powerbi', 'hadoop'],
#  783: ['docker', 'infrastructure as code', 'cicd'],
#  784: ['mailchimp', 'content writing', 'seo'],
#  785: ['express', 'react', 'mongodb', 'javascript'],
#  786: ['photoshop', 'interaction design', 'figma', 'graphic design'],
#  787: ['kubernetes', 'gcp', 'infrastructure as code', 'aws', 'azure'],
#  788: ['mongodb', 'express', 'nextjs', 'react', 'spring', 'angular'],
#  789: ['sql', 'hadoop', 'airflow', 'kafka', 'spark', 'etl'],
#  790: ['cicd', 'docker', 'kubernetes'],
#  791: ['terraform', 'cicd', 'kubernetes', 'gcp', 'jenkins', 'azure'],
#  792: ['vue', 'css', 'mongodb', 'spring', 'express', 'django'],
#  793: ['interaction design', 'uiux design', 'figma'],
#  794: ['spark', 'tableau', 'powerbi', 'etl', 'kafka'],
#  795: ['accounting', 'quickbooks', 'risk analysis', 'financial modeling'],
#  796: ['seo', 'digital marketing', 'google analytics'],
#  797: ['google analytics',
#   'digital marketing',
#   'mailchimp',
#   'content writing',
#   'hubspot',
#   'market research'],
#  798: ['illustrator',
#   'photoshop',
#   'figma',
#   'uiux design',
#   'graphic design',
#   'interaction design'],
#  799: ['ms excel',
#   'accounting',
#   'business analysis',
#   'financial modeling',
#   'risk analysis'],
#  800: ['gen ai', 'machine learning', 'nlp'],
#  801: ['postgresql', 'react', 'nextjs', 'express'],
#  802: ['mlops',
#   'gen ai',
#   'machine learning',
#   'scikitlearn',
#   'data science',
#   'tensorflow'],
#  803: ['jenkins', 'aws', 'docker', 'ansible'],
#  804: ['mailchimp',
#   'google analytics',
#   'social media strategy',
#   'digital marketing'],
#  805: ['hubspot', 'seo', 'content writing', 'market research'],
#  806: ['mlops',
#   'machine learning',
#   'agentic ai',
#   'scikitlearn',
#   'data science'],
#  807: ['hubspot', 'social media strategy', 'digital marketing', 'seo'],
#  808: ['scikitlearn', 'pytorch', 'tensorflow', 'machine learning'],
#  809: ['azure', 'docker', 'jenkins', 'ansible'],
#  810: ['mailchimp',
#   'market research',
#   'google analytics',
#   'social media strategy',
#   'content writing',
#   'seo'],
#  811: ['digital marketing', 'content writing', 'google analytics', 'seo'],
#  812: ['market research',
#   'content writing',
#   'hubspot',
#   'social media strategy',
#   'mailchimp'],
#  813: ['social media strategy', 'seo', 'content writing'],
#  814: ['kotlin', 'firebase', 'dart', 'swift'],
#  815: ['terraform', 'cicd', 'azure', 'docker', 'kubernetes'],
#  816: ['spark', 'airflow', 'etl'],
#  817: ['django', 'postgresql', 'html', 'react', 'angular', 'vue'],
#  818: ['spark', 'powerbi', 'excel'],
#  819: ['quickbooks',
#   'financial modeling',
#   'risk analysis',
#   'ms excel',
#   'accounting'],
#  820: ['figma',
#   'canva',
#   'uiux design',
#   'illustrator',
#   'graphic design',
#   'interaction design'],
#  821: ['ms excel',
#   'accounting',
#   'risk analysis',
#   'financial modeling',
#   'tally',
#   'quickbooks'],
#  822: ['sql', 'tableau', 'powerbi', 'spark'],
#  823: ['react native', 'kotlin', 'dart', 'android', 'ios', 'swift'],
#  824: ['tableau', 'snowflake', 'hadoop'],
#  825: ['dart', 'flutter', 'ios', 'kotlin'],
#  826: ['nodejs', 'vue', 'postgresql', 'react'],
#  827: ['swift', 'flutter', 'dart', 'react native'],
#  828: ['javascript', 'html', 'react'],
#  829: ['digital marketing', 'mailchimp', 'hubspot', 'social media strategy'],
#  830: ['hubspot', 'market research', 'digital marketing', 'mailchimp'],
#  831: ['react native', 'firebase', 'swift', 'android'],
#  832: ['powerbi', 'snowflake', 'sql', 'excel'],
#  833: ['uiux design', 'interaction design', 'photoshop', 'canva'],
#  834: ['adobe xd', 'uiux design', 'figma'],
#  835: ['content writing', 'mailchimp', 'social media strategy'],
#  836: ['tally', 'risk analysis', 'quickbooks'],
#  837: ['jenkins', 'docker', 'gcp', 'kubernetes'],
#  838: ['canva', 'adobe xd', 'graphic design'],
#  839: ['quickbooks', 'accounting', 'financial modeling'],
#  840: ['ms excel',
#   'financial modeling',
#   'tally',
#   'quickbooks',
#   'business analysis'],
#  841: ['pytorch', 'data science', 'deep learning'],
#  842: ['cicd', 'infrastructure as code', 'kubernetes', 'ansible'],
#  843: ['photoshop',
#   'adobe xd',
#   'illustrator',
#   'figma',
#   'uiux design',
#   'graphic design'],
#  844: ['gcp',
#   'kubernetes',
#   'azure',
#   'infrastructure as code',
#   'terraform',
#   'ansible'],
#  845: ['kotlin', 'android', 'flutter', 'react native', 'firebase', 'ios'],
#  846: ['hubspot',
#   'google analytics',
#   'content writing',
#   'mailchimp',
#   'market research',
#   'seo'],
#  847: ['dart', 'kotlin', 'ios'],
#  848: ['docker', 'ansible', 'gcp', 'kubernetes', 'cicd', 'azure'],
#  849: ['spark', 'excel', 'hadoop'],
#  850: ['tensorflow', 'nlp', 'pytorch', 'scikitlearn'],
#  851: ['cicd', 'aws', 'terraform'],
#  852: ['accounting', 'business analysis', 'risk analysis'],
#  853: ['docker', 'gcp', 'jenkins', 'terraform'],
#  854: ['spark', 'airflow', 'snowflake', 'sql', 'hadoop'],
#  855: ['hadoop', 'tableau', 'excel'],
#  856: ['nextjs', 'vue', 'css', 'html', 'django', 'sql'],
#  857: ['agentic ai', 'scikitlearn', 'nlp', 'machine learning'],
#  858: ['mailchimp',
#   'social media strategy',
#   'seo',
#   'content writing',
#   'hubspot'],
#  859: ['accounting',
#   'risk analysis',
#   'business analysis',
#   'financial modeling'],
#  860: ['infrastructure as code', 'cicd', 'gcp'],
#  861: ['kotlin', 'react native', 'android', 'firebase', 'swift', 'ios'],
#  862: ['business analysis', 'tally', 'risk analysis', 'financial modeling'],
#  863: ['sql', 'etl', 'powerbi', 'spark', 'airflow'],
#  864: ['machine learning', 'gen ai', 'computer vision', 'nlp'],
#  865: ['seo', 'digital marketing', 'google analytics', 'hubspot'],
#  866: ['financial modeling', 'quickbooks', 'risk analysis'],
#  867: ['hadoop', 'sql', 'snowflake', 'airflow', 'powerbi', 'tableau'],
#  868: ['gcp', 'kubernetes', 'infrastructure as code'],
#  869: ['react native', 'android', 'dart', 'flutter', 'ios'],
#  870: ['agentic ai',
#   'data science',
#   'computer vision',
#   'tensorflow',
#   'gen ai',
#   'deep learning'],
#  871: ['swift', 'ios', 'android', 'kotlin', 'dart'],
#  872: ['graphic design', 'canva', 'adobe xd', 'interaction design'],
#  873: ['accounting', 'tally', 'risk analysis', 'quickbooks'],
#  874: ['ios', 'kotlin', 'flutter', 'react native', 'firebase'],
#  875: ['nodejs', 'css', 'sql', 'react', 'spring'],
#  876: ['powerbi', 'etl', 'hadoop'],
#  877: ['nlp', 'gen ai', 'scikitlearn', 'agentic ai'],
#  878: ['cicd', 'infrastructure as code', 'terraform', 'docker', 'ansible'],
#  879: ['terraform', 'cicd', 'kubernetes'],
#  880: ['accounting', 'ms excel', 'quickbooks', 'tally'],
#  881: ['tableau', 'etl', 'snowflake', 'excel'],
#  882: ['mongodb', 'nodejs', 'angular', 'spring', 'sql'],
#  883: ['tableau', 'excel', 'spark', 'hadoop'],
#  884: ['flutter', 'android', 'swift', 'firebase'],
#  885: ['spark', 'airflow', 'tableau', 'sql'],
#  886: ['mongodb', 'flask', 'nodejs', 'postgresql', 'django'],
#  887: ['firebase', 'ios', 'android', 'swift'],
#  888: ['agentic ai', 'gen ai', 'tensorflow', 'mlops', 'scikitlearn'],
#  889: ['google analytics', 'content writing', 'hubspot'],
#  890: ['infrastructure as code',
#   'docker',
#   'jenkins',
#   'terraform',
#   'azure',
#   'kubernetes'],
#  891: ['quickbooks', 'accounting', 'risk analysis', 'business analysis'],
#  892: ['machine learning',
#   'data science',
#   'computer vision',
#   'deep learning',
#   'scikitlearn',
#   'tensorflow'],
#  893: ['social media strategy',
#   'google analytics',
#   'seo',
#   'content writing',
#   'hubspot',
#   'market research'],
#  894: ['ms excel', 'quickbooks', 'financial modeling'],
#  895: ['kafka', 'etl', 'spark', 'snowflake', 'powerbi'],
#  896: ['react native', 'android', 'swift', 'flutter', 'firebase'],
#  897: ['spark', 'kafka', 'airflow', 'excel', 'sql', 'hadoop'],
#  898: ['terraform', 'aws', 'kubernetes', 'docker', 'cicd', 'gcp'],
#  899: ['tableau', 'kafka', 'excel', 'snowflake'],
#  900: ['graphic design',
#   'interaction design',
#   'photoshop',
#   'uiux design',
#   'canva',
#   'adobe xd'],
#  901: ['digital marketing',
#   'market research',
#   'content writing',
#   'hubspot',
#   'google analytics'],
#  902: ['mailchimp', 'market research', 'hubspot', 'google analytics', 'seo'],
#  903: ['quickbooks', 'business analysis', 'accounting', 'financial modeling'],
#  904: ['terraform', 'aws', 'cicd'],
#  905: ['machine learning', 'pytorch', 'deep learning'],
#  906: ['digital marketing',
#   'market research',
#   'seo',
#   'social media strategy',
#   'content writing',
#   'hubspot'],
#  907: ['graphic design', 'adobe xd', 'uiux design'],
#  908: ['social media strategy', 'seo', 'mailchimp'],
#  909: ['photoshop', 'interaction design', 'figma', 'canva'],
#  910: ['tableau', 'airflow', 'spark', 'kafka', 'sql'],
#  911: ['sql', 'excel', 'airflow', 'hadoop', 'kafka'],
#  912: ['risk analysis',
#   'quickbooks',
#   'accounting',
#   'tally',
#   'financial modeling',
#   'business analysis'],
#  913: ['dart', 'ios', 'kotlin', 'react native', 'swift'],
#  914: ['airflow', 'kafka', 'excel', 'tableau', 'hadoop'],
#  915: ['docker', 'azure', 'aws', 'jenkins', 'terraform', 'gcp'],
#  916: ['mongodb', 'flask', 'nodejs', 'javascript'],
#  917: ['tally',
#   'ms excel',
#   'quickbooks',
#   'accounting',
#   'risk analysis',
#   'business analysis'],
#  918: ['kafka', 'spark', 'powerbi', 'excel'],
#  919: ['etl', 'sql', 'hadoop', 'snowflake', 'airflow', 'spark'],
#  920: ['kafka', 'spark', 'hadoop', 'airflow', 'excel'],
#  921: ['tableau', 'powerbi', 'kafka'],
#  922: ['social media strategy',
#   'hubspot',
#   'mailchimp',
#   'market research',
#   'digital marketing',
#   'google analytics'],
#  923: ['uiux design', 'illustrator', 'canva', 'figma'],
#  924: ['deep learning', 'machine learning', 'agentic ai'],
#  925: ['digital marketing', 'google analytics', 'seo'],
#  926: ['angular', 'flask', 'vue', 'css', 'sql'],
#  927: ['nlp', 'gen ai', 'machine learning', 'tensorflow', 'pytorch', 'mlops'],
#  928: ['dart', 'swift', 'react native'],
#  929: ['figma', 'adobe xd', 'graphic design', 'illustrator'],
#  930: ['scikitlearn', 'gen ai', 'mlops', 'data science', 'machine learning'],
#  931: ['excel', 'airflow', 'tableau', 'powerbi', 'sql'],
#  932: ['computer vision', 'gen ai', 'tensorflow'],
#  933: ['postgresql', 'css', 'sql', 'django'],
#  934: ['flask', 'spring', 'mongodb', 'react', 'css'],
#  935: ['quickbooks',
#   'tally',
#   'accounting',
#   'risk analysis',
#   'financial modeling',
#   'business analysis'],
#  936: ['powerbi', 'hadoop', 'kafka', 'spark', 'tableau'],
#  937: ['content writing', 'social media strategy', 'seo', 'market research'],
#  938: ['gen ai',
#   'scikitlearn',
#   'deep learning',
#   'agentic ai',
#   'tensorflow',
#   'machine learning'],
#  939: ['machine learning', 'deep learning', 'agentic ai'],
#  940: ['android', 'dart', 'swift'],
#  941: ['powerbi', 'airflow', 'sql', 'excel', 'tableau'],
#  942: ['illustrator', 'graphic design', 'canva', 'interaction design'],
#  943: ['photoshop', 'uiux design', 'interaction design'],
#  944: ['digital marketing',
#   'mailchimp',
#   'hubspot',
#   'seo',
#   'market research',
#   'content writing'],
#  945: ['swift', 'kotlin', 'firebase', 'android'],
#  946: ['agentic ai', 'mlops', 'deep learning', 'tensorflow'],
#  947: ['nodejs', 'javascript', 'react', 'spring', 'django', 'express'],
#  948: ['figma', 'photoshop', 'interaction design'],
#  949: ['risk analysis', 'business analysis', 'accounting', 'quickbooks'],
#  950: ['risk analysis', 'accounting', 'ms excel', 'financial modeling'],
#  951: ['jenkins', 'docker', 'infrastructure as code', 'aws', 'kubernetes'],
#  952: ['tally',
#   'risk analysis',
#   'ms excel',
#   'accounting',
#   'business analysis',
#   'financial modeling'],
#  953: ['ms excel',
#   'financial modeling',
#   'tally',
#   'quickbooks',
#   'risk analysis'],
#  954: ['canva', 'interaction design', 'graphic design'],
#  955: ['adobe xd',
#   'canva',
#   'uiux design',
#   'photoshop',
#   'figma',
#   'graphic design'],
#  956: ['ios', 'firebase', 'dart', 'react native'],
#  957: ['deep learning', 'computer vision', 'nlp'],
#  958: ['business analysis',
#   'financial modeling',
#   'quickbooks',
#   'ms excel',
#   'accounting'],
#  959: ['angular', 'nodejs', 'django', 'flask', 'vue', 'css'],
#  960: ['data science', 'machine learning', 'gen ai'],
#  961: ['django', 'mongodb', 'spring'],
#  962: ['react native', 'firebase', 'android'],
#  963: ['figma', 'canva', 'illustrator', 'interaction design', 'adobe xd'],
#  964: ['react native', 'kotlin', 'dart', 'android', 'swift'],
#  965: ['infrastructure as code', 'kubernetes', 'jenkins', 'docker', 'ansible'],
#  966: ['deep learning', 'tensorflow', 'gen ai', 'machine learning', 'mlops'],
#  967: ['accounting', 'quickbooks', 'tally'],
#  968: ['kafka', 'hadoop', 'sql', 'airflow'],
#  969: ['airflow', 'powerbi', 'tableau', 'snowflake'],
#  970: ['nodejs', 'css', 'vue', 'html'],
#  971: ['mailchimp',
#   'google analytics',
#   'seo',
#   'social media strategy',
#   'hubspot'],
#  972: ['hubspot',
#   'google analytics',
#   'seo',
#   'content writing',
#   'market research'],
#  973: ['computer vision', 'mlops', 'machine learning', 'gen ai'],
#  974: ['content writing', 'google analytics', 'hubspot', 'digital marketing'],
#  975: ['tableau', 'snowflake', 'etl', 'powerbi', 'kafka', 'spark'],
#  976: ['canva', 'figma', 'uiux design', 'adobe xd'],
#  977: ['cicd', 'kubernetes', 'ansible', 'terraform'],
#  978: ['mailchimp',
#   'google analytics',
#   'content writing',
#   'social media strategy',
#   'market research',
#   'hubspot'],
#  979: ['airflow', 'hadoop', 'snowflake'],
#  980: ['canva', 'adobe xd', 'figma', 'illustrator'],
#  981: ['hubspot', 'digital marketing', 'google analytics', 'seo'],
#  982: ['figma', 'canva', 'interaction design', 'adobe xd'],
#  983: ['azure',
#   'terraform',
#   'jenkins',
#   'kubernetes',
#   'infrastructure as code',
#   'aws'],
#  984: ['gcp',
#   'docker',
#   'infrastructure as code',
#   'kubernetes',
#   'azure',
#   'jenkins'],
#  985: ['vue', 'express', 'flask', 'django', 'javascript', 'spring'],
#  986: ['figma', 'adobe xd', 'canva', 'interaction design', 'uiux design'],
#  987: ['tally', 'ms excel', 'quickbooks'],
#  988: ['azure', 'jenkins', 'aws', 'cicd', 'docker', 'gcp'],
#  989: ['figma',
#   'uiux design',
#   'interaction design',
#   'graphic design',
#   'photoshop',
#   'illustrator'],
#  990: ['mongodb', 'html', 'css', 'spring', 'vue', 'nextjs'],
#  991: ['content writing',
#   'mailchimp',
#   'hubspot',
#   'google analytics',
#   'digital marketing',
#   'market research'],
#  992: ['machine learning', 'scikitlearn', 'pytorch', 'agentic ai'],
#  993: ['angular', 'react', 'mongodb'],
#  994: ['pytorch',
#   'agentic ai',
#   'machine learning',
#   'gen ai',
#   'mlops',
#   'scikitlearn'],
#  995: ['ios', 'kotlin', 'flutter', 'swift'],
#  996: ['react native', 'dart', 'android', 'firebase'],
#  997: ['market research',
#   'google analytics',
#   'hubspot',
#   'content writing',
#   'seo',
#   'mailchimp'],
#  998: ['canva',
#   'adobe xd',
#   'illustrator',
#   'interaction design',
#   'uiux design'],
#  999: ['firebase', 'android', 'ios'],
#  1000: ['azure',
#   'ansible',
#   'infrastructure as code',
#   'aws',
#   'cicd',
#   'terraform'],
#  ...}

# %%
from collections import Counter

all_stu_skills = Counter()
for skill in stu_skills.values():
    all_stu_skills.update(skill)
all_int_reqs = Counter()
for req in int_reqs.values():
    all_int_reqs.update(req)

# %%
all_stu_skills
# Out:
# Counter({'sql': 99,
#          'swift': 85,
#          'photoshop': 85,
#          'dart': 84,
#          'canva': 80,
#          'adobe xd': 78,
#          'uiux design': 78,
#          'graphic design': 78,
#          'figma': 75,
#          'accounting': 73,
#          'ios': 73,
#          'flutter': 72,
#          'risk analysis': 72,
#          'quickbooks': 71,
#          'snowflake': 71,
#          'financial modeling': 70,
#          'kotlin': 70,
#          'illustrator': 70,
#          'react native': 70,
#          'google analytics': 69,
#          'mailchimp': 68,
#          'excel': 68,
#          'content writing': 67,
#          'seo': 67,
#          'firebase': 66,
#          'digital marketing': 66,
#          'ms excel': 66,
#          'tally': 66,
#          'interaction design': 65,
#          'tableau': 65,
#          'android': 65,
#          'agentic ai': 64,
#          'hubspot': 64,
#          'market research': 63,
#          'pytorch': 63,
#          'kafka': 62,
#          'business analysis': 61,
#          'terraform': 59,
#          'computer vision': 57,
#          'infrastructure as code': 56,
#          'mlops': 55,
#          'data science': 54,
#          'kubernetes': 54,
#          'social media strategy': 53,
#          'spark': 53,
#          'airflow': 53,
#          'tensorflow': 53,
#          'cicd': 53,
#          'nlp': 53,
#          'docker': 53,
#          'jenkins': 52,
#          'scikitlearn': 51,
#          'gen ai': 50,
#          'aws': 50,
#          'gcp': 49,
#          'etl': 49,
#          'hadoop': 48,
#          'powerbi': 48,
#          'machine learning': 46,
#          'deep learning': 46,
#          'flask': 46,
#          'ansible': 46,
#          'css': 44,
#          'spring': 44,
#          'angular': 43,
#          'django': 42,
#          'nodejs': 42,
#          'postgresql': 40,
#          'azure': 40,
#          'express': 40,
#          'html': 39,
#          'react': 37,
#          'javascript': 36,
#          'vue': 33,
#          'nextjs': 33,
#          'mongodb': 32})

# %%
all_int_reqs
# Out:
# Counter({'sql': 197,
#          'quickbooks': 172,
#          'ms excel': 171,
#          'accounting': 165,
#          'financial modeling': 164,
#          'risk analysis': 161,
#          'business analysis': 160,
#          'uiux design': 160,
#          'tally': 157,
#          'illustrator': 155,
#          'interaction design': 146,
#          'adobe xd': 145,
#          'tableau': 144,
#          'dart': 143,
#          'flutter': 142,
#          'figma': 140,
#          'graphic design': 137,
#          'excel': 137,
#          'swift': 137,
#          'seo': 137,
#          'canva': 135,
#          'android': 135,
#          'ios': 135,
#          'content writing': 135,
#          'react native': 134,
#          'social media strategy': 133,
#          'terraform': 132,
#          'spark': 132,
#          'google analytics': 132,
#          'photoshop': 131,
#          'hubspot': 131,
#          'infrastructure as code': 130,
#          'mailchimp': 130,
#          'etl': 129,
#          'aws': 129,
#          'azure': 128,
#          'gcp': 128,
#          'powerbi': 127,
#          'airflow': 126,
#          'cicd': 126,
#          'market research': 124,
#          'digital marketing': 124,
#          'firebase': 123,
#          'kafka': 120,
#          'docker': 119,
#          'snowflake': 119,
#          'kubernetes': 119,
#          'hadoop': 118,
#          'jenkins': 118,
#          'kotlin': 116,
#          'ansible': 115,
#          'machine learning': 97,
#          'scikitlearn': 95,
#          'gen ai': 94,
#          'data science': 92,
#          'angular': 92,
#          'tensorflow': 91,
#          'vue': 88,
#          'computer vision': 87,
#          'agentic ai': 86,
#          'spring': 86,
#          'pytorch': 85,
#          'deep learning': 84,
#          'react': 82,
#          'css': 81,
#          'mongodb': 78,
#          'mlops': 77,
#          'javascript': 76,
#          'django': 75,
#          'express': 72,
#          'postgresql': 71,
#          'flask': 71,
#          'nextjs': 71,
#          'nlp': 68,
#          'nodejs': 63,
#          'html': 62})

# %%
import matplotlib.pyplot as plt

def plot_skills(counter, title):
    skills = [skill for skill, count in counter.items()]
    counts = [count for skill, count in counter.items()]
    plt.figure(figsize=(10, 15))
    plt.barh(skills, counts, color='skyblue')
    plt.xlabel('Count')
    plt.title(title)
    plt.gca().invert_yaxis()
    plt.show()

# %%
plot_skills(all_stu_skills, 'Student Skills')
plot_skills(all_int_reqs, 'Internship Required Skills')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
skill_corpus = [' '.join(skills) for skills in stu_skills.values()]
X = vectorizer.fit_transform(skill_corpus)
X.shape
# Out:
# (1000, 92)

# %%
intern_reqs_corpus = [' '.join(reqs) for reqs in int_reqs.values()]
Y = vectorizer.transform(intern_reqs_corpus)
Y.shape
# Out:
# (2000, 92)

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(n_neighbors=5, metric='cosine')
model.fit(Y)
# Out:
# NearestNeighbors(metric='cosine')

# %%
# Make predictions: Find similar internships for each student
distances, indices = model.kneighbors(X)

print("Shape of distances:", distances.shape)
print("Shape of indices:", indices.shape)
print("\nFirst student - top 5 matching internships:")
print("Distances:", distances[0])
print("Internship indices:", indices[0])
# Out:
# Shape of distances: (1000, 5)
# Shape of indices: (1000, 5)
#
# First student - top 5 matching internships:
# Distances: [0.13637397 0.13744067 0.13816338 0.13816338 0.14123966]
# Internship indices: [1400 1169 1849  457  155]

# %%
def create_recommendations(distances, indices, top_n=5):
    """
    Create readable recommendations: internships for each student
    """
    recommendations = {}
    
    # Get original student and internship IDs from the dataframes
    student_ids = list(students['student_id'])
    internship_ids = list(internships['internship_id'])
    
    for i, (dists, idxs) in enumerate(zip(distances, indices)):
        student_id = student_ids[i]
        student_name = students[students['student_id'] == student_id]['student_name'].iloc[0]
        
        # Get top internships for this student
        recommended_internships = []
        for j, (dist, idx) in enumerate(zip(dists[:top_n], idxs[:top_n])):
            internship_id = internship_ids[idx]
            company_name = internships[internships['internship_id'] == internship_id]['company'].iloc[0]
            similarity_score = 1 - dist  # Convert distance to similarity
            required_skills = internships[internships['internship_id'] == internship_id]['required_skills'].iloc[0]
            
            recommended_internships.append({
                'rank': j + 1,
                'internship_id': internship_id,
                'company': company_name,
                'similarity_score': similarity_score,
                'distance': dist,
                'required_skills': required_skills
            })
        
        recommendations[student_id] = {
            'student_name': student_name,
            'student_id': student_id,
            'student_skills': stu_skills[student_id],
            'internships': recommended_internships
        }
    
    return recommendations

# Create recommendations
recommendations = create_recommendations(distances, indices, top_n=5)

# %%
# Display recommendations for first 3 students
for i, (student_id, data) in enumerate(recommendations.items()):
    if i >= 3:  # Only show first 3 students
        break
    
    print(f"\n=== Recommendations for {data['student_name']} (ID: {student_id}) ===")
    print(f"Student Skills: {', '.join(data['student_skills'])}")
    print("Top 5 recommended internships:")
    
    for internship in data['internships']:
        print(f"  {internship['rank']}. {internship['company']} (ID: {internship['internship_id']})")
        print(f"     Similarity Score: {internship['similarity_score']:.4f}")
        print(f"     Distance: {internship['distance']:.4f}")
        print(f"     Required Skills: {internship['required_skills']}")
        print()
# Out:
# === Recommendations for Student_1 (ID: 1) ===
# Student Skills: machine learning, data science, agentic ai
# Top 5 recommended internships:
#   1. Kumar & Patel (ID: 1401)
#      Similarity Score: 0.8636
#      Distance: 0.1364
#      Required Skills: data science, mlops, agentic ai, machine learning, pytorch
#
#   2. Bright Future Ltd. (ID: 1170)
#      Similarity Score: 0.8626
#      Distance: 0.1374
#      Required Skills: pytorch, data science, machine learning, tensorflow, agentic ai
#
#   3. Mitchell, Stewart and Morris (ID: 1850)
#      Similarity Score: 0.8618
#      Distance: 0.1382
#      Required Skills: computer vision, data science, agentic ai, machine learning
#
#   4. Singh Technologies (ID: 458)
#      Similarity Score: 0.8618
#      Distance: 0.1382
#      Required Skills: data science, machine learning, agentic ai, computer vision
#
#   5. NextGen Systems (ID: 156)
#      Similarity Score: 0.8588
#      Distance: 0.1412
#      Required Skills: nlp, mlops, machine learning, data science, agentic ai
#
#
# === Recommendations for Student_2 (ID: 2) ===
# Student Skills: dart, firebase, swift, flutter
# Top 5 recommended internships:
#   1. Kumar & Patel (ID: 660)
#      Similarity Score: 0.8902
#      Distance: 0.1098
#      Required Skills: firebase, kotlin, dart, swift, flutter
#
#   2. Robertson-Logan (ID: 1448)
#      Similarity Score: 0.8865
#      Distance: 0.1135
#      Required Skills: firebase, swift, android, flutter, dart
#
#   3. NextGen Systems (ID: 164)
#      Similarity Score: 0.8737
#      Distance: 0.1263
#      Required Skills: swift, firebase, flutter
#
#   4. DataWorks Inc. (ID: 393)
#      Similarity Score: 0.8737
#      Distance: 0.1263
#      Required Skills: firebase, flutter, swift
#
#   5. Guerrero LLC (ID: 507)
#      Similarity Score: 0.8737
#      Distance: 0.1263
#      Required Skills: swift, firebase, flutter
#
#
# === Recommendations for Student_3 (ID: 3) ===
# Student Skills: digital marketing, content writing, mailchimp, hubspot
# Top 5 recommended internships:
#   1. Singh Technologies (ID: 387)
#      Similarity Score: 0.9141
#      Distance: 0.0859
#      Required Skills: hubspot, content writing, digital marketing
#
#   2. Mitchell, Stewart and Morris (ID: 56)
#      Similarity Score: 0.9111
#      Distance: 0.0889
#      Required Skills: mailchimp, digital marketing, content writing
#
#   3. Harris and Sons (ID: 1564)
#      Similarity Score: 0.8683
#      Distance: 0.1317
#      Required Skills: hubspot, content writing, digital marketing, google analytics, mailchimp
#
#   4. NextGen Systems (ID: 1814)
#      Similarity Score: 0.8683
#      Distance: 0.1317
#      Required Skills: digital marketing, google analytics, hubspot, content writing, mailchimp
#
#   5. NextGen Systems (ID: 1734)
#      Similarity Score: 0.8187
#      Distance: 0.1813
#      Required Skills: digital marketing, mailchimp, seo, hubspot, google analytics, content writing
